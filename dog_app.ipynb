# %% [markdown]
# ## Convolutional Neural Networks
#
# ## Project: Write an Algorithm for a Dog Identification App
#
# ---
#
# In this notebook, some template code has already been provided for you, and you will need to implement additional functionality to successfully complete this project. You will not need to modify the included code beyond what is requested. Sections that begin with **'(IMPLEMENTATION)'** in the header indicate that the following block of code will require additional functionality which you must provide. Instructions will be provided for each section, and the specifics of the implementation are marked in the code block with a 'TODO' statement. Please be sure to read the instructions carefully!
#
# > **Note**: Once you have completed all of the code implementations, you need to finalize your work by exporting the iPython Notebook as an HTML document. Before exporting the notebook to html, all of the code cells need to have been run so that reviewers can see the final implementation and output. You can then export the notebook by using the menu above and navigating to  \n",
#     "**File -> Download as -> HTML (.html)**. Include the finished document along with this notebook as your submission.
#
# In addition to implementing code, there will be questions that you must answer which relate to the project and your implementation. Each section where you will answer a question is preceded by a **'Question X'** header. Carefully read each question and provide thorough answers in the following text boxes that begin with **'Answer:'**. Your project submission will be evaluated based on your answers to each of the questions and the implementation you provide.
#
# >**Note:** Code and Markdown cells can be executed using the **Shift + Enter** keyboard shortcut.  Markdown cells can be edited by double-clicking the cell to enter edit mode.
#
# The rubric contains _optional_ "Stand Out Suggestions" for enhancing the project beyond the minimum requirements. If you decide to pursue the "Stand Out Suggestions", you should include the code in this IPython notebook.
#
#
#
# ---
# ### Why We're Here
#
# In this notebook, you will make the first steps towards developing an algorithm that could be used as part of a mobile or web app.  At the end of this project, your code will accept any user-supplied image as input.  If a dog is detected in the image, it will provide an estimate of the dog's breed.  If a human is detected, it will provide an estimate of the dog breed that is most resembling.  The image below displays potential sample output of your finished project (... but we expect that each student's algorithm will behave differently!).
#
# ![Sample Dog Output](images/sample_dog_output.png)
#
# In this real-world setting, you will need to piece together a series of models to perform different tasks; for instance, the algorithm that detects humans in an image will be different from the CNN that infers dog breed.  There are many points of possible failure, and no perfect algorithm exists.  Your imperfect solution will nonetheless create a fun user experience!
#
# ### The Road Ahead
#
# We break the notebook into separate steps.  Feel free to use the links below to navigate the notebook.
#
# * [Step 0](#step0): Import Datasets
# * [Step 1](#step1): Detect Humans
# * [Step 2](#step2): Detect Dogs
# * [Step 3](#step3): Create a CNN to Classify Dog Breeds (from Scratch)
# * [Step 4](#step4): Use a CNN to Classify Dog Breeds (using Transfer Learning)
# * [Step 5](#step5): Create a CNN to Classify Dog Breeds (using Transfer Learning)
# * [Step 6](#step6): Write your Algorithm
# * [Step 7](#step7): Test Your Algorithm
#
# ---
# <a id='step0'></a>
# ## Step 0: Import Datasets
#
# ### Import Dog Dataset
#
# In the code cell below, we import a dataset of dog images.  We populate a few variables through the use of the `load_files` function from the scikit-learn library:
# - `train_files`, `valid_files`, `test_files` - numpy arrays containing file paths to images
# - `train_targets`, `valid_targets`, `test_targets` - numpy arrays containing onehot-encoded classification labels
# - `dog_names` - list of string-valued dog breed names for translating labels

# %%
from sklearn.datasets import load_files       
from keras.utils import np_utils
import numpy as np
from glob import glob

# define function to load train, test, and validation datasets
def load_dataset(path):
    data = load_files(path)
    dog_files = np.array(data['filenames'])
    dog_targets = np_utils.to_categorical(np.array(data['target']), 133)
    return dog_files, dog_targets

# load train, test, and validation datasets
train_files, train_targets = load_dataset('dog_images/train')
valid_files, valid_targets = load_dataset('dog_images/valid')
test_files, test_targets = load_dataset('dog_images/test')

# load list of dog names
dog_names = [item[20:-1] for item in sorted(glob("dog_images/train/*/"))]

# print statistics about the dataset
print('There are %d total dog categories.' % len(dog_names))
print('There are %s total dog images.\n' % len(np.hstack([train_files, valid_files, test_files])))
print('There are %d training dog images.' % len(train_files))
print('There are %d validation dog images.' % len(valid_files))
print('There are %d test dog images.'% len(test_files))
# Out:
# Using TensorFlow backend.
# There are 133 total dog categories.
# There are 8351 total dog images.
#
# There are 6680 training dog images.
# There are 835 validation dog images.
# There are 836 test dog images.

# %% [markdown]
# ### Import Human Dataset
#
# In the code cell below, we import a dataset of human images, where the file paths are stored in the numpy array `human_files`.

# %%
import random
random.seed(8675309)

# load filenames in shuffled human dataset
human_files = np.array(glob("lfw/*/*"))
random.shuffle(human_files)

# print statistics about the dataset
print('There are %d total human images.' % len(human_files))
# Out:
# There are 13233 total human images.

# %% [markdown]
# ---
# <a id='step1'></a>
# ## Step 1: Detect Humans
#
# We use OpenCV's implementation of [Haar feature-based cascade classifiers](http://docs.opencv.org/trunk/d7/d8b/tutorial_py_face_detection.html) to detect human faces in images.  OpenCV provides many pre-trained face detectors, stored as XML files on [github](https://github.com/opencv/opencv/tree/master/data/haarcascades).  We have downloaded one of these detectors and stored it in the `haarcascades` directory.
#
# In the next code cell, we demonstrate how to use this detector to find human faces in a sample image.

# %%
import cv2                
import matplotlib.pyplot as plt                        
# %matplotlib inline                               

# extract pre-trained face detector
face_cascade = cv2.CascadeClassifier('haarcascades/haarcascade_frontalface_alt.xml')

# load color (BGR) image
img = cv2.imread(human_files[12222])
# convert BGR image to grayscale
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# find faces in image
faces = face_cascade.detectMultiScale(gray)

# print number of faces detected in the image
print('Number of faces detected:', len(faces))

# get bounding box for each detected face
for (x,y,w,h) in faces:
    # add bounding box to color image
    cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
    
# convert BGR image to RGB for plotting
cv_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# display the image, along with bounding box
plt.imshow(cv_rgb)
plt.show()
# Out:
# Number of faces detected: 1

# %% [markdown]
# Before using any of the face detectors, it is standard procedure to convert the images to grayscale.  The `detectMultiScale` function executes the classifier stored in `face_cascade` and takes the grayscale image as a parameter.
#
# In the above code, `faces` is a numpy array of detected faces, where each row corresponds to a detected face.  Each detected face is a 1D array with four entries that specifies the bounding box of the detected face.  The first two entries in the array (extracted in the above code as `x` and `y`) specify the horizontal and vertical positions of the top left corner of the bounding box.  The last two entries in the array (extracted here as `w` and `h`) specify the width and height of the box.
#
# ### Write a Human Face Detector
#
# We can use this procedure to write a function that returns `True` if a human face is detected in an image and `False` otherwise.  This function, aptly named `face_detector`, takes a string-valued file path to an image as input and appears in the code block below.

# %%
# returns "True" if face is detected in image stored at img_path
def face_detector(img_path):
    img = cv2.imread(img_path)
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    faces = face_cascade.detectMultiScale(gray)
    return len(faces) > 0

# %% [markdown]
# ### (IMPLEMENTATION) Assess the Human Face Detector
#
# __Question 1:__ Use the code cell below to test the performance of the `face_detector` function.
# - What percentage of the first 100 images in `human_files` have a detected human face?
# - What percentage of the first 100 images in `dog_files` have a detected human face?
#
# Ideally, we would like 100% of human images with a detected face and 0% of dog images with a detected face.  You will see that our algorithm falls short of this goal, but still gives acceptable performance.  We extract the file paths for the first 100 images from each of the datasets and store them in the numpy arrays `human_files_short` and `dog_files_short`.
#
# __Answer:__
#
# Using haarcascades face detector:
#
# Detected human faces in the first 100 human images: 100%
#
# Detected faces in the first 100 dogs images: 11%

# %%
import time

# %%
# %%time
n_files = 100

human_files_short = human_files[:n_files]
dog_files_short = train_files[:n_files]
# Do NOT modify the code above this line.

## TODO: Test the performance of the face_detector algorithm 
## on the images in human_files_short and dog_files_short.
humans = 0 
dogs = 0

for img in human_files_short:
    if face_detector(img) == True:
        humans += 1
        
for img in dog_files_short:
    if face_detector(img) == True:
        dogs += 1

print('Among the first {} human images, {:.2%} were detected as a human face.'.format(n_files, humans/n_files))
print('Among the first {} dog images, {:.2%} were detected as a human face.'.format(n_files, dogs/n_files))
# Out:
# Among the first 100 human images, 99.00% were detected as a human face.
# Among the first 100 dog images, 12.00% were detected as a human face.
# Wall time: 4.64 s

# %% [markdown]
# __Question 2:__ This algorithmic choice necessitates that we communicate to the user that we accept human images only when they provide a clear view of a face (otherwise, we risk having unneccessarily frustrated users!). In your opinion, is this a reasonable expectation to pose on the user? If not, can you think of a way to detect humans in images that does not necessitate an image with a clearly presented face?
#
# __Answer:__
#
# I think that if we can minimize the end user's work/interference we should do. With an "easy to use" system, I think that we can reduce the chances of errors and consequently, frustration. In my opinion, we should train a model including a diverse set of images from a wide variety of angles, lighting conditions, and partial faces.
#
# Haar-Cascade is good at detecting edges and lines. So it is very effective in face detection. The downside of it is to be set manually and there is a limit to the types of things it can detect. The plus side is that Haar-Cascade don’t need to be trained and we can create a classifier without a large dataset. It also has a higher execution speed, requiring less computation power.
# [link](https://towardsdatascience.com/whats-the-difference-between-haar-feature-classifiers-and-convolutional-neural-networks-ce6828343aeb)
#
#
# We suggest the face detector from OpenCV as a potential way to detect human images in your algorithm, but you are free to explore other approaches, especially approaches that make use of deep learning :).  Please use the code cell below to design and test your own face detection algorithm.  If you decide to pursue this _optional_ task, report performance on each of the datasets.

# %%
## (Optional) TODO: Report the performance of another  
## face detection algorithm on the LFW dataset
### Feel free to use as many code cells as needed.

#Approach II: OPENCV LBP CASCADE CLASSIFIER
#load cascade classifier training file for lbpcascade
lbp_face_cascade = cv2.CascadeClassifier('lbpcascade/lbpcascade_frontalface_improved.xml')  
    
def lbp_face_detector(img_path):
    img = cv2.imread(img_path)
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    faces = lbp_face_cascade.detectMultiScale(gray)
    return len(faces) > 0

# %%
humans = 0
dogs = 0

for img in human_files_short:
    if lbp_face_detector(img):
        humans += 1
        
for img in dog_files_short:    
    if lbp_face_detector(img):
        dogs +=1
        
print('Among the first {} human images, {:.2%} were detected as a human face.'.format(n_files, humans/n_files))
print('Among the first {} dog images, {:.2%} were detected as a human face.'.format(n_files, dogs/n_files))
# Out:
# Among the first 100 human images, 93.00% were detected as a human face.
# Among the first 100 dog images, 1.00% were detected as a human face.

# %% [markdown]
# ---
# <a id='step2'></a>
# ## Step 2: Detect Dogs
#
# In this section, we use a pre-trained [ResNet-50](http://ethereon.github.io/netscope/#/gist/db945b393d40bfa26006) model to detect dogs in images.  Our first line of code downloads the ResNet-50 model, along with weights that have been trained on [ImageNet](http://www.image-net.org/), a very large, very popular dataset used for image classification and other vision tasks.  ImageNet contains over 10 million URLs, each linking to an image containing an object from one of [1000 categories](https://gist.github.com/yrevar/942d3a0ac09ec9e5eb3a).  Given an image, this pre-trained ResNet-50 model returns a prediction (derived from the available categories in ImageNet) for the object that is contained in the image.

# %%
from keras.applications.resnet50 import ResNet50

# define ResNet50 model
ResNet50_model = ResNet50(weights='imagenet')
# Out:
# WARNING:tensorflow:From C:\Users\eders\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:4070: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# Downloading data from https://github.com/fchollet/deep-learning-models/releases/download/v0.2/resnet50_weights_tf_dim_ordering_tf_kernels.h5
# 102858752/102853048 [==============================] - 21s 0us/step

# %% [markdown]
# ### Pre-process the Data
#
# When using TensorFlow as backend, Keras CNNs require a 4D array (which we'll also refer to as a 4D tensor) as input, with shape
#
# $$
# (\text{nb_samples}, \text{rows}, \text{columns}, \text{channels}),
# $$
#
# where `nb_samples` corresponds to the total number of images (or samples), and `rows`, `columns`, and `channels` correspond to the number of rows, columns, and channels for each image, respectively.
#
# The `path_to_tensor` function below takes a string-valued file path to a color image as input and returns a 4D tensor suitable for supplying to a Keras CNN.  The function first loads the image and resizes it to a square image that is $224 \times 224$ pixels.  Next, the image is converted to an array, which is then resized to a 4D tensor.  In this case, since we are working with color images, each image has three channels.  Likewise, since we are processing a single image (or sample), the returned tensor will always have shape
#
# $$
# (1, 224, 224, 3).
# $$
#
# The `paths_to_tensor` function takes a numpy array of string-valued image paths as input and returns a 4D tensor with shape
#
# $$
# (\text{nb_samples}, 224, 224, 3).
# $$
#
# Here, `nb_samples` is the number of samples, or number of images, in the supplied array of image paths.  It is best to think of `nb_samples` as the number of 3D tensors (where each 3D tensor corresponds to a different image) in your dataset!

# %%
from keras.preprocessing import image                  
from tqdm import tqdm

def path_to_tensor(img_path):
    # loads RGB image as PIL.Image.Image type
    img = image.load_img(img_path, target_size=(224, 224))
    # convert PIL.Image.Image type to 3D tensor with shape (224, 224, 3)
    x = image.img_to_array(img)
    # convert 3D tensor to 4D tensor with shape (1, 224, 224, 3) and return 4D tensor
    return np.expand_dims(x, axis=0)

def paths_to_tensor(img_paths):
    list_of_tensors = [path_to_tensor(img_path) for img_path in tqdm(img_paths)]
    return np.vstack(list_of_tensors)

# %% [markdown]
# ### Making Predictions with ResNet-50
#
# Getting the 4D tensor ready for ResNet-50, and for any other pre-trained model in Keras, requires some additional processing.  First, the RGB image is converted to BGR by reordering the channels.  All pre-trained models have the additional normalization step that the mean pixel (expressed in RGB as $[103.939, 116.779, 123.68]$ and calculated from all pixels in all images in ImageNet) must be subtracted from every pixel in each image.  This is implemented in the imported function `preprocess_input`.  If you're curious, you can check the code for `preprocess_input` [here](https://github.com/fchollet/keras/blob/master/keras/applications/imagenet_utils.py).
#
# Now that we have a way to format our image for supplying to ResNet-50, we are now ready to use the model to extract the predictions.  This is accomplished with the `predict` method, which returns an array whose $i$-th entry is the model's predicted probability that the image belongs to the $i$-th ImageNet category.  This is implemented in the `ResNet50_predict_labels` function below.
#
# By taking the argmax of the predicted probability vector, we obtain an integer corresponding to the model's predicted object class, which we can identify with an object category through the use of this [dictionary](https://gist.github.com/yrevar/942d3a0ac09ec9e5eb3a).

# %%
from keras.applications.resnet50 import preprocess_input, decode_predictions

def ResNet50_predict_labels(img_path):
    # returns prediction vector for image located at img_path
    img = preprocess_input(path_to_tensor(img_path))
    return np.argmax(ResNet50_model.predict(img))

# %% [markdown]
# ### Write a Dog Detector
#
# While looking at the [dictionary](https://gist.github.com/yrevar/942d3a0ac09ec9e5eb3a), you will notice that the categories corresponding to dogs appear in an uninterrupted sequence and correspond to dictionary keys 151-268, inclusive, to include all categories from `'Chihuahua'` to `'Mexican hairless'`.  Thus, in order to check to see if an image is predicted to contain a dog by the pre-trained ResNet-50 model, we need only check if the `ResNet50_predict_labels` function above returns a value between 151 and 268 (inclusive).
#
# We use these ideas to complete the `dog_detector` function below, which returns `True` if a dog is detected in an image (and `False` if not).

# %%
### returns "True" if a dog is detected in the image stored at img_path
def dog_detector(img_path):
    prediction = ResNet50_predict_labels(img_path)
    return ((prediction <= 268) & (prediction >= 151))

# %% [markdown]
# ### (IMPLEMENTATION) Assess the Dog Detector
#
# __Question 3:__ Use the code cell below to test the performance of your `dog_detector` function.
# - What percentage of the images in `human_files_short` have a detected dog?
# - What percentage of the images in `dog_files_short` have a detected dog?
#
# __Answer:__

# %%
### TODO: Test the performance of the dog_detector function
### on the images in human_files_short and dog_files_short.
n_files = 100

human_files_short = human_files[:n_files]
dog_files_short = train_files[:n_files]
humans = 0 
dogs = 0

for img in human_files_short:
    if dog_detector(img) == True:
        humans += 1
        
for img in dog_files_short:
    if dog_detector(img) == True:
        dogs += 1

print('Among the first {} human images, {:.2%} were detected as a dog.'.format(n_files, humans/n_files))
print('Among the first {} dog images, {:.2%} were detected as a dog.'.format(n_files, dogs/n_files))
# Out:
# WARNING:tensorflow:From C:\Users\eders\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# Among the first 100 human images, 1.00% were detected as a dog.
# Among the first 100 dog images, 100.00% were detected as a dog.

# %% [markdown]
# ---
# <a id='step3'></a>
# ## Step 3: Create a CNN to Classify Dog Breeds (from Scratch)
#
# Now that we have functions for detecting humans and dogs in images, we need a way to predict breed from images.  In this step, you will create a CNN that classifies dog breeds.  You must create your CNN _from scratch_ (so, you can't use transfer learning _yet_!), and you must attain a test accuracy of at least 1%.  In Step 5 of this notebook, you will have the opportunity to use transfer learning to create a CNN that attains greatly improved accuracy.
#
# Be careful with adding too many trainable layers!  More parameters means longer training, which means you are more likely to need a GPU to accelerate the training process.  Thankfully, Keras provides a handy estimate of the time that each epoch is likely to take; you can extrapolate this estimate to figure out how long it will take for your algorithm to train.
#
# We mention that the task of assigning breed to dogs from images is considered exceptionally challenging.  To see why, consider that *even a human* would have great difficulty in distinguishing between a Brittany and a Welsh Springer Spaniel.
#
# Brittany | Welsh Springer Spaniel
# - | -
# <img src="images/Brittany_02625.jpg" width="100"> | <img src="images/Welsh_springer_spaniel_08203.jpg" width="200">
#
# It is not difficult to find other dog breed pairs with minimal inter-class variation (for instance, Curly-Coated Retrievers and American Water Spaniels).
#
# Curly-Coated Retriever | American Water Spaniel
# - | -
# <img src="images/Curly-coated_retriever_03896.jpg" width="200"> | <img src="images/American_water_spaniel_00648.jpg" width="200">
#
#
# Likewise, recall that labradors come in yellow, chocolate, and black.  Your vision-based algorithm will have to conquer this high intra-class variation to determine how to classify all of these different shades as the same breed.
#
# Yellow Labrador | Chocolate Labrador | Black Labrador
# - | -
# <img src="images/Labrador_retriever_06457.jpg" width="150"> | <img src="images/Labrador_retriever_06455.jpg" width="240"> | <img src="images/Labrador_retriever_06449.jpg" width="220">
#
# We also mention that random chance presents an exceptionally low bar: setting aside the fact that the classes are slightly imabalanced, a random guess will provide a correct answer roughly 1 in 133 times, which corresponds to an accuracy of less than 1%.
#
# Remember that the practice is far ahead of the theory in deep learning.  Experiment with many different architectures, and trust your intuition.  And, of course, have fun!
#
# ### Pre-process the Data
#
# We rescale the images by dividing every pixel in every image by 255.

# %%
from PIL import ImageFile                            
ImageFile.LOAD_TRUNCATED_IMAGES = True                 

# pre-process the data for Keras
train_tensors = paths_to_tensor(train_files).astype('float32')/255
valid_tensors = paths_to_tensor(valid_files).astype('float32')/255
test_tensors = paths_to_tensor(test_files).astype('float32')/255
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████| 6680/6680 [00:38<00:00, 172.41it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████| 835/835 [00:04<00:00, 188.45it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████| 836/836 [00:04<00:00, 189.68it/s]

# %% [markdown]
# ### (IMPLEMENTATION) Model Architecture
#
# Create a CNN to classify dog breed.  At the end of your code cell block, summarize the layers of your model by executing the line:
#
#         model.summary()
#
# We have imported some Python modules to get you started, but feel free to import as many modules as you need.  If you end up getting stuck, here's a hint that specifies a model that trains relatively fast on CPU and attains >1% test accuracy in 5 epochs:
#
# ![Sample CNN](images/sample_cnn.png)
#
# __Question 4:__ Outline the steps you took to get to your final CNN architecture and your reasoning at each step.  If you chose to use the hinted architecture above, describe why you think that CNN architecture should work well for the image classification task.
#
# __Answer:__
#
# I have decided to use the same architecture learned in Cifar10 lesson.
# The architecture is the following:
# - 03 C2 layers (16, 32, 64 filters) with 3 MP layers in between.
# - 01 Flatten layer to reduce the matrix to a row vector.
# - Dropout to reduce overfitting and ensure that the network generalizes well.
# - 133 nodes in the last fully connected layer with softmax activation function to obtain probabilities of the prediction.
# - Relu activation function was used for all other layers.

# %%
from keras.layers import Conv2D, MaxPooling2D, GlobalAveragePooling2D
from keras.layers import Dropout, Flatten, Dense
from keras.models import Sequential

model = Sequential()

### TODO: Define your architecture.
model.add(Conv2D(filters=16, kernel_size=2, padding='same', activation='relu', input_shape=train_tensors.shape[1:]))
model.add(MaxPooling2D(pool_size=2))
model.add(Conv2D(filters=32, kernel_size=2, padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Conv2D(filters=64, kernel_size=2, padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.3))
model.add(Flatten())
model.add(Dense(500, activation='relu'))
model.add(Dropout(0.4))
model.add(Dense(133, activation='softmax'))

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 224, 224, 16)      208
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 112, 112, 16)      0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 112, 112, 32)      2080
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 56, 56, 32)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 56, 56, 64)        8256
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 28, 28, 64)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 28, 28, 64)        0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 50176)             0
# _________________________________________________________________
# dense_1 (Dense)              (None, 500)               25088500
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 500)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 133)               66633
# =================================================================
# Total params: 25,165,677
# Trainable params: 25,165,677
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Compile the Model

# %%
model.compile(optimizer='rmsprop', loss='categorical_crossentropy', metrics=['accuracy'])

# %% [markdown]
# ### (IMPLEMENTATION) Train the Model
#
# Train your model in the code cell below.  Use model checkpointing to save the model that attains the best validation loss.
#
# You are welcome to [augment the training data](https://blog.keras.io/building-powerful-image-classification-models-using-very-little-data.html), but this is not a requirement.

# %%
from keras.callbacks import ModelCheckpoint  

### TODO: specify the number of epochs that you would like to use to train the model.

epochs = 5

### Do NOT modify the code below this line.

checkpointer = ModelCheckpoint(filepath='saved_models/weights.best.from_scratch.hdf5', 
                               verbose=1, save_best_only=True)

model.fit(train_tensors, train_targets, 
          validation_data=(valid_tensors, valid_targets),
          epochs=epochs, batch_size=20, callbacks=[checkpointer], verbose=1)
# Out:
# Train on 6680 samples, validate on 835 samples
# Epoch 1/5
# 3680/6680 [===============>..............] - ETA: 2:36 - loss: 4.9106 - accuracy: 0.0000e+ - ETA: 2:06 - loss: 9.2203 - accuracy: 0.0000e+ - ETA: 1:56 - loss: 8.1723 - accuracy: 0.0000e+ - ETA: 1:51 - loss: 7.5717 - accuracy: 0.0000e+ - ETA: 1:47 - loss: 7.1639 - accuracy: 0.0000e+ - ETA: 1:45 - loss: 6.7691 - accuracy: 0.0000e+ - ETA: 1:44 - loss: 6.5261 - accuracy: 0.0000e+ - ETA: 1:42 - loss: 6.3420 - accuracy: 0.0000e+ - ETA: 1:41 - loss: 6.1761 - accuracy: 0.0056   - ETA: 1:41 - loss: 6.0666 - accuracy: 0.00 - ETA: 1:40 - loss: 5.9621 - accuracy: 0.00 - ETA: 1:39 - loss: 5.8820 - accuracy: 0.00 - ETA: 1:39 - loss: 5.8112 - accuracy: 0.00 - ETA: 1:38 - loss: 5.7488 - accuracy: 0.00 - ETA: 1:37 - loss: 5.6899 - accuracy: 0.00 - ETA: 1:37 - loss: 5.6400 - accuracy: 0.00 - ETA: 1:36 - loss: 5.5947 - accuracy: 0.00 - ETA: 1:36 - loss: 5.5590 - accuracy: 0.00 - ETA: 1:35 - loss: 5.5232 - accuracy: 0.00 - ETA: 1:35 - loss: 5.4917 - accuracy: 0.00 - ETA: 1:34 - loss: 5.4624 - accuracy: 0.00 - ETA: 1:34 - loss: 5.4375 - accuracy: 0.00 - ETA: 1:34 - loss: 5.4156 - accuracy: 0.00 - ETA: 1:33 - loss: 5.3942 - accuracy: 0.00 - ETA: 1:33 - loss: 5.3743 - accuracy: 0.00 - ETA: 1:32 - loss: 5.3552 - accuracy: 0.00 - ETA: 1:32 - loss: 5.3379 - accuracy: 0.00 - ETA: 1:31 - loss: 5.3214 - accuracy: 0.00 - ETA: 1:31 - loss: 5.3062 - accuracy: 0.00 - ETA: 1:31 - loss: 5.2915 - accuracy: 0.00 - ETA: 1:30 - loss: 5.2788 - accuracy: 0.00 - ETA: 1:30 - loss: 5.2650 - accuracy: 0.00 - ETA: 1:30 - loss: 5.2541 - accuracy: 0.00 - ETA: 1:29 - loss: 5.2441 - accuracy: 0.00 - ETA: 1:29 - loss: 5.2341 - accuracy: 0.00 - ETA: 1:29 - loss: 5.2242 - accuracy: 0.00 - ETA: 1:28 - loss: 5.2146 - accuracy: 0.00 - ETA: 1:28 - loss: 5.2064 - accuracy: 0.00 - ETA: 1:28 - loss: 5.1985 - accuracy: 0.00 - ETA: 1:27 - loss: 5.1909 - accuracy: 0.00 - ETA: 1:27 - loss: 5.1840 - accuracy: 0.00 - ETA: 1:27 - loss: 5.1759 - accuracy: 0.00 - ETA: 1:26 - loss: 5.1698 - accuracy: 0.00 - ETA: 1:26 - loss: 5.1641 - accuracy: 0.00 - ETA: 1:26 - loss: 5.1575 - accuracy: 0.00 - ETA: 1:25 - loss: 5.1512 - accuracy: 0.00 - ETA: 1:25 - loss: 5.1458 - accuracy: 0.00 - ETA: 1:25 - loss: 5.1407 - accuracy: 0.00 - ETA: 1:25 - loss: 5.1356 - accuracy: 0.00 - ETA: 1:24 - loss: 5.1305 - accuracy: 0.00 - ETA: 1:24 - loss: 5.1260 - accuracy: 0.00 - ETA: 1:24 - loss: 5.1218 - accuracy: 0.00 - ETA: 1:23 - loss: 5.1176 - accuracy: 0.00 - ETA: 1:23 - loss: 5.1136 - accuracy: 0.00 - ETA: 1:23 - loss: 5.1097 - accuracy: 0.00 - ETA: 1:22 - loss: 5.1057 - accuracy: 0.00 - ETA: 1:22 - loss: 5.1015 - accuracy: 0.00 - ETA: 1:22 - loss: 5.0979 - accuracy: 0.00 - ETA: 1:21 - loss: 5.0948 - accuracy: 0.00 - ETA: 1:21 - loss: 5.0912 - accuracy: 0.00 - ETA: 1:21 - loss: 5.0875 - accuracy: 0.00 - ETA: 1:20 - loss: 5.0847 - accuracy: 0.00 - ETA: 1:20 - loss: 5.0818 - accuracy: 0.00 - ETA: 1:20 - loss: 5.0789 - accuracy: 0.00 - ETA: 1:20 - loss: 5.0758 - accuracy: 0.00 - ETA: 1:19 - loss: 5.0729 - accuracy: 0.00 - ETA: 1:19 - loss: 5.0700 - accuracy: 0.00 - ETA: 1:19 - loss: 5.0672 - accuracy: 0.00 - ETA: 1:18 - loss: 5.0643 - accuracy: 0.00 - ETA: 1:18 - loss: 5.0622 - accuracy: 0.00 - ETA: 1:18 - loss: 5.0592 - accuracy: 0.00 - ETA: 1:17 - loss: 5.0573 - accuracy: 0.00 - ETA: 1:17 - loss: 5.0553 - accuracy: 0.00 - ETA: 1:17 - loss: 5.0530 - accuracy: 0.00 - ETA: 1:17 - loss: 5.0505 - accuracy: 0.00 - ETA: 1:16 - loss: 5.0487 - accuracy: 0.00 - ETA: 1:16 - loss: 5.0463 - accuracy: 0.00 - ETA: 1:16 - loss: 5.0445 - accuracy: 0.00 - ETA: 1:15 - loss: 5.0425 - accuracy: 0.00 - ETA: 1:15 - loss: 5.0408 - accuracy: 0.00 - ETA: 1:15 - loss: 5.0387 - accuracy: 0.00 - ETA: 1:14 - loss: 5.0377 - accuracy: 0.00 - ETA: 1:14 - loss: 5.0358 - accuracy: 0.00 - ETA: 1:14 - loss: 5.0340 - accuracy: 0.00 - ETA: 1:14 - loss: 5.0322 - accuracy: 0.00 - ETA: 1:13 - loss: 5.0304 - accuracy: 0.00 - ETA: 1:13 - loss: 5.0285 - accuracy: 0.00 - ETA: 1:13 - loss: 5.0275 - accuracy: 0.00 - ETA: 1:12 - loss: 5.0261 - accuracy: 0.00 - ETA ...
# 6680/6680 [==============================] - ETA: 44s - loss: 4.9457 - accuracy: 0.010 - ETA: 43s - loss: 4.9457 - accuracy: 0.010 - ETA: 43s - loss: 4.9451 - accuracy: 0.010 - ETA: 43s - loss: 4.9442 - accuracy: 0.010 - ETA: 43s - loss: 4.9440 - accuracy: 0.010 - ETA: 42s - loss: 4.9436 - accuracy: 0.010 - ETA: 42s - loss: 4.9431 - accuracy: 0.010 - ETA: 42s - loss: 4.9427 - accuracy: 0.010 - ETA: 41s - loss: 4.9417 - accuracy: 0.010 - ETA: 41s - loss: 4.9406 - accuracy: 0.010 - ETA: 41s - loss: 4.9406 - accuracy: 0.010 - ETA: 40s - loss: 4.9395 - accuracy: 0.010 - ETA: 40s - loss: 4.9384 - accuracy: 0.010 - ETA: 40s - loss: 4.9382 - accuracy: 0.010 - ETA: 40s - loss: 4.9374 - accuracy: 0.010 - ETA: 39s - loss: 4.9376 - accuracy: 0.010 - ETA: 39s - loss: 4.9369 - accuracy: 0.010 - ETA: 39s - loss: 4.9359 - accuracy: 0.010 - ETA: 38s - loss: 4.9363 - accuracy: 0.010 - ETA: 38s - loss: 4.9361 - accuracy: 0.010 - ETA: 38s - loss: 4.9354 - accuracy: 0.010 - ETA: 37s - loss: 4.9348 - accuracy: 0.010 - ETA: 37s - loss: 4.9343 - accuracy: 0.010 - ETA: 37s - loss: 4.9333 - accuracy: 0.011 - ETA: 37s - loss: 4.9326 - accuracy: 0.011 - ETA: 36s - loss: 4.9323 - accuracy: 0.011 - ETA: 36s - loss: 4.9310 - accuracy: 0.011 - ETA: 36s - loss: 4.9307 - accuracy: 0.011 - ETA: 35s - loss: 4.9306 - accuracy: 0.011 - ETA: 35s - loss: 4.9300 - accuracy: 0.011 - ETA: 35s - loss: 4.9295 - accuracy: 0.011 - ETA: 34s - loss: 4.9292 - accuracy: 0.011 - ETA: 34s - loss: 4.9291 - accuracy: 0.011 - ETA: 34s - loss: 4.9288 - accuracy: 0.011 - ETA: 34s - loss: 4.9282 - accuracy: 0.011 - ETA: 33s - loss: 4.9279 - accuracy: 0.011 - ETA: 33s - loss: 4.9276 - accuracy: 0.012 - ETA: 33s - loss: 4.9271 - accuracy: 0.011 - ETA: 32s - loss: 4.9271 - accuracy: 0.011 - ETA: 32s - loss: 4.9267 - accuracy: 0.011 - ETA: 32s - loss: 4.9263 - accuracy: 0.012 - ETA: 32s - loss: 4.9257 - accuracy: 0.011 - ETA: 31s - loss: 4.9253 - accuracy: 0.011 - ETA: 31s - loss: 4.9251 - accuracy: 0.012 - ETA: 31s - loss: 4.9250 - accuracy: 0.012 - ETA: 30s - loss: 4.9247 - accuracy: 0.012 - ETA: 30s - loss: 4.9243 - accuracy: 0.012 - ETA: 30s - loss: 4.9240 - accuracy: 0.012 - ETA: 29s - loss: 4.9236 - accuracy: 0.012 - ETA: 29s - loss: 4.9228 - accuracy: 0.012 - ETA: 29s - loss: 4.9218 - accuracy: 0.012 - ETA: 29s - loss: 4.9209 - accuracy: 0.012 - ETA: 28s - loss: 4.9202 - accuracy: 0.012 - ETA: 28s - loss: 4.9195 - accuracy: 0.012 - ETA: 28s - loss: 4.9188 - accuracy: 0.012 - ETA: 27s - loss: 4.9179 - accuracy: 0.012 - ETA: 27s - loss: 4.9181 - accuracy: 0.012 - ETA: 27s - loss: 4.9181 - accuracy: 0.013 - ETA: 26s - loss: 4.9179 - accuracy: 0.013 - ETA: 26s - loss: 4.9179 - accuracy: 0.013 - ETA: 26s - loss: 4.9169 - accuracy: 0.013 - ETA: 26s - loss: 4.9165 - accuracy: 0.013 - ETA: 25s - loss: 4.9157 - accuracy: 0.013 - ETA: 25s - loss: 4.9148 - accuracy: 0.013 - ETA: 25s - loss: 4.9138 - accuracy: 0.014 - ETA: 24s - loss: 4.9125 - accuracy: 0.014 - ETA: 24s - loss: 4.9114 - accuracy: 0.014 - ETA: 24s - loss: 4.9100 - accuracy: 0.014 - ETA: 24s - loss: 4.9096 - accuracy: 0.014 - ETA: 23s - loss: 4.9087 - accuracy: 0.014 - ETA: 23s - loss: 4.9076 - accuracy: 0.014 - ETA: 23s - loss: 4.9066 - accuracy: 0.015 - ETA: 22s - loss: 4.9070 - accuracy: 0.015 - ETA: 22s - loss: 4.9060 - accuracy: 0.015 - ETA: 22s - loss: 4.9054 - accuracy: 0.015 - ETA: 21s - loss: 4.9046 - accuracy: 0.015 - ETA: 21s - loss: 4.9047 - accuracy: 0.015 - ETA: 21s - loss: 4.9039 - accuracy: 0.015 - ETA: 21s - loss: 4.9037 - accuracy: 0.015 - ETA: 20s - loss: 4.9035 - accuracy: 0.015 - ETA: 20s - loss: 4.9029 - accuracy: 0.015 - ETA: 20s - loss: 4.9017 - accuracy: 0.015 - ETA: 19s - loss: 4.9013 - accuracy: 0.015 - ETA: 19s - loss: 4.9011 - accuracy: 0.015 - ETA: 19s - loss: 4.9000 - accuracy: 0.015 - ETA: 18s - loss: 4.9001 - accuracy: 0.015 - ETA: 18s - loss: 4.8994 - accuracy: 0.015 - ETA: 18s - loss: 4.8989 - accuracy: 0.015 - ETA: 18s - loss: 4.8980 - accuracy: 0.015 - ETA: 17s - loss: 4.8972 - accuracy: 0.0 ...
#
# Epoch 00001: val_loss improved from inf to 4.57078, saving model to saved_models/weights.best.from_scratch.hdf5
# Epoch 2/5
# 3700/6680 [===============>..............] - ETA: 1:38 - loss: 4.7802 - accuracy: 0.0000e+ - ETA: 1:37 - loss: 4.6962 - accuracy: 0.0000e+ - ETA: 1:37 - loss: 4.6093 - accuracy: 0.0333   - ETA: 1:37 - loss: 4.5873 - accuracy: 0.03 - ETA: 1:37 - loss: 4.5963 - accuracy: 0.04 - ETA: 1:37 - loss: 4.5786 - accuracy: 0.03 - ETA: 1:37 - loss: 4.6180 - accuracy: 0.03 - ETA: 1:36 - loss: 4.6097 - accuracy: 0.03 - ETA: 1:36 - loss: 4.5873 - accuracy: 0.03 - ETA: 1:35 - loss: 4.5985 - accuracy: 0.03 - ETA: 1:35 - loss: 4.5834 - accuracy: 0.03 - ETA: 1:35 - loss: 4.5639 - accuracy: 0.03 - ETA: 1:35 - loss: 4.5359 - accuracy: 0.03 - ETA: 1:34 - loss: 4.5317 - accuracy: 0.02 - ETA: 1:34 - loss: 4.5208 - accuracy: 0.02 - ETA: 1:34 - loss: 4.5563 - accuracy: 0.02 - ETA: 1:34 - loss: 4.5576 - accuracy: 0.02 - ETA: 1:33 - loss: 4.5493 - accuracy: 0.02 - ETA: 1:33 - loss: 4.5589 - accuracy: 0.02 - ETA: 1:33 - loss: 4.5738 - accuracy: 0.02 - ETA: 1:32 - loss: 4.5647 - accuracy: 0.03 - ETA: 1:32 - loss: 4.5587 - accuracy: 0.03 - ETA: 1:32 - loss: 4.5544 - accuracy: 0.03 - ETA: 1:32 - loss: 4.5449 - accuracy: 0.03 - ETA: 1:31 - loss: 4.5535 - accuracy: 0.03 - ETA: 1:31 - loss: 4.5459 - accuracy: 0.03 - ETA: 1:31 - loss: 4.5355 - accuracy: 0.04 - ETA: 1:30 - loss: 4.5369 - accuracy: 0.03 - ETA: 1:30 - loss: 4.5345 - accuracy: 0.03 - ETA: 1:30 - loss: 4.5345 - accuracy: 0.03 - ETA: 1:30 - loss: 4.5308 - accuracy: 0.04 - ETA: 1:29 - loss: 4.5267 - accuracy: 0.04 - ETA: 1:29 - loss: 4.5239 - accuracy: 0.04 - ETA: 1:29 - loss: 4.5239 - accuracy: 0.04 - ETA: 1:28 - loss: 4.5247 - accuracy: 0.04 - ETA: 1:28 - loss: 4.5314 - accuracy: 0.04 - ETA: 1:28 - loss: 4.5291 - accuracy: 0.04 - ETA: 1:27 - loss: 4.5292 - accuracy: 0.04 - ETA: 1:27 - loss: 4.5274 - accuracy: 0.04 - ETA: 1:27 - loss: 4.5231 - accuracy: 0.04 - ETA: 1:26 - loss: 4.5183 - accuracy: 0.04 - ETA: 1:26 - loss: 4.5151 - accuracy: 0.04 - ETA: 1:26 - loss: 4.5110 - accuracy: 0.04 - ETA: 1:26 - loss: 4.5149 - accuracy: 0.04 - ETA: 1:25 - loss: 4.5173 - accuracy: 0.04 - ETA: 1:25 - loss: 4.5154 - accuracy: 0.04 - ETA: 1:25 - loss: 4.5129 - accuracy: 0.04 - ETA: 1:24 - loss: 4.5091 - accuracy: 0.04 - ETA: 1:24 - loss: 4.5040 - accuracy: 0.04 - ETA: 1:24 - loss: 4.5047 - accuracy: 0.04 - ETA: 1:23 - loss: 4.5017 - accuracy: 0.04 - ETA: 1:23 - loss: 4.4996 - accuracy: 0.04 - ETA: 1:23 - loss: 4.5030 - accuracy: 0.04 - ETA: 1:22 - loss: 4.4994 - accuracy: 0.04 - ETA: 1:22 - loss: 4.4977 - accuracy: 0.04 - ETA: 1:22 - loss: 4.4985 - accuracy: 0.04 - ETA: 1:22 - loss: 4.4946 - accuracy: 0.04 - ETA: 1:21 - loss: 4.4931 - accuracy: 0.04 - ETA: 1:21 - loss: 4.4946 - accuracy: 0.04 - ETA: 1:21 - loss: 4.4927 - accuracy: 0.04 - ETA: 1:20 - loss: 4.4921 - accuracy: 0.04 - ETA: 1:20 - loss: 4.4909 - accuracy: 0.04 - ETA: 1:20 - loss: 4.4901 - accuracy: 0.04 - ETA: 1:20 - loss: 4.4902 - accuracy: 0.04 - ETA: 1:19 - loss: 4.4889 - accuracy: 0.04 - ETA: 1:19 - loss: 4.4893 - accuracy: 0.04 - ETA: 1:19 - loss: 4.4934 - accuracy: 0.04 - ETA: 1:18 - loss: 4.4918 - accuracy: 0.04 - ETA: 1:18 - loss: 4.4922 - accuracy: 0.04 - ETA: 1:18 - loss: 4.4900 - accuracy: 0.04 - ETA: 1:17 - loss: 4.4910 - accuracy: 0.04 - ETA: 1:17 - loss: 4.4933 - accuracy: 0.04 - ETA: 1:17 - loss: 4.4924 - accuracy: 0.04 - ETA: 1:17 - loss: 4.4957 - accuracy: 0.04 - ETA: 1:16 - loss: 4.4943 - accuracy: 0.04 - ETA: 1:16 - loss: 4.4962 - accuracy: 0.04 - ETA: 1:16 - loss: 4.4972 - accuracy: 0.04 - ETA: 1:15 - loss: 4.4969 - accuracy: 0.04 - ETA: 1:15 - loss: 4.4948 - accuracy: 0.04 - ETA: 1:15 - loss: 4.4986 - accuracy: 0.04 - ETA: 1:15 - loss: 4.5003 - accuracy: 0.03 - ETA: 1:14 - loss: 4.4976 - accuracy: 0.03 - ETA: 1:14 - loss: 4.4950 - accuracy: 0.03 - ETA: 1:14 - loss: 4.4951 - accuracy: 0.03 - ETA: 1:13 - loss: 4.4970 - accuracy: 0.03 - ETA: 1:13 - loss: 4.4931 - accuracy: 0.04 - ETA: 1:13 - loss: 4.4975 - accuracy: 0.04 - ETA: 1:13 - loss: 4.5019 - accuracy: 0.04 - ETA: 1:12 - loss: 4.5010 - accuracy: 0.04 - ETA: 1:12 - loss: 4.5008 -  ...
# 6680/6680 [==============================] - ETA: 43s - loss: 4.4670 - accuracy: 0.046 - ETA: 43s - loss: 4.4680 - accuracy: 0.046 - ETA: 43s - loss: 4.4678 - accuracy: 0.046 - ETA: 43s - loss: 4.4699 - accuracy: 0.046 - ETA: 42s - loss: 4.4696 - accuracy: 0.046 - ETA: 42s - loss: 4.4700 - accuracy: 0.046 - ETA: 42s - loss: 4.4684 - accuracy: 0.047 - ETA: 41s - loss: 4.4675 - accuracy: 0.047 - ETA: 41s - loss: 4.4671 - accuracy: 0.046 - ETA: 41s - loss: 4.4675 - accuracy: 0.046 - ETA: 41s - loss: 4.4658 - accuracy: 0.047 - ETA: 40s - loss: 4.4642 - accuracy: 0.047 - ETA: 40s - loss: 4.4637 - accuracy: 0.046 - ETA: 40s - loss: 4.4648 - accuracy: 0.046 - ETA: 39s - loss: 4.4648 - accuracy: 0.046 - ETA: 39s - loss: 4.4666 - accuracy: 0.046 - ETA: 39s - loss: 4.4679 - accuracy: 0.046 - ETA: 38s - loss: 4.4674 - accuracy: 0.046 - ETA: 38s - loss: 4.4662 - accuracy: 0.047 - ETA: 38s - loss: 4.4643 - accuracy: 0.047 - ETA: 38s - loss: 4.4633 - accuracy: 0.047 - ETA: 37s - loss: 4.4634 - accuracy: 0.047 - ETA: 37s - loss: 4.4635 - accuracy: 0.047 - ETA: 37s - loss: 4.4620 - accuracy: 0.047 - ETA: 36s - loss: 4.4612 - accuracy: 0.047 - ETA: 36s - loss: 4.4617 - accuracy: 0.047 - ETA: 36s - loss: 4.4606 - accuracy: 0.047 - ETA: 35s - loss: 4.4598 - accuracy: 0.047 - ETA: 35s - loss: 4.4607 - accuracy: 0.048 - ETA: 35s - loss: 4.4598 - accuracy: 0.048 - ETA: 35s - loss: 4.4592 - accuracy: 0.047 - ETA: 34s - loss: 4.4599 - accuracy: 0.047 - ETA: 34s - loss: 4.4596 - accuracy: 0.047 - ETA: 34s - loss: 4.4591 - accuracy: 0.047 - ETA: 33s - loss: 4.4585 - accuracy: 0.048 - ETA: 33s - loss: 4.4582 - accuracy: 0.048 - ETA: 33s - loss: 4.4567 - accuracy: 0.048 - ETA: 33s - loss: 4.4573 - accuracy: 0.048 - ETA: 32s - loss: 4.4582 - accuracy: 0.048 - ETA: 32s - loss: 4.4586 - accuracy: 0.048 - ETA: 32s - loss: 4.4584 - accuracy: 0.047 - ETA: 31s - loss: 4.4589 - accuracy: 0.048 - ETA: 31s - loss: 4.4585 - accuracy: 0.048 - ETA: 31s - loss: 4.4574 - accuracy: 0.048 - ETA: 30s - loss: 4.4572 - accuracy: 0.048 - ETA: 30s - loss: 4.4583 - accuracy: 0.048 - ETA: 30s - loss: 4.4591 - accuracy: 0.048 - ETA: 30s - loss: 4.4593 - accuracy: 0.048 - ETA: 29s - loss: 4.4598 - accuracy: 0.048 - ETA: 29s - loss: 4.4594 - accuracy: 0.047 - ETA: 29s - loss: 4.4588 - accuracy: 0.047 - ETA: 28s - loss: 4.4585 - accuracy: 0.048 - ETA: 28s - loss: 4.4580 - accuracy: 0.048 - ETA: 28s - loss: 4.4561 - accuracy: 0.048 - ETA: 27s - loss: 4.4549 - accuracy: 0.048 - ETA: 27s - loss: 4.4546 - accuracy: 0.048 - ETA: 27s - loss: 4.4533 - accuracy: 0.048 - ETA: 27s - loss: 4.4528 - accuracy: 0.048 - ETA: 26s - loss: 4.4531 - accuracy: 0.048 - ETA: 26s - loss: 4.4535 - accuracy: 0.049 - ETA: 26s - loss: 4.4513 - accuracy: 0.049 - ETA: 25s - loss: 4.4490 - accuracy: 0.049 - ETA: 25s - loss: 4.4495 - accuracy: 0.049 - ETA: 25s - loss: 4.4493 - accuracy: 0.049 - ETA: 24s - loss: 4.4494 - accuracy: 0.049 - ETA: 24s - loss: 4.4481 - accuracy: 0.048 - ETA: 24s - loss: 4.4479 - accuracy: 0.049 - ETA: 24s - loss: 4.4480 - accuracy: 0.049 - ETA: 23s - loss: 4.4467 - accuracy: 0.049 - ETA: 23s - loss: 4.4478 - accuracy: 0.049 - ETA: 23s - loss: 4.4462 - accuracy: 0.049 - ETA: 22s - loss: 4.4463 - accuracy: 0.050 - ETA: 22s - loss: 4.4466 - accuracy: 0.050 - ETA: 22s - loss: 4.4476 - accuracy: 0.050 - ETA: 21s - loss: 4.4467 - accuracy: 0.050 - ETA: 21s - loss: 4.4461 - accuracy: 0.049 - ETA: 21s - loss: 4.4454 - accuracy: 0.049 - ETA: 21s - loss: 4.4456 - accuracy: 0.049 - ETA: 20s - loss: 4.4450 - accuracy: 0.049 - ETA: 20s - loss: 4.4435 - accuracy: 0.049 - ETA: 20s - loss: 4.4423 - accuracy: 0.050 - ETA: 19s - loss: 4.4407 - accuracy: 0.050 - ETA: 19s - loss: 4.4400 - accuracy: 0.050 - ETA: 19s - loss: 4.4407 - accuracy: 0.050 - ETA: 19s - loss: 4.4394 - accuracy: 0.051 - ETA: 18s - loss: 4.4375 - accuracy: 0.050 - ETA: 18s - loss: 4.4394 - accuracy: 0.050 - ETA: 18s - loss: 4.4380 - accuracy: 0.050 - ETA: 17s - loss: 4.4368 - accuracy: 0.050 - ETA: 17s - loss: 4.4366 - accuracy: 0.0 ...
#
# Epoch 00002: val_loss improved from 4.57078 to 4.26502, saving model to saved_models/weights.best.from_scratch.hdf5
# Epoch 3/5
# 3720/6680 [===============>..............] - ETA: 1:38 - loss: 4.2940 - accuracy: 0.10 - ETA: 1:37 - loss: 4.1842 - accuracy: 0.07 - ETA: 1:37 - loss: 4.0286 - accuracy: 0.08 - ETA: 1:37 - loss: 3.8734 - accuracy: 0.10 - ETA: 1:37 - loss: 3.7962 - accuracy: 0.12 - ETA: 1:37 - loss: 3.7939 - accuracy: 0.11 - ETA: 1:36 - loss: 3.7619 - accuracy: 0.13 - ETA: 1:37 - loss: 3.7939 - accuracy: 0.14 - ETA: 1:36 - loss: 3.8423 - accuracy: 0.13 - ETA: 1:36 - loss: 3.8154 - accuracy: 0.13 - ETA: 1:36 - loss: 3.8435 - accuracy: 0.12 - ETA: 1:35 - loss: 3.8763 - accuracy: 0.11 - ETA: 1:35 - loss: 3.8973 - accuracy: 0.11 - ETA: 1:35 - loss: 3.9685 - accuracy: 0.11 - ETA: 1:34 - loss: 3.9679 - accuracy: 0.11 - ETA: 1:34 - loss: 3.9739 - accuracy: 0.11 - ETA: 1:34 - loss: 3.9640 - accuracy: 0.11 - ETA: 1:33 - loss: 3.9724 - accuracy: 0.10 - ETA: 1:33 - loss: 3.9652 - accuracy: 0.10 - ETA: 1:33 - loss: 3.9493 - accuracy: 0.10 - ETA: 1:33 - loss: 3.9458 - accuracy: 0.10 - ETA: 1:32 - loss: 3.9481 - accuracy: 0.10 - ETA: 1:32 - loss: 3.9202 - accuracy: 0.11 - ETA: 1:32 - loss: 3.9110 - accuracy: 0.11 - ETA: 1:31 - loss: 3.9192 - accuracy: 0.11 - ETA: 1:31 - loss: 3.9251 - accuracy: 0.11 - ETA: 1:31 - loss: 3.9246 - accuracy: 0.11 - ETA: 1:30 - loss: 3.9255 - accuracy: 0.11 - ETA: 1:30 - loss: 3.9401 - accuracy: 0.11 - ETA: 1:30 - loss: 3.9503 - accuracy: 0.11 - ETA: 1:29 - loss: 3.9353 - accuracy: 0.11 - ETA: 1:29 - loss: 3.9213 - accuracy: 0.11 - ETA: 1:29 - loss: 3.9334 - accuracy: 0.11 - ETA: 1:29 - loss: 3.9484 - accuracy: 0.11 - ETA: 1:28 - loss: 3.9474 - accuracy: 0.11 - ETA: 1:28 - loss: 3.9496 - accuracy: 0.11 - ETA: 1:28 - loss: 3.9438 - accuracy: 0.11 - ETA: 1:27 - loss: 3.9496 - accuracy: 0.11 - ETA: 1:27 - loss: 3.9464 - accuracy: 0.11 - ETA: 1:27 - loss: 3.9431 - accuracy: 0.11 - ETA: 1:27 - loss: 3.9291 - accuracy: 0.12 - ETA: 1:26 - loss: 3.9396 - accuracy: 0.12 - ETA: 1:26 - loss: 3.9433 - accuracy: 0.11 - ETA: 1:26 - loss: 3.9459 - accuracy: 0.11 - ETA: 1:25 - loss: 3.9521 - accuracy: 0.11 - ETA: 1:25 - loss: 3.9544 - accuracy: 0.11 - ETA: 1:25 - loss: 3.9669 - accuracy: 0.11 - ETA: 1:24 - loss: 3.9606 - accuracy: 0.11 - ETA: 1:24 - loss: 3.9518 - accuracy: 0.12 - ETA: 1:24 - loss: 3.9641 - accuracy: 0.11 - ETA: 1:23 - loss: 3.9615 - accuracy: 0.11 - ETA: 1:23 - loss: 3.9602 - accuracy: 0.11 - ETA: 1:23 - loss: 3.9564 - accuracy: 0.12 - ETA: 1:22 - loss: 3.9553 - accuracy: 0.12 - ETA: 1:22 - loss: 3.9597 - accuracy: 0.12 - ETA: 1:22 - loss: 3.9641 - accuracy: 0.12 - ETA: 1:22 - loss: 3.9638 - accuracy: 0.12 - ETA: 1:21 - loss: 3.9607 - accuracy: 0.12 - ETA: 1:21 - loss: 3.9586 - accuracy: 0.12 - ETA: 1:21 - loss: 3.9548 - accuracy: 0.12 - ETA: 1:20 - loss: 3.9562 - accuracy: 0.12 - ETA: 1:20 - loss: 3.9540 - accuracy: 0.12 - ETA: 1:20 - loss: 3.9515 - accuracy: 0.12 - ETA: 1:19 - loss: 3.9479 - accuracy: 0.12 - ETA: 1:19 - loss: 3.9524 - accuracy: 0.12 - ETA: 1:19 - loss: 3.9504 - accuracy: 0.12 - ETA: 1:19 - loss: 3.9440 - accuracy: 0.12 - ETA: 1:18 - loss: 3.9431 - accuracy: 0.12 - ETA: 1:18 - loss: 3.9458 - accuracy: 0.12 - ETA: 1:18 - loss: 3.9432 - accuracy: 0.12 - ETA: 1:17 - loss: 3.9438 - accuracy: 0.12 - ETA: 1:17 - loss: 3.9406 - accuracy: 0.12 - ETA: 1:17 - loss: 3.9408 - accuracy: 0.12 - ETA: 1:17 - loss: 3.9473 - accuracy: 0.12 - ETA: 1:16 - loss: 3.9466 - accuracy: 0.12 - ETA: 1:16 - loss: 3.9401 - accuracy: 0.12 - ETA: 1:16 - loss: 3.9359 - accuracy: 0.12 - ETA: 1:15 - loss: 3.9342 - accuracy: 0.12 - ETA: 1:15 - loss: 3.9320 - accuracy: 0.12 - ETA: 1:15 - loss: 3.9364 - accuracy: 0.12 - ETA: 1:14 - loss: 3.9362 - accuracy: 0.12 - ETA: 1:14 - loss: 3.9341 - accuracy: 0.12 - ETA: 1:14 - loss: 3.9294 - accuracy: 0.12 - ETA: 1:14 - loss: 3.9270 - accuracy: 0.12 - ETA: 1:13 - loss: 3.9272 - accuracy: 0.12 - ETA: 1:13 - loss: 3.9276 - accuracy: 0.12 - ETA: 1:13 - loss: 3.9279 - accuracy: 0.12 - ETA: 1:12 - loss: 3.9284 - accuracy: 0.12 - ETA: 1:12 - loss: 3.9268 - accuracy: 0.12 - ETA: 1:12 - loss: 3.9253 - accuracy: 0. ...
# 6680/6680 [==============================] - ETA: 43s - loss: 3.9026 - accuracy: 0.126 - ETA: 43s - loss: 3.9024 - accuracy: 0.126 - ETA: 43s - loss: 3.9021 - accuracy: 0.126 - ETA: 42s - loss: 3.8996 - accuracy: 0.126 - ETA: 42s - loss: 3.8969 - accuracy: 0.127 - ETA: 42s - loss: 3.8965 - accuracy: 0.127 - ETA: 42s - loss: 3.8951 - accuracy: 0.127 - ETA: 41s - loss: 3.8972 - accuracy: 0.127 - ETA: 41s - loss: 3.8964 - accuracy: 0.127 - ETA: 41s - loss: 3.8963 - accuracy: 0.127 - ETA: 40s - loss: 3.8950 - accuracy: 0.128 - ETA: 40s - loss: 3.8937 - accuracy: 0.129 - ETA: 40s - loss: 3.8931 - accuracy: 0.129 - ETA: 39s - loss: 3.8932 - accuracy: 0.129 - ETA: 39s - loss: 3.8909 - accuracy: 0.129 - ETA: 39s - loss: 3.8908 - accuracy: 0.129 - ETA: 39s - loss: 3.8883 - accuracy: 0.129 - ETA: 38s - loss: 3.8862 - accuracy: 0.130 - ETA: 38s - loss: 3.8859 - accuracy: 0.130 - ETA: 38s - loss: 3.8843 - accuracy: 0.130 - ETA: 37s - loss: 3.8838 - accuracy: 0.130 - ETA: 37s - loss: 3.8818 - accuracy: 0.130 - ETA: 37s - loss: 3.8827 - accuracy: 0.130 - ETA: 36s - loss: 3.8836 - accuracy: 0.130 - ETA: 36s - loss: 3.8830 - accuracy: 0.130 - ETA: 36s - loss: 3.8823 - accuracy: 0.130 - ETA: 36s - loss: 3.8794 - accuracy: 0.130 - ETA: 35s - loss: 3.8801 - accuracy: 0.130 - ETA: 35s - loss: 3.8773 - accuracy: 0.131 - ETA: 35s - loss: 3.8782 - accuracy: 0.131 - ETA: 34s - loss: 3.8792 - accuracy: 0.131 - ETA: 34s - loss: 3.8779 - accuracy: 0.131 - ETA: 34s - loss: 3.8791 - accuracy: 0.131 - ETA: 34s - loss: 3.8796 - accuracy: 0.131 - ETA: 33s - loss: 3.8793 - accuracy: 0.131 - ETA: 33s - loss: 3.8796 - accuracy: 0.131 - ETA: 33s - loss: 3.8804 - accuracy: 0.131 - ETA: 32s - loss: 3.8822 - accuracy: 0.130 - ETA: 32s - loss: 3.8813 - accuracy: 0.130 - ETA: 32s - loss: 3.8790 - accuracy: 0.130 - ETA: 31s - loss: 3.8799 - accuracy: 0.130 - ETA: 31s - loss: 3.8814 - accuracy: 0.130 - ETA: 31s - loss: 3.8820 - accuracy: 0.130 - ETA: 31s - loss: 3.8823 - accuracy: 0.130 - ETA: 30s - loss: 3.8827 - accuracy: 0.130 - ETA: 30s - loss: 3.8821 - accuracy: 0.130 - ETA: 30s - loss: 3.8815 - accuracy: 0.130 - ETA: 29s - loss: 3.8794 - accuracy: 0.130 - ETA: 29s - loss: 3.8795 - accuracy: 0.130 - ETA: 29s - loss: 3.8765 - accuracy: 0.130 - ETA: 28s - loss: 3.8767 - accuracy: 0.131 - ETA: 28s - loss: 3.8765 - accuracy: 0.130 - ETA: 28s - loss: 3.8771 - accuracy: 0.130 - ETA: 28s - loss: 3.8749 - accuracy: 0.130 - ETA: 27s - loss: 3.8723 - accuracy: 0.131 - ETA: 27s - loss: 3.8734 - accuracy: 0.130 - ETA: 27s - loss: 3.8769 - accuracy: 0.130 - ETA: 26s - loss: 3.8749 - accuracy: 0.130 - ETA: 26s - loss: 3.8756 - accuracy: 0.130 - ETA: 26s - loss: 3.8757 - accuracy: 0.130 - ETA: 25s - loss: 3.8765 - accuracy: 0.130 - ETA: 25s - loss: 3.8774 - accuracy: 0.130 - ETA: 25s - loss: 3.8754 - accuracy: 0.130 - ETA: 25s - loss: 3.8762 - accuracy: 0.130 - ETA: 24s - loss: 3.8763 - accuracy: 0.130 - ETA: 24s - loss: 3.8788 - accuracy: 0.130 - ETA: 24s - loss: 3.8776 - accuracy: 0.131 - ETA: 23s - loss: 3.8759 - accuracy: 0.130 - ETA: 23s - loss: 3.8764 - accuracy: 0.130 - ETA: 23s - loss: 3.8748 - accuracy: 0.131 - ETA: 22s - loss: 3.8742 - accuracy: 0.131 - ETA: 22s - loss: 3.8744 - accuracy: 0.131 - ETA: 22s - loss: 3.8739 - accuracy: 0.131 - ETA: 22s - loss: 3.8732 - accuracy: 0.131 - ETA: 21s - loss: 3.8734 - accuracy: 0.131 - ETA: 21s - loss: 3.8754 - accuracy: 0.130 - ETA: 21s - loss: 3.8754 - accuracy: 0.130 - ETA: 20s - loss: 3.8737 - accuracy: 0.130 - ETA: 20s - loss: 3.8738 - accuracy: 0.129 - ETA: 20s - loss: 3.8743 - accuracy: 0.129 - ETA: 19s - loss: 3.8738 - accuracy: 0.129 - ETA: 19s - loss: 3.8729 - accuracy: 0.129 - ETA: 19s - loss: 3.8713 - accuracy: 0.129 - ETA: 19s - loss: 3.8710 - accuracy: 0.129 - ETA: 18s - loss: 3.8703 - accuracy: 0.129 - ETA: 18s - loss: 3.8687 - accuracy: 0.130 - ETA: 18s - loss: 3.8682 - accuracy: 0.129 - ETA: 17s - loss: 3.8666 - accuracy: 0.129 - ETA: 17s - loss: 3.8703 - accuracy: 0.129 - ETA: 17s - loss: 3.8720 - accuracy: 0.1 ...
#
# Epoch 00003: val_loss improved from 4.26502 to 4.16603, saving model to saved_models/weights.best.from_scratch.hdf5
# Epoch 4/5
# 3720/6680 [===============>..............] - ETA: 1:35 - loss: 3.2319 - accuracy: 0.35 - ETA: 1:36 - loss: 3.2640 - accuracy: 0.32 - ETA: 1:38 - loss: 3.2596 - accuracy: 0.30 - ETA: 1:38 - loss: 3.2459 - accuracy: 0.26 - ETA: 1:37 - loss: 3.2066 - accuracy: 0.26 - ETA: 1:37 - loss: 3.2193 - accuracy: 0.25 - ETA: 1:37 - loss: 3.1840 - accuracy: 0.26 - ETA: 1:37 - loss: 3.1634 - accuracy: 0.25 - ETA: 1:36 - loss: 3.1016 - accuracy: 0.26 - ETA: 1:36 - loss: 3.1171 - accuracy: 0.25 - ETA: 1:36 - loss: 3.1174 - accuracy: 0.25 - ETA: 1:36 - loss: 3.1157 - accuracy: 0.25 - ETA: 1:35 - loss: 3.1319 - accuracy: 0.25 - ETA: 1:35 - loss: 3.0848 - accuracy: 0.26 - ETA: 1:35 - loss: 3.0881 - accuracy: 0.26 - ETA: 1:35 - loss: 3.0507 - accuracy: 0.27 - ETA: 1:34 - loss: 3.0674 - accuracy: 0.27 - ETA: 1:34 - loss: 3.0890 - accuracy: 0.26 - ETA: 1:34 - loss: 3.0846 - accuracy: 0.27 - ETA: 1:33 - loss: 3.0803 - accuracy: 0.27 - ETA: 1:33 - loss: 3.1059 - accuracy: 0.27 - ETA: 1:33 - loss: 3.0738 - accuracy: 0.27 - ETA: 1:32 - loss: 3.0868 - accuracy: 0.27 - ETA: 1:32 - loss: 3.0756 - accuracy: 0.28 - ETA: 1:32 - loss: 3.0755 - accuracy: 0.28 - ETA: 1:31 - loss: 3.0874 - accuracy: 0.27 - ETA: 1:31 - loss: 3.1018 - accuracy: 0.27 - ETA: 1:31 - loss: 3.0936 - accuracy: 0.27 - ETA: 1:31 - loss: 3.1089 - accuracy: 0.27 - ETA: 1:30 - loss: 3.1182 - accuracy: 0.26 - ETA: 1:30 - loss: 3.1191 - accuracy: 0.27 - ETA: 1:30 - loss: 3.1124 - accuracy: 0.27 - ETA: 1:29 - loss: 3.1196 - accuracy: 0.26 - ETA: 1:29 - loss: 3.1284 - accuracy: 0.27 - ETA: 1:29 - loss: 3.1418 - accuracy: 0.26 - ETA: 1:28 - loss: 3.1284 - accuracy: 0.26 - ETA: 1:28 - loss: 3.1175 - accuracy: 0.27 - ETA: 1:28 - loss: 3.1373 - accuracy: 0.26 - ETA: 1:28 - loss: 3.1438 - accuracy: 0.27 - ETA: 1:27 - loss: 3.1478 - accuracy: 0.27 - ETA: 1:27 - loss: 3.1504 - accuracy: 0.26 - ETA: 1:27 - loss: 3.1365 - accuracy: 0.26 - ETA: 1:26 - loss: 3.1365 - accuracy: 0.26 - ETA: 1:26 - loss: 3.1299 - accuracy: 0.27 - ETA: 1:26 - loss: 3.1325 - accuracy: 0.27 - ETA: 1:25 - loss: 3.1299 - accuracy: 0.27 - ETA: 1:25 - loss: 3.1362 - accuracy: 0.26 - ETA: 1:25 - loss: 3.1397 - accuracy: 0.26 - ETA: 1:25 - loss: 3.1463 - accuracy: 0.26 - ETA: 1:24 - loss: 3.1312 - accuracy: 0.26 - ETA: 1:24 - loss: 3.1190 - accuracy: 0.27 - ETA: 1:24 - loss: 3.1150 - accuracy: 0.26 - ETA: 1:23 - loss: 3.1151 - accuracy: 0.26 - ETA: 1:23 - loss: 3.1073 - accuracy: 0.26 - ETA: 1:23 - loss: 3.0977 - accuracy: 0.26 - ETA: 1:22 - loss: 3.0907 - accuracy: 0.26 - ETA: 1:22 - loss: 3.0900 - accuracy: 0.26 - ETA: 1:22 - loss: 3.0827 - accuracy: 0.26 - ETA: 1:22 - loss: 3.0811 - accuracy: 0.27 - ETA: 1:21 - loss: 3.0713 - accuracy: 0.27 - ETA: 1:21 - loss: 3.0694 - accuracy: 0.27 - ETA: 1:21 - loss: 3.0714 - accuracy: 0.27 - ETA: 1:21 - loss: 3.0888 - accuracy: 0.27 - ETA: 1:20 - loss: 3.0873 - accuracy: 0.27 - ETA: 1:20 - loss: 3.0863 - accuracy: 0.27 - ETA: 1:20 - loss: 3.0921 - accuracy: 0.26 - ETA: 1:19 - loss: 3.0884 - accuracy: 0.27 - ETA: 1:19 - loss: 3.0859 - accuracy: 0.26 - ETA: 1:19 - loss: 3.0906 - accuracy: 0.27 - ETA: 1:18 - loss: 3.0870 - accuracy: 0.27 - ETA: 1:18 - loss: 3.0959 - accuracy: 0.27 - ETA: 1:18 - loss: 3.0882 - accuracy: 0.27 - ETA: 1:17 - loss: 3.0895 - accuracy: 0.26 - ETA: 1:17 - loss: 3.0843 - accuracy: 0.27 - ETA: 1:17 - loss: 3.0865 - accuracy: 0.27 - ETA: 1:17 - loss: 3.0889 - accuracy: 0.27 - ETA: 1:16 - loss: 3.0886 - accuracy: 0.27 - ETA: 1:16 - loss: 3.0877 - accuracy: 0.27 - ETA: 1:16 - loss: 3.0824 - accuracy: 0.26 - ETA: 1:15 - loss: 3.0781 - accuracy: 0.27 - ETA: 1:15 - loss: 3.0874 - accuracy: 0.26 - ETA: 1:15 - loss: 3.0883 - accuracy: 0.27 - ETA: 1:14 - loss: 3.0858 - accuracy: 0.27 - ETA: 1:14 - loss: 3.0852 - accuracy: 0.27 - ETA: 1:14 - loss: 3.0752 - accuracy: 0.27 - ETA: 1:14 - loss: 3.0777 - accuracy: 0.27 - ETA: 1:13 - loss: 3.0754 - accuracy: 0.27 - ETA: 1:13 - loss: 3.0779 - accuracy: 0.27 - ETA: 1:13 - loss: 3.0720 - accuracy: 0.27 - ETA: 1:12 - loss: 3.0718 - accuracy: 0. ...
# 6680/6680 [==============================] - ETA: 43s - loss: 3.0617 - accuracy: 0.271 - ETA: 43s - loss: 3.0595 - accuracy: 0.272 - ETA: 43s - loss: 3.0593 - accuracy: 0.272 - ETA: 42s - loss: 3.0560 - accuracy: 0.272 - ETA: 42s - loss: 3.0535 - accuracy: 0.272 - ETA: 42s - loss: 3.0514 - accuracy: 0.273 - ETA: 42s - loss: 3.0526 - accuracy: 0.273 - ETA: 41s - loss: 3.0514 - accuracy: 0.273 - ETA: 41s - loss: 3.0532 - accuracy: 0.273 - ETA: 41s - loss: 3.0541 - accuracy: 0.273 - ETA: 40s - loss: 3.0526 - accuracy: 0.273 - ETA: 40s - loss: 3.0532 - accuracy: 0.273 - ETA: 40s - loss: 3.0549 - accuracy: 0.272 - ETA: 39s - loss: 3.0550 - accuracy: 0.273 - ETA: 39s - loss: 3.0546 - accuracy: 0.273 - ETA: 39s - loss: 3.0552 - accuracy: 0.273 - ETA: 39s - loss: 3.0559 - accuracy: 0.273 - ETA: 38s - loss: 3.0546 - accuracy: 0.273 - ETA: 38s - loss: 3.0545 - accuracy: 0.273 - ETA: 38s - loss: 3.0537 - accuracy: 0.273 - ETA: 37s - loss: 3.0548 - accuracy: 0.273 - ETA: 37s - loss: 3.0538 - accuracy: 0.273 - ETA: 37s - loss: 3.0539 - accuracy: 0.273 - ETA: 36s - loss: 3.0536 - accuracy: 0.272 - ETA: 36s - loss: 3.0526 - accuracy: 0.272 - ETA: 36s - loss: 3.0517 - accuracy: 0.272 - ETA: 36s - loss: 3.0495 - accuracy: 0.272 - ETA: 35s - loss: 3.0506 - accuracy: 0.272 - ETA: 35s - loss: 3.0504 - accuracy: 0.273 - ETA: 35s - loss: 3.0474 - accuracy: 0.273 - ETA: 34s - loss: 3.0477 - accuracy: 0.274 - ETA: 34s - loss: 3.0444 - accuracy: 0.274 - ETA: 34s - loss: 3.0456 - accuracy: 0.274 - ETA: 33s - loss: 3.0422 - accuracy: 0.275 - ETA: 33s - loss: 3.0432 - accuracy: 0.274 - ETA: 33s - loss: 3.0416 - accuracy: 0.275 - ETA: 33s - loss: 3.0472 - accuracy: 0.274 - ETA: 32s - loss: 3.0445 - accuracy: 0.275 - ETA: 32s - loss: 3.0441 - accuracy: 0.274 - ETA: 32s - loss: 3.0443 - accuracy: 0.275 - ETA: 31s - loss: 3.0439 - accuracy: 0.275 - ETA: 31s - loss: 3.0453 - accuracy: 0.275 - ETA: 31s - loss: 3.0461 - accuracy: 0.275 - ETA: 30s - loss: 3.0457 - accuracy: 0.276 - ETA: 30s - loss: 3.0465 - accuracy: 0.276 - ETA: 30s - loss: 3.0471 - accuracy: 0.275 - ETA: 30s - loss: 3.0480 - accuracy: 0.275 - ETA: 29s - loss: 3.0482 - accuracy: 0.275 - ETA: 29s - loss: 3.0471 - accuracy: 0.275 - ETA: 29s - loss: 3.0479 - accuracy: 0.275 - ETA: 28s - loss: 3.0469 - accuracy: 0.276 - ETA: 28s - loss: 3.0453 - accuracy: 0.276 - ETA: 28s - loss: 3.0430 - accuracy: 0.276 - ETA: 27s - loss: 3.0418 - accuracy: 0.276 - ETA: 27s - loss: 3.0432 - accuracy: 0.276 - ETA: 27s - loss: 3.0443 - accuracy: 0.276 - ETA: 27s - loss: 3.0404 - accuracy: 0.276 - ETA: 26s - loss: 3.0404 - accuracy: 0.276 - ETA: 26s - loss: 3.0454 - accuracy: 0.276 - ETA: 26s - loss: 3.0449 - accuracy: 0.276 - ETA: 25s - loss: 3.0470 - accuracy: 0.275 - ETA: 25s - loss: 3.0473 - accuracy: 0.275 - ETA: 25s - loss: 3.0474 - accuracy: 0.276 - ETA: 24s - loss: 3.0478 - accuracy: 0.276 - ETA: 24s - loss: 3.0450 - accuracy: 0.276 - ETA: 24s - loss: 3.0478 - accuracy: 0.276 - ETA: 24s - loss: 3.0461 - accuracy: 0.277 - ETA: 23s - loss: 3.0475 - accuracy: 0.277 - ETA: 23s - loss: 3.0483 - accuracy: 0.277 - ETA: 23s - loss: 3.0478 - accuracy: 0.277 - ETA: 22s - loss: 3.0489 - accuracy: 0.276 - ETA: 22s - loss: 3.0469 - accuracy: 0.277 - ETA: 22s - loss: 3.0452 - accuracy: 0.277 - ETA: 22s - loss: 3.0428 - accuracy: 0.277 - ETA: 21s - loss: 3.0423 - accuracy: 0.277 - ETA: 21s - loss: 3.0453 - accuracy: 0.276 - ETA: 21s - loss: 3.0460 - accuracy: 0.276 - ETA: 20s - loss: 3.0449 - accuracy: 0.277 - ETA: 20s - loss: 3.0432 - accuracy: 0.278 - ETA: 20s - loss: 3.0425 - accuracy: 0.277 - ETA: 19s - loss: 3.0430 - accuracy: 0.277 - ETA: 19s - loss: 3.0415 - accuracy: 0.278 - ETA: 19s - loss: 3.0424 - accuracy: 0.278 - ETA: 19s - loss: 3.0429 - accuracy: 0.278 - ETA: 18s - loss: 3.0420 - accuracy: 0.278 - ETA: 18s - loss: 3.0421 - accuracy: 0.278 - ETA: 18s - loss: 3.0420 - accuracy: 0.278 - ETA: 17s - loss: 3.0405 - accuracy: 0.278 - ETA: 17s - loss: 3.0386 - accuracy: 0.278 - ETA: 17s - loss: 3.0395 - accuracy: 0.2 ...
#
# Epoch 00004: val_loss did not improve from 4.16603
# Epoch 5/5
# 3720/6680 [===============>..............] - ETA: 1:37 - loss: 2.1083 - accuracy: 0.60 - ETA: 1:37 - loss: 2.2373 - accuracy: 0.52 - ETA: 1:36 - loss: 2.2057 - accuracy: 0.48 - ETA: 1:37 - loss: 2.0264 - accuracy: 0.52 - ETA: 1:37 - loss: 2.0578 - accuracy: 0.51 - ETA: 1:37 - loss: 2.1258 - accuracy: 0.47 - ETA: 1:37 - loss: 2.2102 - accuracy: 0.45 - ETA: 1:36 - loss: 2.1981 - accuracy: 0.46 - ETA: 1:36 - loss: 2.1633 - accuracy: 0.48 - ETA: 1:36 - loss: 2.1762 - accuracy: 0.49 - ETA: 1:36 - loss: 2.1825 - accuracy: 0.48 - ETA: 1:36 - loss: 2.1738 - accuracy: 0.48 - ETA: 1:35 - loss: 2.1431 - accuracy: 0.49 - ETA: 1:35 - loss: 2.1328 - accuracy: 0.48 - ETA: 1:35 - loss: 2.1569 - accuracy: 0.48 - ETA: 1:35 - loss: 2.1260 - accuracy: 0.48 - ETA: 1:35 - loss: 2.1033 - accuracy: 0.48 - ETA: 1:35 - loss: 2.1070 - accuracy: 0.48 - ETA: 1:34 - loss: 2.1097 - accuracy: 0.48 - ETA: 1:34 - loss: 2.0820 - accuracy: 0.49 - ETA: 1:34 - loss: 2.0782 - accuracy: 0.49 - ETA: 1:34 - loss: 2.0765 - accuracy: 0.49 - ETA: 1:33 - loss: 2.0393 - accuracy: 0.50 - ETA: 1:33 - loss: 2.0494 - accuracy: 0.49 - ETA: 1:33 - loss: 2.0418 - accuracy: 0.50 - ETA: 1:32 - loss: 2.0195 - accuracy: 0.50 - ETA: 1:32 - loss: 2.0004 - accuracy: 0.51 - ETA: 1:32 - loss: 2.0215 - accuracy: 0.50 - ETA: 1:31 - loss: 2.0405 - accuracy: 0.50 - ETA: 1:31 - loss: 2.0439 - accuracy: 0.49 - ETA: 1:31 - loss: 2.0310 - accuracy: 0.49 - ETA: 1:30 - loss: 2.0471 - accuracy: 0.49 - ETA: 1:30 - loss: 2.0313 - accuracy: 0.50 - ETA: 1:30 - loss: 2.0185 - accuracy: 0.50 - ETA: 1:29 - loss: 2.0211 - accuracy: 0.50 - ETA: 1:29 - loss: 2.0136 - accuracy: 0.50 - ETA: 1:29 - loss: 2.0140 - accuracy: 0.50 - ETA: 1:28 - loss: 2.0013 - accuracy: 0.50 - ETA: 1:28 - loss: 2.0068 - accuracy: 0.50 - ETA: 1:28 - loss: 2.0190 - accuracy: 0.50 - ETA: 1:27 - loss: 2.0185 - accuracy: 0.50 - ETA: 1:27 - loss: 2.0055 - accuracy: 0.50 - ETA: 1:27 - loss: 1.9979 - accuracy: 0.50 - ETA: 1:26 - loss: 2.0009 - accuracy: 0.50 - ETA: 1:26 - loss: 1.9988 - accuracy: 0.50 - ETA: 1:26 - loss: 1.9957 - accuracy: 0.50 - ETA: 1:25 - loss: 1.9968 - accuracy: 0.50 - ETA: 1:25 - loss: 1.9911 - accuracy: 0.50 - ETA: 1:25 - loss: 1.9759 - accuracy: 0.51 - ETA: 1:25 - loss: 1.9613 - accuracy: 0.51 - ETA: 1:24 - loss: 1.9515 - accuracy: 0.51 - ETA: 1:24 - loss: 1.9427 - accuracy: 0.52 - ETA: 1:24 - loss: 1.9562 - accuracy: 0.52 - ETA: 1:23 - loss: 1.9589 - accuracy: 0.51 - ETA: 1:23 - loss: 1.9522 - accuracy: 0.51 - ETA: 1:23 - loss: 1.9523 - accuracy: 0.52 - ETA: 1:22 - loss: 1.9428 - accuracy: 0.52 - ETA: 1:22 - loss: 1.9400 - accuracy: 0.52 - ETA: 1:22 - loss: 1.9260 - accuracy: 0.52 - ETA: 1:22 - loss: 1.9300 - accuracy: 0.52 - ETA: 1:21 - loss: 1.9279 - accuracy: 0.52 - ETA: 1:21 - loss: 1.9298 - accuracy: 0.52 - ETA: 1:21 - loss: 1.9323 - accuracy: 0.52 - ETA: 1:20 - loss: 1.9295 - accuracy: 0.52 - ETA: 1:20 - loss: 1.9274 - accuracy: 0.52 - ETA: 1:20 - loss: 1.9412 - accuracy: 0.52 - ETA: 1:19 - loss: 1.9417 - accuracy: 0.52 - ETA: 1:19 - loss: 1.9411 - accuracy: 0.51 - ETA: 1:19 - loss: 1.9429 - accuracy: 0.51 - ETA: 1:18 - loss: 1.9465 - accuracy: 0.51 - ETA: 1:18 - loss: 1.9450 - accuracy: 0.51 - ETA: 1:18 - loss: 1.9430 - accuracy: 0.51 - ETA: 1:17 - loss: 1.9563 - accuracy: 0.51 - ETA: 1:17 - loss: 1.9582 - accuracy: 0.51 - ETA: 1:17 - loss: 1.9520 - accuracy: 0.51 - ETA: 1:17 - loss: 1.9513 - accuracy: 0.51 - ETA: 1:16 - loss: 1.9454 - accuracy: 0.52 - ETA: 1:16 - loss: 1.9477 - accuracy: 0.52 - ETA: 1:16 - loss: 1.9515 - accuracy: 0.51 - ETA: 1:15 - loss: 1.9557 - accuracy: 0.51 - ETA: 1:15 - loss: 1.9560 - accuracy: 0.51 - ETA: 1:15 - loss: 1.9599 - accuracy: 0.51 - ETA: 1:14 - loss: 1.9600 - accuracy: 0.51 - ETA: 1:14 - loss: 1.9567 - accuracy: 0.51 - ETA: 1:14 - loss: 1.9540 - accuracy: 0.51 - ETA: 1:13 - loss: 1.9511 - accuracy: 0.51 - ETA: 1:13 - loss: 1.9394 - accuracy: 0.52 - ETA: 1:13 - loss: 1.9335 - accuracy: 0.52 - ETA: 1:13 - loss: 1.9301 - accuracy: 0.52 - ETA: 1:12 - loss: 1.9257 - accuracy: 0. ...
# 6680/6680 [==============================] - ETA: 43s - loss: 1.9384 - accuracy: 0.517 - ETA: 43s - loss: 1.9385 - accuracy: 0.517 - ETA: 43s - loss: 1.9392 - accuracy: 0.516 - ETA: 42s - loss: 1.9415 - accuracy: 0.515 - ETA: 42s - loss: 1.9431 - accuracy: 0.514 - ETA: 42s - loss: 1.9436 - accuracy: 0.514 - ETA: 41s - loss: 1.9429 - accuracy: 0.515 - ETA: 41s - loss: 1.9420 - accuracy: 0.515 - ETA: 41s - loss: 1.9377 - accuracy: 0.516 - ETA: 41s - loss: 1.9368 - accuracy: 0.517 - ETA: 40s - loss: 1.9356 - accuracy: 0.517 - ETA: 40s - loss: 1.9353 - accuracy: 0.517 - ETA: 40s - loss: 1.9417 - accuracy: 0.516 - ETA: 39s - loss: 1.9461 - accuracy: 0.515 - ETA: 39s - loss: 1.9484 - accuracy: 0.515 - ETA: 39s - loss: 1.9514 - accuracy: 0.514 - ETA: 38s - loss: 1.9521 - accuracy: 0.514 - ETA: 38s - loss: 1.9535 - accuracy: 0.514 - ETA: 38s - loss: 1.9516 - accuracy: 0.515 - ETA: 38s - loss: 1.9502 - accuracy: 0.515 - ETA: 37s - loss: 1.9479 - accuracy: 0.515 - ETA: 37s - loss: 1.9499 - accuracy: 0.515 - ETA: 37s - loss: 1.9482 - accuracy: 0.516 - ETA: 36s - loss: 1.9483 - accuracy: 0.516 - ETA: 36s - loss: 1.9479 - accuracy: 0.515 - ETA: 36s - loss: 1.9473 - accuracy: 0.515 - ETA: 35s - loss: 1.9443 - accuracy: 0.516 - ETA: 35s - loss: 1.9472 - accuracy: 0.516 - ETA: 35s - loss: 1.9470 - accuracy: 0.516 - ETA: 35s - loss: 1.9475 - accuracy: 0.516 - ETA: 34s - loss: 1.9462 - accuracy: 0.516 - ETA: 34s - loss: 1.9441 - accuracy: 0.517 - ETA: 34s - loss: 1.9433 - accuracy: 0.517 - ETA: 33s - loss: 1.9441 - accuracy: 0.516 - ETA: 33s - loss: 1.9439 - accuracy: 0.516 - ETA: 33s - loss: 1.9461 - accuracy: 0.516 - ETA: 32s - loss: 1.9474 - accuracy: 0.515 - ETA: 32s - loss: 1.9453 - accuracy: 0.516 - ETA: 32s - loss: 1.9461 - accuracy: 0.516 - ETA: 32s - loss: 1.9490 - accuracy: 0.516 - ETA: 31s - loss: 1.9508 - accuracy: 0.517 - ETA: 31s - loss: 1.9522 - accuracy: 0.516 - ETA: 31s - loss: 1.9493 - accuracy: 0.517 - ETA: 30s - loss: 1.9471 - accuracy: 0.517 - ETA: 30s - loss: 1.9469 - accuracy: 0.517 - ETA: 30s - loss: 1.9451 - accuracy: 0.518 - ETA: 30s - loss: 1.9445 - accuracy: 0.518 - ETA: 29s - loss: 1.9422 - accuracy: 0.519 - ETA: 29s - loss: 1.9435 - accuracy: 0.518 - ETA: 29s - loss: 1.9422 - accuracy: 0.518 - ETA: 28s - loss: 1.9400 - accuracy: 0.519 - ETA: 28s - loss: 1.9408 - accuracy: 0.518 - ETA: 28s - loss: 1.9430 - accuracy: 0.518 - ETA: 27s - loss: 1.9414 - accuracy: 0.518 - ETA: 27s - loss: 1.9437 - accuracy: 0.518 - ETA: 27s - loss: 1.9415 - accuracy: 0.518 - ETA: 27s - loss: 1.9433 - accuracy: 0.518 - ETA: 26s - loss: 1.9449 - accuracy: 0.517 - ETA: 26s - loss: 1.9461 - accuracy: 0.517 - ETA: 26s - loss: 1.9469 - accuracy: 0.517 - ETA: 25s - loss: 1.9463 - accuracy: 0.517 - ETA: 25s - loss: 1.9462 - accuracy: 0.518 - ETA: 25s - loss: 1.9464 - accuracy: 0.517 - ETA: 24s - loss: 1.9434 - accuracy: 0.518 - ETA: 24s - loss: 1.9400 - accuracy: 0.519 - ETA: 24s - loss: 1.9386 - accuracy: 0.520 - ETA: 24s - loss: 1.9418 - accuracy: 0.519 - ETA: 23s - loss: 1.9415 - accuracy: 0.519 - ETA: 23s - loss: 1.9411 - accuracy: 0.519 - ETA: 23s - loss: 1.9417 - accuracy: 0.519 - ETA: 22s - loss: 1.9437 - accuracy: 0.519 - ETA: 22s - loss: 1.9439 - accuracy: 0.519 - ETA: 22s - loss: 1.9458 - accuracy: 0.519 - ETA: 21s - loss: 1.9455 - accuracy: 0.519 - ETA: 21s - loss: 1.9451 - accuracy: 0.520 - ETA: 21s - loss: 1.9450 - accuracy: 0.520 - ETA: 21s - loss: 1.9461 - accuracy: 0.519 - ETA: 20s - loss: 1.9492 - accuracy: 0.518 - ETA: 20s - loss: 1.9512 - accuracy: 0.518 - ETA: 20s - loss: 1.9500 - accuracy: 0.518 - ETA: 19s - loss: 1.9502 - accuracy: 0.518 - ETA: 19s - loss: 1.9488 - accuracy: 0.518 - ETA: 19s - loss: 1.9490 - accuracy: 0.517 - ETA: 19s - loss: 1.9498 - accuracy: 0.517 - ETA: 18s - loss: 1.9466 - accuracy: 0.517 - ETA: 18s - loss: 1.9488 - accuracy: 0.516 - ETA: 18s - loss: 1.9491 - accuracy: 0.516 - ETA: 17s - loss: 1.9488 - accuracy: 0.516 - ETA: 17s - loss: 1.9513 - accuracy: 0.516 - ETA: 17s - loss: 1.9513 - accuracy: 0.5 ...
#
# Epoch 00005: val_loss did not improve from 4.16603

# %% [markdown]
# ### Load the Model with the Best Validation Loss

# %%
model.load_weights('saved_models/weights.best.from_scratch.hdf5')

# %% [markdown]
# ### Test the Model
#
# Try out your model on the test dataset of dog images.  Ensure that your test accuracy is greater than 1%.

# %%
# get index of predicted dog breed for each image in test set
dog_breed_predictions = [np.argmax(model.predict(np.expand_dims(tensor, axis=0))) for tensor in test_tensors]

# report test accuracy
test_accuracy = 100*np.sum(np.array(dog_breed_predictions)==np.argmax(test_targets, axis=1))/len(dog_breed_predictions)
print('Test accuracy: %.4f%%' % test_accuracy)
# Out:
# Test accuracy: 8.7321%

# %% [markdown]
# ---
# <a id='step4'></a>
# ## Step 4: Use a CNN to Classify Dog Breeds
#
# To reduce training time without sacrificing accuracy, we show you how to train a CNN using transfer learning.  In the following step, you will get a chance to use transfer learning to train your own CNN.
#
# ### Obtain Bottleneck Features

# %%
bottleneck_features = np.load('bottleneck_features/DogVGG16Data.npz')
train_VGG16 = bottleneck_features['train']
valid_VGG16 = bottleneck_features['valid']
test_VGG16 = bottleneck_features['test']

# %% [markdown]
# ### Model Architecture
#
# The model uses the the pre-trained VGG-16 model as a fixed feature extractor, where the last convolutional output of VGG-16 is fed as input to our model.  We only add a global average pooling layer and a fully connected layer, where the latter contains one node for each dog category and is equipped with a softmax.

# %%
VGG16_model = Sequential()
VGG16_model.add(GlobalAveragePooling2D(input_shape=train_VGG16.shape[1:]))
VGG16_model.add(Dense(133, activation='softmax'))

VGG16_model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# global_average_pooling2d_1 ( (None, 512)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 133)               68229
# =================================================================
# Total params: 68,229
# Trainable params: 68,229
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Compile the Model

# %%
VGG16_model.compile(loss='categorical_crossentropy', optimizer='rmsprop', metrics=['accuracy'])

# %% [markdown]
# ### Train the Model

# %%
checkpointer = ModelCheckpoint(filepath='saved_models/weights.best.VGG16.hdf5', 
                               verbose=1, save_best_only=True)

VGG16_model.fit(train_VGG16, train_targets, 
          validation_data=(valid_VGG16, valid_targets),
          epochs=5, batch_size=20, callbacks=[checkpointer], verbose=1)
# Out:
# Train on 6680 samples, validate on 835 samples
# Epoch 1/5
# 6680/6680 [==============================] - ETA: 31s - loss: 23.9674 - accuracy: 0.05 - ETA: 1s - loss: 19.0611 - accuracy: 0.0188 - ETA: 0s - loss: 16.0619 - accuracy: 0.035 - ETA: 0s - loss: 14.0182 - accuracy: 0.060 - ETA: 0s - loss: 12.6876 - accuracy: 0.081 - ETA: 0s - loss: 11.4238 - accuracy: 0.114 - ETA: 0s - loss: 10.4382 - accuracy: 0.141 - ETA: 0s - loss: 9.6683 - accuracy: 0.163 - ETA: 0s - loss: 8.9902 - accuracy: 0.19 - ETA: 0s - loss: 8.4434 - accuracy: 0.21 - ETA: 0s - loss: 7.9895 - accuracy: 0.22 - 1s 109us/step - loss: 7.9510 - accuracy: 0.2310 - val_loss: 3.7874 - val_accuracy: 0.4287
#
# Epoch 00001: val_loss improved from inf to 3.78738, saving model to saved_models/weights.best.VGG16.hdf5
# Epoch 2/5
# 6680/6680 [==============================] - ETA: 0s - loss: 2.2450 - accuracy: 0.60 - ETA: 0s - loss: 2.7016 - accuracy: 0.53 - ETA: 0s - loss: 2.5810 - accuracy: 0.54 - ETA: 0s - loss: 2.5399 - accuracy: 0.55 - ETA: 0s - loss: 2.4626 - accuracy: 0.56 - ETA: 0s - loss: 2.4306 - accuracy: 0.56 - ETA: 0s - loss: 2.3939 - accuracy: 0.57 - ETA: 0s - loss: 2.3497 - accuracy: 0.57 - ETA: 0s - loss: 2.3056 - accuracy: 0.58 - ETA: 0s - loss: 2.2658 - accuracy: 0.59 - ETA: 0s - loss: 2.2460 - accuracy: 0.59 - 1s 84us/step - loss: 2.2382 - accuracy: 0.5958 - val_loss: 2.5210 - val_accuracy: 0.5749
#
# Epoch 00002: val_loss improved from 3.78738 to 2.52104, saving model to saved_models/weights.best.VGG16.hdf5
# Epoch 3/5
# 6680/6680 [==============================] - ETA: 0s - loss: 1.3132 - accuracy: 0.65 - ETA: 0s - loss: 1.1680 - accuracy: 0.74 - ETA: 0s - loss: 1.2867 - accuracy: 0.71 - ETA: 0s - loss: 1.3097 - accuracy: 0.71 - ETA: 0s - loss: 1.2892 - accuracy: 0.72 - ETA: 0s - loss: 1.2895 - accuracy: 0.71 - ETA: 0s - loss: 1.2689 - accuracy: 0.72 - ETA: 0s - loss: 1.2682 - accuracy: 0.72 - ETA: 0s - loss: 1.2644 - accuracy: 0.73 - ETA: 0s - loss: 1.2496 - accuracy: 0.73 - ETA: 0s - loss: 1.2616 - accuracy: 0.73 - 1s 85us/step - loss: 1.2687 - accuracy: 0.7328 - val_loss: 2.1896 - val_accuracy: 0.6407
#
# Epoch 00003: val_loss improved from 2.52104 to 2.18959, saving model to saved_models/weights.best.VGG16.hdf5
# Epoch 4/5
# 6680/6680 [==============================] - ETA: 0s - loss: 0.2333 - accuracy: 0.85 - ETA: 0s - loss: 0.6700 - accuracy: 0.84 - ETA: 0s - loss: 0.6942 - accuracy: 0.83 - ETA: 0s - loss: 0.7163 - accuracy: 0.82 - ETA: 0s - loss: 0.7400 - accuracy: 0.82 - ETA: 0s - loss: 0.7756 - accuracy: 0.82 - ETA: 0s - loss: 0.7963 - accuracy: 0.81 - ETA: 0s - loss: 0.8100 - accuracy: 0.81 - ETA: 0s - loss: 0.8204 - accuracy: 0.81 - ETA: 0s - loss: 0.8189 - accuracy: 0.81 - ETA: 0s - loss: 0.8255 - accuracy: 0.81 - 1s 86us/step - loss: 0.8265 - accuracy: 0.8145 - val_loss: 1.9015 - val_accuracy: 0.6443
#
# Epoch 00004: val_loss improved from 2.18959 to 1.90151, saving model to saved_models/weights.best.VGG16.hdf5
# Epoch 5/5
# 6680/6680 [==============================] - ETA: 0s - loss: 0.2094 - accuracy: 0.90 - ETA: 0s - loss: 0.3498 - accuracy: 0.89 - ETA: 0s - loss: 0.3944 - accuracy: 0.87 - ETA: 0s - loss: 0.4230 - accuracy: 0.86 - ETA: 0s - loss: 0.4665 - accuracy: 0.86 - ETA: 0s - loss: 0.5036 - accuracy: 0.86 - ETA: 0s - loss: 0.5166 - accuracy: 0.85 - ETA: 0s - loss: 0.5310 - accuracy: 0.85 - ETA: 0s - loss: 0.5527 - accuracy: 0.85 - ETA: 0s - loss: 0.5657 - accuracy: 0.85 - ETA: 0s - loss: 0.5694 - accuracy: 0.85 - 1s 88us/step - loss: 0.5742 - accuracy: 0.8551 - val_loss: 1.8967 - val_accuracy: 0.6826
#
# Epoch 00005: val_loss improved from 1.90151 to 1.89675, saving model to saved_models/weights.best.VGG16.hdf5

# %% [markdown]
# ### Load the Model with the Best Validation Loss

# %%
VGG16_model.load_weights('saved_models/weights.best.VGG16.hdf5')

# %% [markdown]
# ### Test the Model
#
# Now, we can use the CNN to test how well it identifies breed within our test dataset of dog images.  We print the test accuracy below.

# %%
# get index of predicted dog breed for each image in test set
VGG16_predictions = [np.argmax(VGG16_model.predict(np.expand_dims(feature, axis=0))) for feature in test_VGG16]

# report test accuracy
test_accuracy = 100*np.sum(np.array(VGG16_predictions)==np.argmax(test_targets, axis=1))/len(VGG16_predictions)
print('Test accuracy: %.4f%%' % test_accuracy)
# Out:
# Test accuracy: 67.2249%

# %% [markdown]
# ### Predict Dog Breed with the Model

# %%
from extract_bottleneck_features import *

def VGG16_predict_breed(img_path):
    # extract bottleneck features
    bottleneck_feature = extract_VGG16(path_to_tensor(img_path))
    # obtain predicted vector
    predicted_vector = VGG16_model.predict(bottleneck_feature)
    # return dog breed that is predicted by the model
    return dog_names[np.argmax(predicted_vector)]

# %% [markdown]
# ---
# <a id='step5'></a>
# ## Step 5: Create a CNN to Classify Dog Breeds (using Transfer Learning)
#
# You will now use transfer learning to create a CNN that can identify dog breed from images.  Your CNN must attain at least 60% accuracy on the test set.
#
# In Step 4, we used transfer learning to create a CNN using VGG-16 bottleneck features.  In this section, you must use the bottleneck features from a different pre-trained model.  To make things easier for you, we have pre-computed the features for all of the networks that are currently available in Keras.  These are already in the workspace, at /data/bottleneck_features.  If you wish to download them on a different machine, they can be found at:
# - [VGG-19](https://s3-us-west-1.amazonaws.com/udacity-aind/dog-project/DogVGG19Data.npz) bottleneck features
# - [ResNet-50](https://s3-us-west-1.amazonaws.com/udacity-aind/dog-project/DogResnet50Data.npz) bottleneck features
# - [Inception](https://s3-us-west-1.amazonaws.com/udacity-aind/dog-project/DogInceptionV3Data.npz) bottleneck features
# - [Xception](https://s3-us-west-1.amazonaws.com/udacity-aind/dog-project/DogXceptionData.npz) bottleneck features
#
# The files are encoded as such:
#
#     Dog{network}Data.npz
#
# where `{network}`, in the above filename, can be one of `VGG19`, `Resnet50`, `InceptionV3`, or `Xception`.
#
# The above architectures are downloaded and stored for you in the `/data/bottleneck_features/` folder.
#
# This means the following will be in the `/data/bottleneck_features/` folder:
#
# `DogVGG19Data.npz`
# `DogResnet50Data.npz`
# `DogInceptionV3Data.npz`
# `DogXceptionData.npz`
#
#
#
# ### (IMPLEMENTATION) Obtain Bottleneck Features
#
# In the code block below, extract the bottleneck features corresponding to the train, test, and validation sets by running the following:
#
#     bottleneck_features = np.load('/data/bottleneck_features/Dog{network}Data.npz')
#     train_{network} = bottleneck_features['train']
#     valid_{network} = bottleneck_features['valid']
#     test_{network} = bottleneck_features['test']

# %%
### TODO: Obtain bottleneck features from another pre-trained CNN.
bottleneck_features = np.load('bottleneck_features/DogXceptionData.npz')
train_Xception = bottleneck_features['train']
valid_Xception = bottleneck_features['valid']
test_Xception = bottleneck_features['test']

# %% [markdown]
# ### (IMPLEMENTATION) Model Architecture
#
# Create a CNN to classify dog breed.  At the end of your code cell block, summarize the layers of your model by executing the line:
#
#         <your model's name>.summary()
#
# __Question 5:__ Outline the steps you took to get to your final CNN architecture and your reasoning at each step.  Describe why you think the architecture is suitable for the current problem.
#
# __Answer:__
#
# Transfer learning is widely used in computer vision because it can build accurate models in less time. In this method, we take a pre-trained model with already learned patterns from a large benchmark dataset when solving a similar problem. This way we take advantage of previous learning and avoid starting from the very beginning.
# I have chosen Xception because of its high accuracy predicting dog breed [here](https://www.pyimagesearch.com/2017/03/20/imagenet-vggnet-resnet-inception-xception-keras/) and also its good performance showed in [this](http://zpascal.net/cvpr2017/Chollet_Xception_Deep_Learning_CVPR_2017_paper.pdf) paper.

# %%
### TODO: Define your architecture.
from keras.layers import Dropout
from keras.layers.normalization import BatchNormalization

Xception_model = Sequential()
Xception_model.add(GlobalAveragePooling2D(input_shape=train_Xception.shape[1:]))
Xception_model.add(Dense(500, activation='relu'))
Xception_model.add(Dropout(0.4))
Xception_model.add(Dense(500, activation='relu'))
Xception_model.add(Dropout(0.4))
Xception_model.add(Dense(133, activation='softmax'))

Xception_model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# global_average_pooling2d_2 ( (None, 2048)              0
# _________________________________________________________________
# dense_4 (Dense)              (None, 500)               1024500
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 500)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 500)               250500
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 500)               0
# _________________________________________________________________
# dense_6 (Dense)              (None, 133)               66633
# =================================================================
# Total params: 1,341,633
# Trainable params: 1,341,633
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### (IMPLEMENTATION) Compile the Model

# %%
### TODO: Compile the model.
Xception_model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %% [markdown]
# ### (IMPLEMENTATION) Train the Model
#
# Train your model in the code cell below.  Use model checkpointing to save the model that attains the best validation loss.
#
# You are welcome to [augment the training data](https://blog.keras.io/building-powerful-image-classification-models-using-very-little-data.html), but this is not a requirement.

# %%
### TODO: Train the model.
from keras.callbacks import ModelCheckpoint 

checkpointer = ModelCheckpoint(filepath='saved_models/weights.best.Xception.hdf5', 
                               verbose=1, save_best_only=True)

Xception_model.fit(train_Xception, train_targets, 
          validation_data=(valid_Xception, valid_targets),
          epochs=20, batch_size=20, callbacks=[checkpointer], verbose=1)
# Out:
# Train on 6680 samples, validate on 835 samples
# Epoch 1/20
# 6680/6680 [==============================] - ETA: 58s - loss: 5.0245 - accuracy: 0.0000e+0 - ETA: 15s - loss: 4.9257 - accuracy: 0.0400    - ETA: 10s - loss: 4.9846 - accuracy: 0.038 - ETA: 8s - loss: 4.9668 - accuracy: 0.038 - ETA: 7s - loss: 4.8982 - accuracy: 0.04 - ETA: 6s - loss: 4.8619 - accuracy: 0.05 - ETA: 6s - loss: 4.7718 - accuracy: 0.07 - ETA: 6s - loss: 4.7303 - accuracy: 0.08 - ETA: 5s - loss: 4.6798 - accuracy: 0.08 - ETA: 5s - loss: 4.6206 - accuracy: 0.10 - ETA: 5s - loss: 4.5424 - accuracy: 0.11 - ETA: 5s - loss: 4.4662 - accuracy: 0.12 - ETA: 5s - loss: 4.3763 - accuracy: 0.14 - ETA: 4s - loss: 4.2959 - accuracy: 0.16 - ETA: 4s - loss: 4.2004 - accuracy: 0.17 - ETA: 4s - loss: 4.1395 - accuracy: 0.18 - ETA: 4s - loss: 4.0761 - accuracy: 0.19 - ETA: 4s - loss: 4.0144 - accuracy: 0.20 - ETA: 4s - loss: 3.9414 - accuracy: 0.21 - ETA: 4s - loss: 3.8861 - accuracy: 0.22 - ETA: 4s - loss: 3.8302 - accuracy: 0.22 - ETA: 4s - loss: 3.7727 - accuracy: 0.23 - ETA: 3s - loss: 3.7287 - accuracy: 0.24 - ETA: 3s - loss: 3.6638 - accuracy: 0.25 - ETA: 3s - loss: 3.5912 - accuracy: 0.26 - ETA: 3s - loss: 3.5253 - accuracy: 0.27 - ETA: 3s - loss: 3.4715 - accuracy: 0.28 - ETA: 3s - loss: 3.4046 - accuracy: 0.29 - ETA: 3s - loss: 3.3541 - accuracy: 0.30 - ETA: 3s - loss: 3.3034 - accuracy: 0.31 - ETA: 3s - loss: 3.2632 - accuracy: 0.31 - ETA: 3s - loss: 3.2128 - accuracy: 0.32 - ETA: 3s - loss: 3.1653 - accuracy: 0.32 - ETA: 3s - loss: 3.1161 - accuracy: 0.33 - ETA: 3s - loss: 3.0705 - accuracy: 0.34 - ETA: 2s - loss: 3.0379 - accuracy: 0.34 - ETA: 2s - loss: 2.9889 - accuracy: 0.35 - ETA: 2s - loss: 2.9606 - accuracy: 0.35 - ETA: 2s - loss: 2.9181 - accuracy: 0.36 - ETA: 2s - loss: 2.8848 - accuracy: 0.37 - ETA: 2s - loss: 2.8496 - accuracy: 0.37 - ETA: 2s - loss: 2.8162 - accuracy: 0.38 - ETA: 2s - loss: 2.7891 - accuracy: 0.38 - ETA: 2s - loss: 2.7532 - accuracy: 0.39 - ETA: 2s - loss: 2.7242 - accuracy: 0.39 - ETA: 2s - loss: 2.6935 - accuracy: 0.40 - ETA: 2s - loss: 2.6745 - accuracy: 0.40 - ETA: 2s - loss: 2.6546 - accuracy: 0.40 - ETA: 2s - loss: 2.6260 - accuracy: 0.41 - ETA: 2s - loss: 2.5967 - accuracy: 0.41 - ETA: 2s - loss: 2.5737 - accuracy: 0.42 - ETA: 1s - loss: 2.5452 - accuracy: 0.42 - ETA: 1s - loss: 2.5176 - accuracy: 0.43 - ETA: 1s - loss: 2.4991 - accuracy: 0.43 - ETA: 1s - loss: 2.4782 - accuracy: 0.43 - ETA: 1s - loss: 2.4582 - accuracy: 0.44 - ETA: 1s - loss: 2.4370 - accuracy: 0.44 - ETA: 1s - loss: 2.4140 - accuracy: 0.44 - ETA: 1s - loss: 2.3959 - accuracy: 0.45 - ETA: 1s - loss: 2.3776 - accuracy: 0.45 - ETA: 1s - loss: 2.3587 - accuracy: 0.45 - ETA: 1s - loss: 2.3487 - accuracy: 0.45 - ETA: 1s - loss: 2.3338 - accuracy: 0.46 - ETA: 1s - loss: 2.3178 - accuracy: 0.46 - ETA: 1s - loss: 2.3027 - accuracy: 0.46 - ETA: 1s - loss: 2.2836 - accuracy: 0.47 - ETA: 1s - loss: 2.2677 - accuracy: 0.47 - ETA: 0s - loss: 2.2525 - accuracy: 0.47 - ETA: 0s - loss: 2.2376 - accuracy: 0.48 - ETA: 0s - loss: 2.2227 - accuracy: 0.48 - ETA: 0s - loss: 2.2072 - accuracy: 0.48 - ETA: 0s - loss: 2.1892 - accuracy: 0.48 - ETA: 0s - loss: 2.1746 - accuracy: 0.49 - ETA: 0s - loss: 2.1649 - accuracy: 0.49 - ETA: 0s - loss: 2.1564 - accuracy: 0.49 - ETA: 0s - loss: 2.1435 - accuracy: 0.49 - ETA: 0s - loss: 2.1333 - accuracy: 0.49 - ETA: 0s - loss: 2.1265 - accuracy: 0.50 - ETA: 0s - loss: 2.1151 - accuracy: 0.50 - ETA: 0s - loss: 2.1030 - accuracy: 0.50 - ETA: 0s - loss: 2.0918 - accuracy: 0.50 - ETA: 0s - loss: 2.0780 - accuracy: 0.50 - ETA: 0s - loss: 2.0674 - accuracy: 0.51 - ETA: 0s - loss: 2.0592 - accuracy: 0.51 - 5s 779us/step - loss: 2.0575 - accuracy: 0.5123 - val_loss: 0.6955 - val_accuracy: 0.7808
#
# Epoch 00001: val_loss improved from inf to 0.69548, saving model to saved_models/weights.best.Xception.hdf5
# Epoch 2/20
# 6680/6680 [==============================] - ETA: 4s - loss: 0.8696 - accuracy: 0.75 - ETA: 4s - loss: 0.8664 - accuracy: 0.75 - ETA: 4s - loss: 0.7843 - accuracy: 0.76 - ETA: 4s - loss: 0.8106 - accuracy: 0.76 - ETA: 4s - loss: 0.8691 - accuracy: 0.75 - ETA: 4s - loss: 0.8744 - accuracy: 0.74 - ETA: 4s - loss: 0.8545 - accuracy: 0.74 - ETA: 4s - loss: 0.8669 - accuracy: 0.73 - ETA: 4s - loss: 0.9127 - accuracy: 0.73 - ETA: 4s - loss: 0.9050 - accuracy: 0.73 - ETA: 4s - loss: 0.8976 - accuracy: 0.73 - ETA: 4s - loss: 0.9012 - accuracy: 0.73 - ETA: 4s - loss: 0.8917 - accuracy: 0.73 - ETA: 4s - loss: 0.8860 - accuracy: 0.73 - ETA: 3s - loss: 0.9005 - accuracy: 0.73 - ETA: 3s - loss: 0.8979 - accuracy: 0.73 - ETA: 3s - loss: 0.9196 - accuracy: 0.72 - ETA: 3s - loss: 0.9194 - accuracy: 0.72 - ETA: 3s - loss: 0.9142 - accuracy: 0.72 - ETA: 3s - loss: 0.9238 - accuracy: 0.72 - ETA: 3s - loss: 0.9307 - accuracy: 0.72 - ETA: 3s - loss: 0.9343 - accuracy: 0.72 - ETA: 3s - loss: 0.9222 - accuracy: 0.72 - ETA: 3s - loss: 0.9131 - accuracy: 0.73 - ETA: 3s - loss: 0.9081 - accuracy: 0.73 - ETA: 3s - loss: 0.9094 - accuracy: 0.73 - ETA: 3s - loss: 0.9074 - accuracy: 0.73 - ETA: 3s - loss: 0.9098 - accuracy: 0.72 - ETA: 3s - loss: 0.9150 - accuracy: 0.72 - ETA: 3s - loss: 0.9079 - accuracy: 0.73 - ETA: 3s - loss: 0.9072 - accuracy: 0.72 - ETA: 3s - loss: 0.9026 - accuracy: 0.73 - ETA: 2s - loss: 0.9047 - accuracy: 0.73 - ETA: 2s - loss: 0.9099 - accuracy: 0.72 - ETA: 2s - loss: 0.9170 - accuracy: 0.72 - ETA: 2s - loss: 0.9105 - accuracy: 0.72 - ETA: 2s - loss: 0.9159 - accuracy: 0.72 - ETA: 2s - loss: 0.9184 - accuracy: 0.72 - ETA: 2s - loss: 0.9102 - accuracy: 0.72 - ETA: 2s - loss: 0.9168 - accuracy: 0.72 - ETA: 2s - loss: 0.9157 - accuracy: 0.72 - ETA: 2s - loss: 0.9214 - accuracy: 0.72 - ETA: 2s - loss: 0.9155 - accuracy: 0.72 - ETA: 2s - loss: 0.9131 - accuracy: 0.72 - ETA: 2s - loss: 0.9176 - accuracy: 0.72 - ETA: 2s - loss: 0.9189 - accuracy: 0.72 - ETA: 2s - loss: 0.9129 - accuracy: 0.72 - ETA: 2s - loss: 0.9120 - accuracy: 0.72 - ETA: 2s - loss: 0.9103 - accuracy: 0.72 - ETA: 1s - loss: 0.9070 - accuracy: 0.72 - ETA: 1s - loss: 0.9054 - accuracy: 0.72 - ETA: 1s - loss: 0.9071 - accuracy: 0.72 - ETA: 1s - loss: 0.9013 - accuracy: 0.72 - ETA: 1s - loss: 0.8996 - accuracy: 0.72 - ETA: 1s - loss: 0.8954 - accuracy: 0.72 - ETA: 1s - loss: 0.8972 - accuracy: 0.73 - ETA: 1s - loss: 0.8981 - accuracy: 0.73 - ETA: 1s - loss: 0.8973 - accuracy: 0.73 - ETA: 1s - loss: 0.8978 - accuracy: 0.72 - ETA: 1s - loss: 0.8970 - accuracy: 0.72 - ETA: 1s - loss: 0.8980 - accuracy: 0.72 - ETA: 1s - loss: 0.8974 - accuracy: 0.72 - ETA: 1s - loss: 0.8983 - accuracy: 0.72 - ETA: 1s - loss: 0.9092 - accuracy: 0.72 - ETA: 1s - loss: 0.9062 - accuracy: 0.72 - ETA: 1s - loss: 0.9062 - accuracy: 0.72 - ETA: 0s - loss: 0.9114 - accuracy: 0.72 - ETA: 0s - loss: 0.9102 - accuracy: 0.72 - ETA: 0s - loss: 0.9052 - accuracy: 0.72 - ETA: 0s - loss: 0.9053 - accuracy: 0.72 - ETA: 0s - loss: 0.9064 - accuracy: 0.72 - ETA: 0s - loss: 0.9032 - accuracy: 0.72 - ETA: 0s - loss: 0.9020 - accuracy: 0.72 - ETA: 0s - loss: 0.9008 - accuracy: 0.72 - ETA: 0s - loss: 0.9012 - accuracy: 0.72 - ETA: 0s - loss: 0.9047 - accuracy: 0.72 - ETA: 0s - loss: 0.9035 - accuracy: 0.73 - ETA: 0s - loss: 0.9023 - accuracy: 0.73 - ETA: 0s - loss: 0.9096 - accuracy: 0.72 - ETA: 0s - loss: 0.9107 - accuracy: 0.72 - ETA: 0s - loss: 0.9127 - accuracy: 0.72 - ETA: 0s - loss: 0.9160 - accuracy: 0.72 - ETA: 0s - loss: 0.9178 - accuracy: 0.72 - ETA: 0s - loss: 0.9170 - accuracy: 0.72 - 5s 743us/step - loss: 0.9170 - accuracy: 0.7278 - val_loss: 0.6961 - val_accuracy: 0.7976
#
# Epoch 00002: val_loss did not improve from 0.69548
# Epoch 3/20
# 6680/6680 [==============================] - ETA: 4s - loss: 0.5871 - accuracy: 0.85 - ETA: 4s - loss: 0.5776 - accuracy: 0.83 - ETA: 4s - loss: 0.6516 - accuracy: 0.80 - ETA: 4s - loss: 0.7585 - accuracy: 0.78 - ETA: 4s - loss: 0.7379 - accuracy: 0.78 - ETA: 4s - loss: 0.7018 - accuracy: 0.80 - ETA: 4s - loss: 0.7365 - accuracy: 0.79 - ETA: 4s - loss: 0.7486 - accuracy: 0.78 - ETA: 4s - loss: 0.7757 - accuracy: 0.77 - ETA: 4s - loss: 0.7619 - accuracy: 0.77 - ETA: 4s - loss: 0.7581 - accuracy: 0.77 - ETA: 4s - loss: 0.7593 - accuracy: 0.77 - ETA: 4s - loss: 0.7831 - accuracy: 0.76 - ETA: 4s - loss: 0.7642 - accuracy: 0.76 - ETA: 3s - loss: 0.7636 - accuracy: 0.76 - ETA: 3s - loss: 0.7677 - accuracy: 0.76 - ETA: 3s - loss: 0.7773 - accuracy: 0.76 - ETA: 3s - loss: 0.7732 - accuracy: 0.76 - ETA: 3s - loss: 0.7927 - accuracy: 0.76 - ETA: 3s - loss: 0.7933 - accuracy: 0.76 - ETA: 3s - loss: 0.7853 - accuracy: 0.76 - ETA: 3s - loss: 0.7917 - accuracy: 0.76 - ETA: 3s - loss: 0.7758 - accuracy: 0.76 - ETA: 3s - loss: 0.7698 - accuracy: 0.76 - ETA: 3s - loss: 0.7699 - accuracy: 0.76 - ETA: 3s - loss: 0.7630 - accuracy: 0.76 - ETA: 3s - loss: 0.7629 - accuracy: 0.77 - ETA: 3s - loss: 0.7515 - accuracy: 0.77 - ETA: 3s - loss: 0.7493 - accuracy: 0.77 - ETA: 3s - loss: 0.7602 - accuracy: 0.77 - ETA: 3s - loss: 0.7613 - accuracy: 0.77 - ETA: 2s - loss: 0.7623 - accuracy: 0.77 - ETA: 2s - loss: 0.7638 - accuracy: 0.77 - ETA: 2s - loss: 0.7640 - accuracy: 0.77 - ETA: 2s - loss: 0.7668 - accuracy: 0.77 - ETA: 2s - loss: 0.7691 - accuracy: 0.77 - ETA: 2s - loss: 0.7711 - accuracy: 0.77 - ETA: 2s - loss: 0.7723 - accuracy: 0.77 - ETA: 2s - loss: 0.7722 - accuracy: 0.77 - ETA: 2s - loss: 0.7724 - accuracy: 0.77 - ETA: 2s - loss: 0.7711 - accuracy: 0.77 - ETA: 2s - loss: 0.7693 - accuracy: 0.77 - ETA: 2s - loss: 0.7721 - accuracy: 0.77 - ETA: 2s - loss: 0.7686 - accuracy: 0.77 - ETA: 2s - loss: 0.7665 - accuracy: 0.77 - ETA: 2s - loss: 0.7614 - accuracy: 0.77 - ETA: 2s - loss: 0.7601 - accuracy: 0.77 - ETA: 2s - loss: 0.7564 - accuracy: 0.77 - ETA: 2s - loss: 0.7505 - accuracy: 0.77 - ETA: 1s - loss: 0.7565 - accuracy: 0.77 - ETA: 1s - loss: 0.7569 - accuracy: 0.77 - ETA: 1s - loss: 0.7537 - accuracy: 0.77 - ETA: 1s - loss: 0.7568 - accuracy: 0.77 - ETA: 1s - loss: 0.7560 - accuracy: 0.77 - ETA: 1s - loss: 0.7582 - accuracy: 0.77 - ETA: 1s - loss: 0.7548 - accuracy: 0.77 - ETA: 1s - loss: 0.7543 - accuracy: 0.77 - ETA: 1s - loss: 0.7526 - accuracy: 0.77 - ETA: 1s - loss: 0.7510 - accuracy: 0.77 - ETA: 1s - loss: 0.7489 - accuracy: 0.77 - ETA: 1s - loss: 0.7522 - accuracy: 0.77 - ETA: 1s - loss: 0.7552 - accuracy: 0.77 - ETA: 1s - loss: 0.7557 - accuracy: 0.77 - ETA: 1s - loss: 0.7589 - accuracy: 0.77 - ETA: 1s - loss: 0.7605 - accuracy: 0.77 - ETA: 1s - loss: 0.7578 - accuracy: 0.77 - ETA: 0s - loss: 0.7598 - accuracy: 0.77 - ETA: 0s - loss: 0.7602 - accuracy: 0.77 - ETA: 0s - loss: 0.7604 - accuracy: 0.77 - ETA: 0s - loss: 0.7614 - accuracy: 0.77 - ETA: 0s - loss: 0.7599 - accuracy: 0.77 - ETA: 0s - loss: 0.7630 - accuracy: 0.77 - ETA: 0s - loss: 0.7618 - accuracy: 0.77 - ETA: 0s - loss: 0.7609 - accuracy: 0.77 - ETA: 0s - loss: 0.7573 - accuracy: 0.77 - ETA: 0s - loss: 0.7587 - accuracy: 0.77 - ETA: 0s - loss: 0.7584 - accuracy: 0.77 - ETA: 0s - loss: 0.7586 - accuracy: 0.77 - ETA: 0s - loss: 0.7574 - accuracy: 0.77 - ETA: 0s - loss: 0.7576 - accuracy: 0.77 - ETA: 0s - loss: 0.7581 - accuracy: 0.77 - ETA: 0s - loss: 0.7557 - accuracy: 0.77 - ETA: 0s - loss: 0.7518 - accuracy: 0.77 - ETA: 0s - loss: 0.7548 - accuracy: 0.77 - 5s 745us/step - loss: 0.7541 - accuracy: 0.7738 - val_loss: 0.6531 - val_accuracy: 0.7868
#
# Epoch 00003: val_loss improved from 0.69548 to 0.65310, saving model to saved_models/weights.best.Xception.hdf5
# Epoch 4/20
# 6680/6680 [==============================] - ETA: 4s - loss: 0.6265 - accuracy: 0.80 - ETA: 4s - loss: 0.4489 - accuracy: 0.85 - ETA: 4s - loss: 0.4679 - accuracy: 0.85 - ETA: 4s - loss: 0.5197 - accuracy: 0.84 - ETA: 4s - loss: 0.5148 - accuracy: 0.83 - ETA: 4s - loss: 0.5384 - accuracy: 0.83 - ETA: 4s - loss: 0.5895 - accuracy: 0.81 - ETA: 4s - loss: 0.6101 - accuracy: 0.80 - ETA: 4s - loss: 0.6004 - accuracy: 0.81 - ETA: 4s - loss: 0.5656 - accuracy: 0.82 - ETA: 4s - loss: 0.5737 - accuracy: 0.82 - ETA: 4s - loss: 0.5964 - accuracy: 0.81 - ETA: 4s - loss: 0.5933 - accuracy: 0.81 - ETA: 4s - loss: 0.6067 - accuracy: 0.81 - ETA: 3s - loss: 0.5964 - accuracy: 0.82 - ETA: 3s - loss: 0.5980 - accuracy: 0.81 - ETA: 3s - loss: 0.6017 - accuracy: 0.81 - ETA: 3s - loss: 0.6061 - accuracy: 0.81 - ETA: 3s - loss: 0.6163 - accuracy: 0.81 - ETA: 3s - loss: 0.6215 - accuracy: 0.81 - ETA: 3s - loss: 0.6208 - accuracy: 0.80 - ETA: 3s - loss: 0.6264 - accuracy: 0.80 - ETA: 3s - loss: 0.6222 - accuracy: 0.80 - ETA: 3s - loss: 0.6164 - accuracy: 0.80 - ETA: 3s - loss: 0.6072 - accuracy: 0.81 - ETA: 3s - loss: 0.6057 - accuracy: 0.81 - ETA: 3s - loss: 0.6153 - accuracy: 0.80 - ETA: 3s - loss: 0.6200 - accuracy: 0.80 - ETA: 3s - loss: 0.6290 - accuracy: 0.80 - ETA: 3s - loss: 0.6315 - accuracy: 0.80 - ETA: 3s - loss: 0.6432 - accuracy: 0.80 - ETA: 2s - loss: 0.6431 - accuracy: 0.80 - ETA: 2s - loss: 0.6429 - accuracy: 0.80 - ETA: 2s - loss: 0.6359 - accuracy: 0.80 - ETA: 2s - loss: 0.6339 - accuracy: 0.80 - ETA: 2s - loss: 0.6382 - accuracy: 0.80 - ETA: 2s - loss: 0.6371 - accuracy: 0.80 - ETA: 2s - loss: 0.6334 - accuracy: 0.80 - ETA: 2s - loss: 0.6304 - accuracy: 0.80 - ETA: 2s - loss: 0.6353 - accuracy: 0.80 - ETA: 2s - loss: 0.6326 - accuracy: 0.80 - ETA: 2s - loss: 0.6333 - accuracy: 0.80 - ETA: 2s - loss: 0.6344 - accuracy: 0.80 - ETA: 2s - loss: 0.6318 - accuracy: 0.80 - ETA: 2s - loss: 0.6288 - accuracy: 0.81 - ETA: 2s - loss: 0.6311 - accuracy: 0.80 - ETA: 2s - loss: 0.6325 - accuracy: 0.80 - ETA: 2s - loss: 0.6330 - accuracy: 0.80 - ETA: 2s - loss: 0.6352 - accuracy: 0.80 - ETA: 1s - loss: 0.6349 - accuracy: 0.80 - ETA: 1s - loss: 0.6376 - accuracy: 0.80 - ETA: 1s - loss: 0.6376 - accuracy: 0.80 - ETA: 1s - loss: 0.6404 - accuracy: 0.80 - ETA: 1s - loss: 0.6394 - accuracy: 0.80 - ETA: 1s - loss: 0.6431 - accuracy: 0.80 - ETA: 1s - loss: 0.6416 - accuracy: 0.80 - ETA: 1s - loss: 0.6414 - accuracy: 0.80 - ETA: 1s - loss: 0.6401 - accuracy: 0.80 - ETA: 1s - loss: 0.6407 - accuracy: 0.80 - ETA: 1s - loss: 0.6399 - accuracy: 0.80 - ETA: 1s - loss: 0.6385 - accuracy: 0.80 - ETA: 1s - loss: 0.6388 - accuracy: 0.80 - ETA: 1s - loss: 0.6385 - accuracy: 0.80 - ETA: 1s - loss: 0.6380 - accuracy: 0.80 - ETA: 1s - loss: 0.6411 - accuracy: 0.80 - ETA: 1s - loss: 0.6433 - accuracy: 0.80 - ETA: 0s - loss: 0.6489 - accuracy: 0.80 - ETA: 0s - loss: 0.6532 - accuracy: 0.79 - ETA: 0s - loss: 0.6511 - accuracy: 0.80 - ETA: 0s - loss: 0.6516 - accuracy: 0.80 - ETA: 0s - loss: 0.6522 - accuracy: 0.80 - ETA: 0s - loss: 0.6524 - accuracy: 0.80 - ETA: 0s - loss: 0.6514 - accuracy: 0.80 - ETA: 0s - loss: 0.6538 - accuracy: 0.79 - ETA: 0s - loss: 0.6522 - accuracy: 0.80 - ETA: 0s - loss: 0.6544 - accuracy: 0.79 - ETA: 0s - loss: 0.6562 - accuracy: 0.79 - ETA: 0s - loss: 0.6548 - accuracy: 0.80 - ETA: 0s - loss: 0.6547 - accuracy: 0.80 - ETA: 0s - loss: 0.6545 - accuracy: 0.80 - ETA: 0s - loss: 0.6552 - accuracy: 0.80 - ETA: 0s - loss: 0.6539 - accuracy: 0.80 - ETA: 0s - loss: 0.6543 - accuracy: 0.80 - ETA: 0s - loss: 0.6560 - accuracy: 0.79 - 5s 742us/step - loss: 0.6572 - accuracy: 0.7993 - val_loss: 0.6039 - val_accuracy: 0.8156
#
# Epoch 00004: val_loss improved from 0.65310 to 0.60386, saving model to saved_models/weights.best.Xception.hdf5
# Epoch 5/20
# 6680/6680 [==============================] - ETA: 4s - loss: 0.7925 - accuracy: 0.80 - ETA: 4s - loss: 0.7367 - accuracy: 0.78 - ETA: 4s - loss: 0.6306 - accuracy: 0.82 - ETA: 4s - loss: 0.6057 - accuracy: 0.81 - ETA: 4s - loss: 0.5933 - accuracy: 0.81 - ETA: 4s - loss: 0.6061 - accuracy: 0.81 - ETA: 4s - loss: 0.5830 - accuracy: 0.82 - ETA: 4s - loss: 0.5846 - accuracy: 0.82 - ETA: 4s - loss: 0.5757 - accuracy: 0.82 - ETA: 4s - loss: 0.5694 - accuracy: 0.82 - ETA: 4s - loss: 0.5608 - accuracy: 0.82 - ETA: 4s - loss: 0.5393 - accuracy: 0.82 - ETA: 4s - loss: 0.5496 - accuracy: 0.82 - ETA: 4s - loss: 0.5388 - accuracy: 0.82 - ETA: 3s - loss: 0.5383 - accuracy: 0.82 - ETA: 3s - loss: 0.5477 - accuracy: 0.82 - ETA: 3s - loss: 0.5559 - accuracy: 0.82 - ETA: 3s - loss: 0.5522 - accuracy: 0.82 - ETA: 3s - loss: 0.5441 - accuracy: 0.82 - ETA: 3s - loss: 0.5414 - accuracy: 0.82 - ETA: 3s - loss: 0.5462 - accuracy: 0.82 - ETA: 3s - loss: 0.5611 - accuracy: 0.81 - ETA: 3s - loss: 0.5569 - accuracy: 0.81 - ETA: 3s - loss: 0.5611 - accuracy: 0.81 - ETA: 3s - loss: 0.5640 - accuracy: 0.81 - ETA: 3s - loss: 0.5626 - accuracy: 0.81 - ETA: 3s - loss: 0.5623 - accuracy: 0.81 - ETA: 3s - loss: 0.5612 - accuracy: 0.81 - ETA: 3s - loss: 0.5570 - accuracy: 0.81 - ETA: 3s - loss: 0.5589 - accuracy: 0.81 - ETA: 3s - loss: 0.5528 - accuracy: 0.82 - ETA: 2s - loss: 0.5536 - accuracy: 0.82 - ETA: 2s - loss: 0.5472 - accuracy: 0.82 - ETA: 2s - loss: 0.5532 - accuracy: 0.82 - ETA: 2s - loss: 0.5489 - accuracy: 0.82 - ETA: 2s - loss: 0.5443 - accuracy: 0.82 - ETA: 2s - loss: 0.5452 - accuracy: 0.82 - ETA: 2s - loss: 0.5482 - accuracy: 0.82 - ETA: 2s - loss: 0.5444 - accuracy: 0.82 - ETA: 2s - loss: 0.5463 - accuracy: 0.82 - ETA: 2s - loss: 0.5470 - accuracy: 0.82 - ETA: 2s - loss: 0.5429 - accuracy: 0.82 - ETA: 2s - loss: 0.5509 - accuracy: 0.82 - ETA: 2s - loss: 0.5488 - accuracy: 0.82 - ETA: 2s - loss: 0.5526 - accuracy: 0.82 - ETA: 2s - loss: 0.5524 - accuracy: 0.82 - ETA: 2s - loss: 0.5477 - accuracy: 0.82 - ETA: 2s - loss: 0.5521 - accuracy: 0.82 - ETA: 2s - loss: 0.5539 - accuracy: 0.82 - ETA: 1s - loss: 0.5577 - accuracy: 0.82 - ETA: 1s - loss: 0.5598 - accuracy: 0.82 - ETA: 1s - loss: 0.5649 - accuracy: 0.82 - ETA: 1s - loss: 0.5685 - accuracy: 0.82 - ETA: 1s - loss: 0.5652 - accuracy: 0.82 - ETA: 1s - loss: 0.5648 - accuracy: 0.82 - ETA: 1s - loss: 0.5658 - accuracy: 0.82 - ETA: 1s - loss: 0.5695 - accuracy: 0.82 - ETA: 1s - loss: 0.5695 - accuracy: 0.82 - ETA: 1s - loss: 0.5741 - accuracy: 0.82 - ETA: 1s - loss: 0.5728 - accuracy: 0.82 - ETA: 1s - loss: 0.5760 - accuracy: 0.82 - ETA: 1s - loss: 0.5803 - accuracy: 0.81 - ETA: 1s - loss: 0.5811 - accuracy: 0.81 - ETA: 1s - loss: 0.5799 - accuracy: 0.82 - ETA: 1s - loss: 0.5817 - accuracy: 0.81 - ETA: 1s - loss: 0.5824 - accuracy: 0.81 - ETA: 0s - loss: 0.5818 - accuracy: 0.81 - ETA: 0s - loss: 0.5845 - accuracy: 0.81 - ETA: 0s - loss: 0.5817 - accuracy: 0.81 - ETA: 0s - loss: 0.5825 - accuracy: 0.81 - ETA: 0s - loss: 0.5863 - accuracy: 0.81 - ETA: 0s - loss: 0.5848 - accuracy: 0.81 - ETA: 0s - loss: 0.5865 - accuracy: 0.81 - ETA: 0s - loss: 0.5820 - accuracy: 0.81 - ETA: 0s - loss: 0.5847 - accuracy: 0.81 - ETA: 0s - loss: 0.5841 - accuracy: 0.81 - ETA: 0s - loss: 0.5833 - accuracy: 0.81 - ETA: 0s - loss: 0.5878 - accuracy: 0.81 - ETA: 0s - loss: 0.5867 - accuracy: 0.81 - ETA: 0s - loss: 0.5888 - accuracy: 0.81 - ETA: 0s - loss: 0.5883 - accuracy: 0.81 - ETA: 0s - loss: 0.5877 - accuracy: 0.81 - ETA: 0s - loss: 0.5896 - accuracy: 0.81 - ETA: 0s - loss: 0.5946 - accuracy: 0.81 - 5s 741us/step - loss: 0.5935 - accuracy: 0.8154 - val_loss: 0.6187 - val_accuracy: 0.8132
#
# Epoch 00005: val_loss did not improve from 0.60386
# Epoch 6/20
# 6680/6680 [==============================] - ETA: 4s - loss: 0.3767 - accuracy: 0.85 - ETA: 4s - loss: 0.4366 - accuracy: 0.85 - ETA: 4s - loss: 0.6124 - accuracy: 0.81 - ETA: 4s - loss: 0.5781 - accuracy: 0.82 - ETA: 4s - loss: 0.5369 - accuracy: 0.83 - ETA: 4s - loss: 0.5136 - accuracy: 0.83 - ETA: 4s - loss: 0.5231 - accuracy: 0.83 - ETA: 4s - loss: 0.4946 - accuracy: 0.84 - ETA: 4s - loss: 0.4996 - accuracy: 0.83 - ETA: 4s - loss: 0.5049 - accuracy: 0.84 - ETA: 4s - loss: 0.4968 - accuracy: 0.84 - ETA: 4s - loss: 0.4787 - accuracy: 0.84 - ETA: 4s - loss: 0.4922 - accuracy: 0.84 - ETA: 4s - loss: 0.4899 - accuracy: 0.84 - ETA: 3s - loss: 0.4912 - accuracy: 0.84 - ETA: 3s - loss: 0.4964 - accuracy: 0.83 - ETA: 3s - loss: 0.4914 - accuracy: 0.84 - ETA: 3s - loss: 0.4934 - accuracy: 0.84 - ETA: 3s - loss: 0.5006 - accuracy: 0.83 - ETA: 3s - loss: 0.5032 - accuracy: 0.83 - ETA: 3s - loss: 0.5027 - accuracy: 0.83 - ETA: 3s - loss: 0.5055 - accuracy: 0.83 - ETA: 3s - loss: 0.5010 - accuracy: 0.83 - ETA: 3s - loss: 0.5117 - accuracy: 0.83 - ETA: 3s - loss: 0.5111 - accuracy: 0.83 - ETA: 3s - loss: 0.5150 - accuracy: 0.83 - ETA: 3s - loss: 0.5175 - accuracy: 0.83 - ETA: 3s - loss: 0.5259 - accuracy: 0.83 - ETA: 3s - loss: 0.5274 - accuracy: 0.83 - ETA: 3s - loss: 0.5285 - accuracy: 0.83 - ETA: 3s - loss: 0.5360 - accuracy: 0.83 - ETA: 2s - loss: 0.5325 - accuracy: 0.83 - ETA: 2s - loss: 0.5326 - accuracy: 0.83 - ETA: 2s - loss: 0.5360 - accuracy: 0.83 - ETA: 2s - loss: 0.5398 - accuracy: 0.83 - ETA: 2s - loss: 0.5370 - accuracy: 0.83 - ETA: 2s - loss: 0.5378 - accuracy: 0.83 - ETA: 2s - loss: 0.5344 - accuracy: 0.83 - ETA: 2s - loss: 0.5341 - accuracy: 0.83 - ETA: 2s - loss: 0.5368 - accuracy: 0.83 - ETA: 2s - loss: 0.5334 - accuracy: 0.83 - ETA: 2s - loss: 0.5401 - accuracy: 0.83 - ETA: 2s - loss: 0.5395 - accuracy: 0.83 - ETA: 2s - loss: 0.5373 - accuracy: 0.83 - ETA: 2s - loss: 0.5339 - accuracy: 0.83 - ETA: 2s - loss: 0.5335 - accuracy: 0.83 - ETA: 2s - loss: 0.5330 - accuracy: 0.82 - ETA: 2s - loss: 0.5397 - accuracy: 0.82 - ETA: 2s - loss: 0.5424 - accuracy: 0.82 - ETA: 1s - loss: 0.5397 - accuracy: 0.82 - ETA: 1s - loss: 0.5406 - accuracy: 0.82 - ETA: 1s - loss: 0.5479 - accuracy: 0.82 - ETA: 1s - loss: 0.5473 - accuracy: 0.82 - ETA: 1s - loss: 0.5467 - accuracy: 0.82 - ETA: 1s - loss: 0.5461 - accuracy: 0.82 - ETA: 1s - loss: 0.5470 - accuracy: 0.82 - ETA: 1s - loss: 0.5494 - accuracy: 0.82 - ETA: 1s - loss: 0.5507 - accuracy: 0.82 - ETA: 1s - loss: 0.5523 - accuracy: 0.82 - ETA: 1s - loss: 0.5497 - accuracy: 0.82 - ETA: 1s - loss: 0.5515 - accuracy: 0.82 - ETA: 1s - loss: 0.5525 - accuracy: 0.82 - ETA: 1s - loss: 0.5562 - accuracy: 0.82 - ETA: 1s - loss: 0.5569 - accuracy: 0.82 - ETA: 1s - loss: 0.5594 - accuracy: 0.82 - ETA: 1s - loss: 0.5566 - accuracy: 0.82 - ETA: 0s - loss: 0.5553 - accuracy: 0.82 - ETA: 0s - loss: 0.5585 - accuracy: 0.82 - ETA: 0s - loss: 0.5580 - accuracy: 0.82 - ETA: 0s - loss: 0.5581 - accuracy: 0.82 - ETA: 0s - loss: 0.5611 - accuracy: 0.82 - ETA: 0s - loss: 0.5599 - accuracy: 0.82 - ETA: 0s - loss: 0.5600 - accuracy: 0.82 - ETA: 0s - loss: 0.5585 - accuracy: 0.82 - ETA: 0s - loss: 0.5576 - accuracy: 0.82 - ETA: 0s - loss: 0.5568 - accuracy: 0.82 - ETA: 0s - loss: 0.5588 - accuracy: 0.82 - ETA: 0s - loss: 0.5625 - accuracy: 0.82 - ETA: 0s - loss: 0.5627 - accuracy: 0.82 - ETA: 0s - loss: 0.5667 - accuracy: 0.82 - ETA: 0s - loss: 0.5678 - accuracy: 0.82 - ETA: 0s - loss: 0.5689 - accuracy: 0.82 - ETA: 0s - loss: 0.5704 - accuracy: 0.82 - ETA: 0s - loss: 0.5692 - accuracy: 0.82 - 5s 740us/step - loss: 0.5718 - accuracy: 0.8222 - val_loss: 0.5818 - val_accuracy: 0.8311
#
# Epoch 00006: val_loss improved from 0.60386 to 0.58178, saving model to saved_models/weights.best.Xception.hdf5
# Epoch 7/20
# 6680/6680 [==============================] - ETA: 4s - loss: 0.6182 - accuracy: 0.85 - ETA: 4s - loss: 0.6155 - accuracy: 0.83 - ETA: 4s - loss: 0.5150 - accuracy: 0.86 - ETA: 4s - loss: 0.5299 - accuracy: 0.85 - ETA: 4s - loss: 0.5003 - accuracy: 0.85 - ETA: 4s - loss: 0.4881 - accuracy: 0.85 - ETA: 4s - loss: 0.5012 - accuracy: 0.85 - ETA: 4s - loss: 0.5106 - accuracy: 0.85 - ETA: 4s - loss: 0.5020 - accuracy: 0.85 - ETA: 4s - loss: 0.5172 - accuracy: 0.84 - ETA: 4s - loss: 0.5237 - accuracy: 0.84 - ETA: 4s - loss: 0.5390 - accuracy: 0.84 - ETA: 4s - loss: 0.5347 - accuracy: 0.84 - ETA: 4s - loss: 0.5360 - accuracy: 0.84 - ETA: 3s - loss: 0.5233 - accuracy: 0.84 - ETA: 3s - loss: 0.5203 - accuracy: 0.84 - ETA: 3s - loss: 0.5185 - accuracy: 0.84 - ETA: 3s - loss: 0.5097 - accuracy: 0.85 - ETA: 3s - loss: 0.5137 - accuracy: 0.84 - ETA: 3s - loss: 0.5033 - accuracy: 0.85 - ETA: 3s - loss: 0.4993 - accuracy: 0.85 - ETA: 3s - loss: 0.4995 - accuracy: 0.85 - ETA: 3s - loss: 0.4952 - accuracy: 0.85 - ETA: 3s - loss: 0.4953 - accuracy: 0.85 - ETA: 3s - loss: 0.4929 - accuracy: 0.85 - ETA: 3s - loss: 0.4924 - accuracy: 0.85 - ETA: 3s - loss: 0.4901 - accuracy: 0.85 - ETA: 3s - loss: 0.4885 - accuracy: 0.85 - ETA: 3s - loss: 0.4923 - accuracy: 0.85 - ETA: 3s - loss: 0.4926 - accuracy: 0.85 - ETA: 3s - loss: 0.4954 - accuracy: 0.85 - ETA: 2s - loss: 0.5011 - accuracy: 0.84 - ETA: 2s - loss: 0.4981 - accuracy: 0.85 - ETA: 2s - loss: 0.4979 - accuracy: 0.85 - ETA: 2s - loss: 0.5024 - accuracy: 0.84 - ETA: 2s - loss: 0.5045 - accuracy: 0.84 - ETA: 2s - loss: 0.5042 - accuracy: 0.84 - ETA: 2s - loss: 0.5048 - accuracy: 0.84 - ETA: 2s - loss: 0.4999 - accuracy: 0.84 - ETA: 2s - loss: 0.5004 - accuracy: 0.84 - ETA: 2s - loss: 0.5016 - accuracy: 0.84 - ETA: 2s - loss: 0.5009 - accuracy: 0.84 - ETA: 2s - loss: 0.4988 - accuracy: 0.84 - ETA: 2s - loss: 0.4947 - accuracy: 0.85 - ETA: 2s - loss: 0.4949 - accuracy: 0.85 - ETA: 2s - loss: 0.4934 - accuracy: 0.84 - ETA: 2s - loss: 0.4885 - accuracy: 0.85 - ETA: 2s - loss: 0.4922 - accuracy: 0.84 - ETA: 2s - loss: 0.4906 - accuracy: 0.84 - ETA: 1s - loss: 0.4901 - accuracy: 0.85 - ETA: 1s - loss: 0.4926 - accuracy: 0.84 - ETA: 1s - loss: 0.4948 - accuracy: 0.84 - ETA: 1s - loss: 0.4970 - accuracy: 0.84 - ETA: 1s - loss: 0.4952 - accuracy: 0.84 - ETA: 1s - loss: 0.4929 - accuracy: 0.84 - ETA: 1s - loss: 0.4896 - accuracy: 0.85 - ETA: 1s - loss: 0.4893 - accuracy: 0.85 - ETA: 1s - loss: 0.4899 - accuracy: 0.84 - ETA: 1s - loss: 0.4876 - accuracy: 0.84 - ETA: 1s - loss: 0.4839 - accuracy: 0.85 - ETA: 1s - loss: 0.4856 - accuracy: 0.84 - ETA: 1s - loss: 0.4872 - accuracy: 0.85 - ETA: 1s - loss: 0.4853 - accuracy: 0.85 - ETA: 1s - loss: 0.4851 - accuracy: 0.84 - ETA: 1s - loss: 0.4867 - accuracy: 0.84 - ETA: 1s - loss: 0.4861 - accuracy: 0.84 - ETA: 0s - loss: 0.4861 - accuracy: 0.84 - ETA: 0s - loss: 0.4841 - accuracy: 0.84 - ETA: 0s - loss: 0.4851 - accuracy: 0.84 - ETA: 0s - loss: 0.4842 - accuracy: 0.84 - ETA: 0s - loss: 0.4833 - accuracy: 0.84 - ETA: 0s - loss: 0.4816 - accuracy: 0.84 - ETA: 0s - loss: 0.4809 - accuracy: 0.85 - ETA: 0s - loss: 0.4812 - accuracy: 0.85 - ETA: 0s - loss: 0.4825 - accuracy: 0.85 - ETA: 0s - loss: 0.4844 - accuracy: 0.85 - ETA: 0s - loss: 0.4877 - accuracy: 0.84 - ETA: 0s - loss: 0.4841 - accuracy: 0.85 - ETA: 0s - loss: 0.4838 - accuracy: 0.85 - ETA: 0s - loss: 0.4852 - accuracy: 0.85 - ETA: 0s - loss: 0.4848 - accuracy: 0.85 - ETA: 0s - loss: 0.4858 - accuracy: 0.85 - ETA: 0s - loss: 0.4891 - accuracy: 0.85 - ETA: 0s - loss: 0.4865 - accuracy: 0.85 - 5s 739us/step - loss: 0.4862 - accuracy: 0.8509 - val_loss: 0.6402 - val_accuracy: 0.8192
#
# Epoch 00007: val_loss did not improve from 0.58178
# Epoch 8/20
# 6680/6680 [==============================] - ETA: 4s - loss: 0.3254 - accuracy: 0.90 - ETA: 4s - loss: 0.4548 - accuracy: 0.84 - ETA: 4s - loss: 0.4516 - accuracy: 0.84 - ETA: 4s - loss: 0.4414 - accuracy: 0.85 - ETA: 4s - loss: 0.4616 - accuracy: 0.84 - ETA: 4s - loss: 0.4470 - accuracy: 0.85 - ETA: 4s - loss: 0.4477 - accuracy: 0.84 - ETA: 4s - loss: 0.4322 - accuracy: 0.85 - ETA: 4s - loss: 0.4126 - accuracy: 0.85 - ETA: 4s - loss: 0.4133 - accuracy: 0.85 - ETA: 4s - loss: 0.4055 - accuracy: 0.85 - ETA: 4s - loss: 0.3996 - accuracy: 0.86 - ETA: 4s - loss: 0.3964 - accuracy: 0.86 - ETA: 3s - loss: 0.4000 - accuracy: 0.86 - ETA: 3s - loss: 0.4028 - accuracy: 0.86 - ETA: 3s - loss: 0.4006 - accuracy: 0.86 - ETA: 3s - loss: 0.4057 - accuracy: 0.86 - ETA: 3s - loss: 0.4044 - accuracy: 0.86 - ETA: 3s - loss: 0.4069 - accuracy: 0.86 - ETA: 3s - loss: 0.4216 - accuracy: 0.85 - ETA: 3s - loss: 0.4157 - accuracy: 0.86 - ETA: 3s - loss: 0.4344 - accuracy: 0.85 - ETA: 3s - loss: 0.4362 - accuracy: 0.85 - ETA: 3s - loss: 0.4397 - accuracy: 0.85 - ETA: 3s - loss: 0.4422 - accuracy: 0.85 - ETA: 3s - loss: 0.4365 - accuracy: 0.85 - ETA: 3s - loss: 0.4418 - accuracy: 0.85 - ETA: 3s - loss: 0.4485 - accuracy: 0.85 - ETA: 3s - loss: 0.4638 - accuracy: 0.85 - ETA: 3s - loss: 0.4687 - accuracy: 0.84 - ETA: 3s - loss: 0.4712 - accuracy: 0.84 - ETA: 2s - loss: 0.4721 - accuracy: 0.84 - ETA: 2s - loss: 0.4713 - accuracy: 0.84 - ETA: 2s - loss: 0.4725 - accuracy: 0.84 - ETA: 2s - loss: 0.4733 - accuracy: 0.84 - ETA: 2s - loss: 0.4638 - accuracy: 0.84 - ETA: 2s - loss: 0.4657 - accuracy: 0.84 - ETA: 2s - loss: 0.4646 - accuracy: 0.84 - ETA: 2s - loss: 0.4671 - accuracy: 0.84 - ETA: 2s - loss: 0.4686 - accuracy: 0.84 - ETA: 2s - loss: 0.4750 - accuracy: 0.84 - ETA: 2s - loss: 0.4752 - accuracy: 0.84 - ETA: 2s - loss: 0.4744 - accuracy: 0.84 - ETA: 2s - loss: 0.4743 - accuracy: 0.84 - ETA: 2s - loss: 0.4746 - accuracy: 0.84 - ETA: 2s - loss: 0.4746 - accuracy: 0.84 - ETA: 2s - loss: 0.4769 - accuracy: 0.84 - ETA: 2s - loss: 0.4759 - accuracy: 0.84 - ETA: 2s - loss: 0.4746 - accuracy: 0.84 - ETA: 1s - loss: 0.4728 - accuracy: 0.84 - ETA: 1s - loss: 0.4734 - accuracy: 0.84 - ETA: 1s - loss: 0.4716 - accuracy: 0.84 - ETA: 1s - loss: 0.4721 - accuracy: 0.84 - ETA: 1s - loss: 0.4714 - accuracy: 0.84 - ETA: 1s - loss: 0.4730 - accuracy: 0.84 - ETA: 1s - loss: 0.4707 - accuracy: 0.84 - ETA: 1s - loss: 0.4699 - accuracy: 0.84 - ETA: 1s - loss: 0.4724 - accuracy: 0.84 - ETA: 1s - loss: 0.4715 - accuracy: 0.84 - ETA: 1s - loss: 0.4703 - accuracy: 0.84 - ETA: 1s - loss: 0.4688 - accuracy: 0.84 - ETA: 1s - loss: 0.4688 - accuracy: 0.84 - ETA: 1s - loss: 0.4676 - accuracy: 0.84 - ETA: 1s - loss: 0.4677 - accuracy: 0.84 - ETA: 1s - loss: 0.4720 - accuracy: 0.84 - ETA: 1s - loss: 0.4736 - accuracy: 0.84 - ETA: 0s - loss: 0.4772 - accuracy: 0.84 - ETA: 0s - loss: 0.4747 - accuracy: 0.84 - ETA: 0s - loss: 0.4755 - accuracy: 0.84 - ETA: 0s - loss: 0.4750 - accuracy: 0.84 - ETA: 0s - loss: 0.4768 - accuracy: 0.84 - ETA: 0s - loss: 0.4780 - accuracy: 0.84 - ETA: 0s - loss: 0.4830 - accuracy: 0.84 - ETA: 0s - loss: 0.4813 - accuracy: 0.84 - ETA: 0s - loss: 0.4787 - accuracy: 0.84 - ETA: 0s - loss: 0.4785 - accuracy: 0.84 - ETA: 0s - loss: 0.4791 - accuracy: 0.84 - ETA: 0s - loss: 0.4790 - accuracy: 0.84 - ETA: 0s - loss: 0.4813 - accuracy: 0.84 - ETA: 0s - loss: 0.4834 - accuracy: 0.84 - ETA: 0s - loss: 0.4846 - accuracy: 0.84 - ETA: 0s - loss: 0.4862 - accuracy: 0.84 - ETA: 0s - loss: 0.4851 - accuracy: 0.84 - ETA: 0s - loss: 0.4831 - accuracy: 0.84 - 5s 740us/step - loss: 0.4826 - accuracy: 0.8500 - val_loss: 0.6356 - val_accuracy: 0.8240
#
# Epoch 00008: val_loss did not improve from 0.58178
# Epoch 9/20
# 6680/6680 [==============================] - ETA: 4s - loss: 0.8899 - accuracy: 0.75 - ETA: 4s - loss: 0.4330 - accuracy: 0.86 - ETA: 4s - loss: 0.5740 - accuracy: 0.85 - ETA: 4s - loss: 0.5285 - accuracy: 0.86 - ETA: 4s - loss: 0.4521 - accuracy: 0.87 - ETA: 4s - loss: 0.4343 - accuracy: 0.88 - ETA: 4s - loss: 0.4226 - accuracy: 0.88 - ETA: 4s - loss: 0.4088 - accuracy: 0.87 - ETA: 4s - loss: 0.3888 - accuracy: 0.88 - ETA: 4s - loss: 0.4027 - accuracy: 0.88 - ETA: 4s - loss: 0.3923 - accuracy: 0.88 - ETA: 4s - loss: 0.3842 - accuracy: 0.88 - ETA: 4s - loss: 0.3803 - accuracy: 0.88 - ETA: 4s - loss: 0.3845 - accuracy: 0.87 - ETA: 3s - loss: 0.3889 - accuracy: 0.87 - ETA: 3s - loss: 0.3794 - accuracy: 0.88 - ETA: 3s - loss: 0.3788 - accuracy: 0.87 - ETA: 3s - loss: 0.3916 - accuracy: 0.87 - ETA: 3s - loss: 0.3959 - accuracy: 0.87 - ETA: 3s - loss: 0.3932 - accuracy: 0.87 - ETA: 3s - loss: 0.3991 - accuracy: 0.87 - ETA: 3s - loss: 0.3902 - accuracy: 0.87 - ETA: 3s - loss: 0.4057 - accuracy: 0.87 - ETA: 3s - loss: 0.4105 - accuracy: 0.87 - ETA: 3s - loss: 0.4107 - accuracy: 0.87 - ETA: 3s - loss: 0.4090 - accuracy: 0.87 - ETA: 3s - loss: 0.4077 - accuracy: 0.87 - ETA: 3s - loss: 0.4102 - accuracy: 0.87 - ETA: 3s - loss: 0.4086 - accuracy: 0.87 - ETA: 3s - loss: 0.4112 - accuracy: 0.87 - ETA: 3s - loss: 0.4136 - accuracy: 0.87 - ETA: 2s - loss: 0.4130 - accuracy: 0.87 - ETA: 2s - loss: 0.4166 - accuracy: 0.87 - ETA: 2s - loss: 0.4156 - accuracy: 0.87 - ETA: 2s - loss: 0.4124 - accuracy: 0.87 - ETA: 2s - loss: 0.4143 - accuracy: 0.87 - ETA: 2s - loss: 0.4168 - accuracy: 0.87 - ETA: 2s - loss: 0.4215 - accuracy: 0.87 - ETA: 2s - loss: 0.4237 - accuracy: 0.87 - ETA: 2s - loss: 0.4256 - accuracy: 0.87 - ETA: 2s - loss: 0.4283 - accuracy: 0.87 - ETA: 2s - loss: 0.4357 - accuracy: 0.86 - ETA: 2s - loss: 0.4405 - accuracy: 0.86 - ETA: 2s - loss: 0.4406 - accuracy: 0.86 - ETA: 2s - loss: 0.4379 - accuracy: 0.86 - ETA: 2s - loss: 0.4431 - accuracy: 0.86 - ETA: 2s - loss: 0.4418 - accuracy: 0.86 - ETA: 2s - loss: 0.4392 - accuracy: 0.86 - ETA: 2s - loss: 0.4368 - accuracy: 0.86 - ETA: 1s - loss: 0.4364 - accuracy: 0.86 - ETA: 1s - loss: 0.4356 - accuracy: 0.86 - ETA: 1s - loss: 0.4367 - accuracy: 0.86 - ETA: 1s - loss: 0.4335 - accuracy: 0.86 - ETA: 1s - loss: 0.4342 - accuracy: 0.86 - ETA: 1s - loss: 0.4390 - accuracy: 0.86 - ETA: 1s - loss: 0.4355 - accuracy: 0.86 - ETA: 1s - loss: 0.4351 - accuracy: 0.86 - ETA: 1s - loss: 0.4364 - accuracy: 0.86 - ETA: 1s - loss: 0.4333 - accuracy: 0.86 - ETA: 1s - loss: 0.4350 - accuracy: 0.86 - ETA: 1s - loss: 0.4345 - accuracy: 0.86 - ETA: 1s - loss: 0.4340 - accuracy: 0.86 - ETA: 1s - loss: 0.4359 - accuracy: 0.86 - ETA: 1s - loss: 0.4411 - accuracy: 0.86 - ETA: 1s - loss: 0.4379 - accuracy: 0.86 - ETA: 1s - loss: 0.4395 - accuracy: 0.86 - ETA: 0s - loss: 0.4384 - accuracy: 0.86 - ETA: 0s - loss: 0.4408 - accuracy: 0.86 - ETA: 0s - loss: 0.4381 - accuracy: 0.86 - ETA: 0s - loss: 0.4394 - accuracy: 0.86 - ETA: 0s - loss: 0.4414 - accuracy: 0.86 - ETA: 0s - loss: 0.4398 - accuracy: 0.86 - ETA: 0s - loss: 0.4398 - accuracy: 0.86 - ETA: 0s - loss: 0.4429 - accuracy: 0.86 - ETA: 0s - loss: 0.4420 - accuracy: 0.86 - ETA: 0s - loss: 0.4428 - accuracy: 0.86 - ETA: 0s - loss: 0.4440 - accuracy: 0.86 - ETA: 0s - loss: 0.4457 - accuracy: 0.86 - ETA: 0s - loss: 0.4426 - accuracy: 0.86 - ETA: 0s - loss: 0.4421 - accuracy: 0.86 - ETA: 0s - loss: 0.4429 - accuracy: 0.86 - ETA: 0s - loss: 0.4424 - accuracy: 0.86 - ETA: 0s - loss: 0.4443 - accuracy: 0.86 - ETA: 0s - loss: 0.4430 - accuracy: 0.86 - 5s 740us/step - loss: 0.4423 - accuracy: 0.8647 - val_loss: 0.5473 - val_accuracy: 0.8443
#
# Epoch 00009: val_loss improved from 0.58178 to 0.54728, saving model to saved_models/weights.best.Xception.hdf5
# Epoch 10/20
# 6680/6680 [==============================] - ETA: 4s - loss: 0.4558 - accuracy: 0.90 - ETA: 4s - loss: 0.3236 - accuracy: 0.91 - ETA: 4s - loss: 0.3397 - accuracy: 0.90 - ETA: 4s - loss: 0.3320 - accuracy: 0.90 - ETA: 4s - loss: 0.3701 - accuracy: 0.88 - ETA: 4s - loss: 0.3776 - accuracy: 0.87 - ETA: 4s - loss: 0.3522 - accuracy: 0.88 - ETA: 4s - loss: 0.3786 - accuracy: 0.87 - ETA: 4s - loss: 0.3839 - accuracy: 0.87 - ETA: 4s - loss: 0.3802 - accuracy: 0.87 - ETA: 4s - loss: 0.3872 - accuracy: 0.87 - ETA: 4s - loss: 0.3862 - accuracy: 0.87 - ETA: 4s - loss: 0.3970 - accuracy: 0.88 - ETA: 4s - loss: 0.4172 - accuracy: 0.88 - ETA: 3s - loss: 0.4187 - accuracy: 0.88 - ETA: 3s - loss: 0.4141 - accuracy: 0.88 - ETA: 3s - loss: 0.4001 - accuracy: 0.88 - ETA: 3s - loss: 0.4053 - accuracy: 0.88 - ETA: 3s - loss: 0.4158 - accuracy: 0.87 - ETA: 3s - loss: 0.4136 - accuracy: 0.87 - ETA: 3s - loss: 0.4139 - accuracy: 0.87 - ETA: 3s - loss: 0.4078 - accuracy: 0.88 - ETA: 3s - loss: 0.4116 - accuracy: 0.88 - ETA: 3s - loss: 0.4173 - accuracy: 0.87 - ETA: 3s - loss: 0.4076 - accuracy: 0.88 - ETA: 3s - loss: 0.4071 - accuracy: 0.88 - ETA: 3s - loss: 0.4082 - accuracy: 0.87 - ETA: 3s - loss: 0.4099 - accuracy: 0.87 - ETA: 3s - loss: 0.4057 - accuracy: 0.88 - ETA: 3s - loss: 0.4026 - accuracy: 0.88 - ETA: 3s - loss: 0.4027 - accuracy: 0.87 - ETA: 2s - loss: 0.4044 - accuracy: 0.87 - ETA: 2s - loss: 0.4076 - accuracy: 0.87 - ETA: 2s - loss: 0.4119 - accuracy: 0.87 - ETA: 2s - loss: 0.4148 - accuracy: 0.87 - ETA: 2s - loss: 0.4128 - accuracy: 0.87 - ETA: 2s - loss: 0.4131 - accuracy: 0.87 - ETA: 2s - loss: 0.4100 - accuracy: 0.87 - ETA: 2s - loss: 0.4120 - accuracy: 0.87 - ETA: 2s - loss: 0.4111 - accuracy: 0.87 - ETA: 2s - loss: 0.4119 - accuracy: 0.87 - ETA: 2s - loss: 0.4089 - accuracy: 0.87 - ETA: 2s - loss: 0.4099 - accuracy: 0.87 - ETA: 2s - loss: 0.4064 - accuracy: 0.87 - ETA: 2s - loss: 0.4032 - accuracy: 0.87 - ETA: 2s - loss: 0.4099 - accuracy: 0.87 - ETA: 2s - loss: 0.4084 - accuracy: 0.87 - ETA: 2s - loss: 0.4133 - accuracy: 0.87 - ETA: 2s - loss: 0.4125 - accuracy: 0.87 - ETA: 1s - loss: 0.4127 - accuracy: 0.87 - ETA: 1s - loss: 0.4119 - accuracy: 0.87 - ETA: 1s - loss: 0.4105 - accuracy: 0.87 - ETA: 1s - loss: 0.4094 - accuracy: 0.87 - ETA: 1s - loss: 0.4106 - accuracy: 0.87 - ETA: 1s - loss: 0.4094 - accuracy: 0.87 - ETA: 1s - loss: 0.4086 - accuracy: 0.87 - ETA: 1s - loss: 0.4114 - accuracy: 0.87 - ETA: 1s - loss: 0.4129 - accuracy: 0.87 - ETA: 1s - loss: 0.4117 - accuracy: 0.87 - ETA: 1s - loss: 0.4124 - accuracy: 0.87 - ETA: 1s - loss: 0.4116 - accuracy: 0.87 - ETA: 1s - loss: 0.4112 - accuracy: 0.87 - ETA: 1s - loss: 0.4104 - accuracy: 0.87 - ETA: 1s - loss: 0.4087 - accuracy: 0.87 - ETA: 1s - loss: 0.4086 - accuracy: 0.87 - ETA: 1s - loss: 0.4096 - accuracy: 0.87 - ETA: 0s - loss: 0.4112 - accuracy: 0.87 - ETA: 0s - loss: 0.4094 - accuracy: 0.87 - ETA: 0s - loss: 0.4065 - accuracy: 0.87 - ETA: 0s - loss: 0.4079 - accuracy: 0.87 - ETA: 0s - loss: 0.4068 - accuracy: 0.87 - ETA: 0s - loss: 0.4063 - accuracy: 0.87 - ETA: 0s - loss: 0.4061 - accuracy: 0.87 - ETA: 0s - loss: 0.4102 - accuracy: 0.87 - ETA: 0s - loss: 0.4109 - accuracy: 0.87 - ETA: 0s - loss: 0.4088 - accuracy: 0.87 - ETA: 0s - loss: 0.4108 - accuracy: 0.87 - ETA: 0s - loss: 0.4110 - accuracy: 0.87 - ETA: 0s - loss: 0.4099 - accuracy: 0.87 - ETA: 0s - loss: 0.4090 - accuracy: 0.87 - ETA: 0s - loss: 0.4071 - accuracy: 0.87 - ETA: 0s - loss: 0.4062 - accuracy: 0.87 - ETA: 0s - loss: 0.4058 - accuracy: 0.87 - ETA: 0s - loss: 0.4072 - accuracy: 0.87 - 5s 740us/step - loss: 0.4069 - accuracy: 0.8726 - val_loss: 0.6318 - val_accuracy: 0.8287
#
# Epoch 00010: val_loss did not improve from 0.54728
# Epoch 11/20
# 6680/6680 [==============================] - ETA: 4s - loss: 0.5495 - accuracy: 0.90 - ETA: 4s - loss: 0.2813 - accuracy: 0.91 - ETA: 4s - loss: 0.2753 - accuracy: 0.92 - ETA: 4s - loss: 0.2916 - accuracy: 0.90 - ETA: 4s - loss: 0.2959 - accuracy: 0.90 - ETA: 4s - loss: 0.2922 - accuracy: 0.89 - ETA: 4s - loss: 0.3166 - accuracy: 0.89 - ETA: 4s - loss: 0.3078 - accuracy: 0.89 - ETA: 4s - loss: 0.3054 - accuracy: 0.89 - ETA: 4s - loss: 0.2899 - accuracy: 0.90 - ETA: 4s - loss: 0.2878 - accuracy: 0.89 - ETA: 4s - loss: 0.2815 - accuracy: 0.89 - ETA: 4s - loss: 0.2891 - accuracy: 0.89 - ETA: 4s - loss: 0.2865 - accuracy: 0.89 - ETA: 3s - loss: 0.2844 - accuracy: 0.89 - ETA: 3s - loss: 0.2905 - accuracy: 0.89 - ETA: 3s - loss: 0.3047 - accuracy: 0.89 - ETA: 3s - loss: 0.3126 - accuracy: 0.89 - ETA: 3s - loss: 0.3263 - accuracy: 0.88 - ETA: 3s - loss: 0.3262 - accuracy: 0.88 - ETA: 3s - loss: 0.3212 - accuracy: 0.89 - ETA: 3s - loss: 0.3252 - accuracy: 0.89 - ETA: 3s - loss: 0.3276 - accuracy: 0.89 - ETA: 3s - loss: 0.3289 - accuracy: 0.89 - ETA: 3s - loss: 0.3357 - accuracy: 0.88 - ETA: 3s - loss: 0.3327 - accuracy: 0.89 - ETA: 3s - loss: 0.3408 - accuracy: 0.89 - ETA: 3s - loss: 0.3489 - accuracy: 0.88 - ETA: 3s - loss: 0.3533 - accuracy: 0.88 - ETA: 3s - loss: 0.3527 - accuracy: 0.88 - ETA: 3s - loss: 0.3515 - accuracy: 0.88 - ETA: 2s - loss: 0.3519 - accuracy: 0.88 - ETA: 2s - loss: 0.3486 - accuracy: 0.88 - ETA: 2s - loss: 0.3513 - accuracy: 0.88 - ETA: 2s - loss: 0.3547 - accuracy: 0.88 - ETA: 2s - loss: 0.3521 - accuracy: 0.88 - ETA: 2s - loss: 0.3497 - accuracy: 0.88 - ETA: 2s - loss: 0.3511 - accuracy: 0.88 - ETA: 2s - loss: 0.3500 - accuracy: 0.88 - ETA: 2s - loss: 0.3494 - accuracy: 0.88 - ETA: 2s - loss: 0.3542 - accuracy: 0.88 - ETA: 2s - loss: 0.3551 - accuracy: 0.88 - ETA: 2s - loss: 0.3554 - accuracy: 0.88 - ETA: 2s - loss: 0.3590 - accuracy: 0.88 - ETA: 2s - loss: 0.3582 - accuracy: 0.88 - ETA: 2s - loss: 0.3561 - accuracy: 0.88 - ETA: 2s - loss: 0.3616 - accuracy: 0.88 - ETA: 2s - loss: 0.3631 - accuracy: 0.88 - ETA: 2s - loss: 0.3591 - accuracy: 0.88 - ETA: 1s - loss: 0.3612 - accuracy: 0.88 - ETA: 1s - loss: 0.3598 - accuracy: 0.88 - ETA: 1s - loss: 0.3568 - accuracy: 0.88 - ETA: 1s - loss: 0.3571 - accuracy: 0.88 - ETA: 1s - loss: 0.3570 - accuracy: 0.88 - ETA: 1s - loss: 0.3564 - accuracy: 0.88 - ETA: 1s - loss: 0.3543 - accuracy: 0.88 - ETA: 1s - loss: 0.3560 - accuracy: 0.88 - ETA: 1s - loss: 0.3561 - accuracy: 0.88 - ETA: 1s - loss: 0.3560 - accuracy: 0.88 - ETA: 1s - loss: 0.3572 - accuracy: 0.88 - ETA: 1s - loss: 0.3601 - accuracy: 0.88 - ETA: 1s - loss: 0.3587 - accuracy: 0.88 - ETA: 1s - loss: 0.3576 - accuracy: 0.88 - ETA: 1s - loss: 0.3583 - accuracy: 0.88 - ETA: 1s - loss: 0.3598 - accuracy: 0.88 - ETA: 1s - loss: 0.3654 - accuracy: 0.88 - ETA: 0s - loss: 0.3638 - accuracy: 0.88 - ETA: 0s - loss: 0.3633 - accuracy: 0.88 - ETA: 0s - loss: 0.3610 - accuracy: 0.88 - ETA: 0s - loss: 0.3661 - accuracy: 0.88 - ETA: 0s - loss: 0.3696 - accuracy: 0.88 - ETA: 0s - loss: 0.3692 - accuracy: 0.88 - ETA: 0s - loss: 0.3686 - accuracy: 0.88 - ETA: 0s - loss: 0.3684 - accuracy: 0.88 - ETA: 0s - loss: 0.3706 - accuracy: 0.88 - ETA: 0s - loss: 0.3694 - accuracy: 0.88 - ETA: 0s - loss: 0.3688 - accuracy: 0.88 - ETA: 0s - loss: 0.3690 - accuracy: 0.88 - ETA: 0s - loss: 0.3688 - accuracy: 0.88 - ETA: 0s - loss: 0.3713 - accuracy: 0.88 - ETA: 0s - loss: 0.3734 - accuracy: 0.88 - ETA: 0s - loss: 0.3790 - accuracy: 0.88 - ETA: 0s - loss: 0.3809 - accuracy: 0.87 - ETA: 0s - loss: 0.3809 - accuracy: 0.87 - 5s 741us/step - loss: 0.3815 - accuracy: 0.8796 - val_loss: 0.6283 - val_accuracy: 0.8359
#
# Epoch 00011: val_loss did not improve from 0.54728
# Epoch 12/20
# 6680/6680 [==============================] - ETA: 4s - loss: 0.3284 - accuracy: 0.80 - ETA: 4s - loss: 0.3076 - accuracy: 0.88 - ETA: 4s - loss: 0.3304 - accuracy: 0.88 - ETA: 4s - loss: 0.3887 - accuracy: 0.86 - ETA: 4s - loss: 0.3867 - accuracy: 0.86 - ETA: 4s - loss: 0.3933 - accuracy: 0.86 - ETA: 4s - loss: 0.3833 - accuracy: 0.86 - ETA: 4s - loss: 0.3865 - accuracy: 0.86 - ETA: 4s - loss: 0.3737 - accuracy: 0.86 - ETA: 4s - loss: 0.3729 - accuracy: 0.87 - ETA: 4s - loss: 0.3669 - accuracy: 0.86 - ETA: 4s - loss: 0.3944 - accuracy: 0.86 - ETA: 4s - loss: 0.3977 - accuracy: 0.86 - ETA: 3s - loss: 0.3977 - accuracy: 0.86 - ETA: 3s - loss: 0.3873 - accuracy: 0.86 - ETA: 3s - loss: 0.3783 - accuracy: 0.87 - ETA: 3s - loss: 0.3817 - accuracy: 0.87 - ETA: 3s - loss: 0.3813 - accuracy: 0.87 - ETA: 3s - loss: 0.3847 - accuracy: 0.87 - ETA: 3s - loss: 0.3795 - accuracy: 0.87 - ETA: 3s - loss: 0.3743 - accuracy: 0.87 - ETA: 3s - loss: 0.3688 - accuracy: 0.87 - ETA: 3s - loss: 0.3741 - accuracy: 0.87 - ETA: 3s - loss: 0.3768 - accuracy: 0.87 - ETA: 3s - loss: 0.3820 - accuracy: 0.87 - ETA: 3s - loss: 0.3805 - accuracy: 0.87 - ETA: 3s - loss: 0.3784 - accuracy: 0.87 - ETA: 3s - loss: 0.3768 - accuracy: 0.87 - ETA: 3s - loss: 0.3749 - accuracy: 0.87 - ETA: 3s - loss: 0.3896 - accuracy: 0.87 - ETA: 3s - loss: 0.3916 - accuracy: 0.87 - ETA: 2s - loss: 0.3974 - accuracy: 0.87 - ETA: 2s - loss: 0.3945 - accuracy: 0.87 - ETA: 2s - loss: 0.3985 - accuracy: 0.87 - ETA: 2s - loss: 0.3948 - accuracy: 0.87 - ETA: 2s - loss: 0.3945 - accuracy: 0.87 - ETA: 2s - loss: 0.3902 - accuracy: 0.87 - ETA: 2s - loss: 0.3841 - accuracy: 0.87 - ETA: 2s - loss: 0.3814 - accuracy: 0.87 - ETA: 2s - loss: 0.3805 - accuracy: 0.87 - ETA: 2s - loss: 0.3786 - accuracy: 0.87 - ETA: 2s - loss: 0.3789 - accuracy: 0.87 - ETA: 2s - loss: 0.3750 - accuracy: 0.88 - ETA: 2s - loss: 0.3739 - accuracy: 0.88 - ETA: 2s - loss: 0.3729 - accuracy: 0.88 - ETA: 2s - loss: 0.3733 - accuracy: 0.88 - ETA: 2s - loss: 0.3690 - accuracy: 0.88 - ETA: 2s - loss: 0.3726 - accuracy: 0.88 - ETA: 2s - loss: 0.3720 - accuracy: 0.87 - ETA: 1s - loss: 0.3800 - accuracy: 0.87 - ETA: 1s - loss: 0.3838 - accuracy: 0.87 - ETA: 1s - loss: 0.3813 - accuracy: 0.87 - ETA: 1s - loss: 0.3845 - accuracy: 0.87 - ETA: 1s - loss: 0.3835 - accuracy: 0.87 - ETA: 1s - loss: 0.3847 - accuracy: 0.87 - ETA: 1s - loss: 0.3830 - accuracy: 0.87 - ETA: 1s - loss: 0.3835 - accuracy: 0.87 - ETA: 1s - loss: 0.3839 - accuracy: 0.87 - ETA: 1s - loss: 0.3822 - accuracy: 0.87 - ETA: 1s - loss: 0.3810 - accuracy: 0.87 - ETA: 1s - loss: 0.3798 - accuracy: 0.87 - ETA: 1s - loss: 0.3788 - accuracy: 0.87 - ETA: 1s - loss: 0.3818 - accuracy: 0.87 - ETA: 1s - loss: 0.3812 - accuracy: 0.87 - ETA: 1s - loss: 0.3813 - accuracy: 0.87 - ETA: 1s - loss: 0.3846 - accuracy: 0.87 - ETA: 0s - loss: 0.3839 - accuracy: 0.87 - ETA: 0s - loss: 0.3881 - accuracy: 0.87 - ETA: 0s - loss: 0.3890 - accuracy: 0.87 - ETA: 0s - loss: 0.3893 - accuracy: 0.87 - ETA: 0s - loss: 0.3894 - accuracy: 0.87 - ETA: 0s - loss: 0.3897 - accuracy: 0.87 - ETA: 0s - loss: 0.3887 - accuracy: 0.87 - ETA: 0s - loss: 0.3924 - accuracy: 0.87 - ETA: 0s - loss: 0.3954 - accuracy: 0.87 - ETA: 0s - loss: 0.3944 - accuracy: 0.87 - ETA: 0s - loss: 0.3946 - accuracy: 0.87 - ETA: 0s - loss: 0.3967 - accuracy: 0.87 - ETA: 0s - loss: 0.3968 - accuracy: 0.87 - ETA: 0s - loss: 0.4017 - accuracy: 0.87 - ETA: 0s - loss: 0.4030 - accuracy: 0.87 - ETA: 0s - loss: 0.4038 - accuracy: 0.87 - ETA: 0s - loss: 0.4059 - accuracy: 0.87 - ETA: 0s - loss: 0.4064 - accuracy: 0.87 - 5s 739us/step - loss: 0.4059 - accuracy: 0.8734 - val_loss: 0.7000 - val_accuracy: 0.8192
#
# Epoch 00012: val_loss did not improve from 0.54728
# Epoch 13/20
# ...
#
# Epoch 00016: val_loss did not improve from 0.54728
# Epoch 17/20
# 6680/6680 [==============================] - ETA: 4s - loss: 0.4567 - accuracy: 0.90 - ETA: 4s - loss: 0.3336 - accuracy: 0.89 - ETA: 4s - loss: 0.2541 - accuracy: 0.91 - ETA: 4s - loss: 0.2517 - accuracy: 0.91 - ETA: 4s - loss: 0.2775 - accuracy: 0.91 - ETA: 4s - loss: 0.2833 - accuracy: 0.91 - ETA: 4s - loss: 0.2694 - accuracy: 0.91 - ETA: 4s - loss: 0.2882 - accuracy: 0.91 - ETA: 4s - loss: 0.2988 - accuracy: 0.90 - ETA: 4s - loss: 0.2743 - accuracy: 0.91 - ETA: 4s - loss: 0.2782 - accuracy: 0.91 - ETA: 4s - loss: 0.2903 - accuracy: 0.91 - ETA: 4s - loss: 0.2963 - accuracy: 0.91 - ETA: 4s - loss: 0.2966 - accuracy: 0.91 - ETA: 3s - loss: 0.3176 - accuracy: 0.90 - ETA: 3s - loss: 0.3181 - accuracy: 0.90 - ETA: 3s - loss: 0.3116 - accuracy: 0.90 - ETA: 3s - loss: 0.3018 - accuracy: 0.91 - ETA: 3s - loss: 0.3046 - accuracy: 0.90 - ETA: 3s - loss: 0.3057 - accuracy: 0.90 - ETA: 3s - loss: 0.3040 - accuracy: 0.90 - ETA: 3s - loss: 0.3087 - accuracy: 0.90 - ETA: 3s - loss: 0.3014 - accuracy: 0.90 - ETA: 3s - loss: 0.3095 - accuracy: 0.90 - ETA: 3s - loss: 0.3129 - accuracy: 0.90 - ETA: 3s - loss: 0.3173 - accuracy: 0.90 - ETA: 3s - loss: 0.3191 - accuracy: 0.90 - ETA: 3s - loss: 0.3222 - accuracy: 0.90 - ETA: 3s - loss: 0.3215 - accuracy: 0.90 - ETA: 3s - loss: 0.3255 - accuracy: 0.90 - ETA: 3s - loss: 0.3263 - accuracy: 0.90 - ETA: 2s - loss: 0.3204 - accuracy: 0.90 - ETA: 2s - loss: 0.3251 - accuracy: 0.90 - ETA: 2s - loss: 0.3222 - accuracy: 0.90 - ETA: 2s - loss: 0.3307 - accuracy: 0.90 - ETA: 2s - loss: 0.3352 - accuracy: 0.90 - ETA: 2s - loss: 0.3375 - accuracy: 0.89 - ETA: 2s - loss: 0.3345 - accuracy: 0.90 - ETA: 2s - loss: 0.3295 - accuracy: 0.90 - ETA: 2s - loss: 0.3328 - accuracy: 0.90 - ETA: 2s - loss: 0.3328 - accuracy: 0.90 - ETA: 2s - loss: 0.3316 - accuracy: 0.90 - ETA: 2s - loss: 0.3285 - accuracy: 0.90 - ETA: 2s - loss: 0.3269 - accuracy: 0.90 - ETA: 2s - loss: 0.3264 - accuracy: 0.90 - ETA: 2s - loss: 0.3257 - accuracy: 0.90 - ETA: 2s - loss: 0.3219 - accuracy: 0.90 - ETA: 2s - loss: 0.3197 - accuracy: 0.90 - ETA: 2s - loss: 0.3208 - accuracy: 0.90 - ETA: 1s - loss: 0.3223 - accuracy: 0.90 - ETA: 1s - loss: 0.3235 - accuracy: 0.90 - ETA: 1s - loss: 0.3275 - accuracy: 0.90 - ETA: 1s - loss: 0.3282 - accuracy: 0.90 - ETA: 1s - loss: 0.3298 - accuracy: 0.90 - ETA: 1s - loss: 0.3317 - accuracy: 0.90 - ETA: 1s - loss: 0.3309 - accuracy: 0.90 - ETA: 1s - loss: 0.3310 - accuracy: 0.90 - ETA: 1s - loss: 0.3363 - accuracy: 0.89 - ETA: 1s - loss: 0.3345 - accuracy: 0.89 - ETA: 1s - loss: 0.3365 - accuracy: 0.90 - ETA: 1s - loss: 0.3358 - accuracy: 0.90 - ETA: 1s - loss: 0.3320 - accuracy: 0.90 - ETA: 1s - loss: 0.3334 - accuracy: 0.90 - ETA: 1s - loss: 0.3326 - accuracy: 0.90 - ETA: 1s - loss: 0.3339 - accuracy: 0.90 - ETA: 1s - loss: 0.3357 - accuracy: 0.90 - ETA: 0s - loss: 0.3337 - accuracy: 0.90 - ETA: 0s - loss: 0.3310 - accuracy: 0.90 - ETA: 0s - loss: 0.3307 - accuracy: 0.90 - ETA: 0s - loss: 0.3322 - accuracy: 0.90 - ETA: 0s - loss: 0.3305 - accuracy: 0.90 - ETA: 0s - loss: 0.3305 - accuracy: 0.90 - ETA: 0s - loss: 0.3291 - accuracy: 0.90 - ETA: 0s - loss: 0.3283 - accuracy: 0.90 - ETA: 0s - loss: 0.3290 - accuracy: 0.90 - ETA: 0s - loss: 0.3299 - accuracy: 0.90 - ETA: 0s - loss: 0.3315 - accuracy: 0.90 - ETA: 0s - loss: 0.3338 - accuracy: 0.90 - ETA: 0s - loss: 0.3340 - accuracy: 0.90 - ETA: 0s - loss: 0.3326 - accuracy: 0.90 - ETA: 0s - loss: 0.3313 - accuracy: 0.90 - ETA: 0s - loss: 0.3332 - accuracy: 0.90 - ETA: 0s - loss: 0.3333 - accuracy: 0.90 - ETA: 0s - loss: 0.3345 - accuracy: 0.89 - 5s 739us/step - loss: 0.3364 - accuracy: 0.8994 - val_loss: 0.6895 - val_accuracy: 0.8299
#
# Epoch 00017: val_loss did not improve from 0.54728
# Epoch 18/20
# 6680/6680 [==============================] - ETA: 4s - loss: 0.1823 - accuracy: 0.95 - ETA: 4s - loss: 0.2439 - accuracy: 0.90 - ETA: 4s - loss: 0.2063 - accuracy: 0.91 - ETA: 4s - loss: 0.2670 - accuracy: 0.89 - ETA: 4s - loss: 0.2621 - accuracy: 0.90 - ETA: 4s - loss: 0.2704 - accuracy: 0.90 - ETA: 4s - loss: 0.2597 - accuracy: 0.91 - ETA: 4s - loss: 0.2606 - accuracy: 0.90 - ETA: 4s - loss: 0.2524 - accuracy: 0.90 - ETA: 4s - loss: 0.2542 - accuracy: 0.90 - ETA: 4s - loss: 0.2570 - accuracy: 0.90 - ETA: 4s - loss: 0.2546 - accuracy: 0.90 - ETA: 4s - loss: 0.2756 - accuracy: 0.90 - ETA: 3s - loss: 0.2766 - accuracy: 0.90 - ETA: 3s - loss: 0.2855 - accuracy: 0.90 - ETA: 3s - loss: 0.2763 - accuracy: 0.91 - ETA: 3s - loss: 0.2792 - accuracy: 0.90 - ETA: 3s - loss: 0.2903 - accuracy: 0.90 - ETA: 3s - loss: 0.2842 - accuracy: 0.90 - ETA: 3s - loss: 0.2788 - accuracy: 0.90 - ETA: 3s - loss: 0.2736 - accuracy: 0.91 - ETA: 3s - loss: 0.2686 - accuracy: 0.91 - ETA: 3s - loss: 0.2661 - accuracy: 0.91 - ETA: 3s - loss: 0.2718 - accuracy: 0.91 - ETA: 3s - loss: 0.2688 - accuracy: 0.91 - ETA: 3s - loss: 0.2652 - accuracy: 0.91 - ETA: 3s - loss: 0.2679 - accuracy: 0.91 - ETA: 3s - loss: 0.2807 - accuracy: 0.91 - ETA: 3s - loss: 0.2813 - accuracy: 0.91 - ETA: 3s - loss: 0.2801 - accuracy: 0.91 - ETA: 3s - loss: 0.2800 - accuracy: 0.91 - ETA: 2s - loss: 0.2749 - accuracy: 0.91 - ETA: 2s - loss: 0.2822 - accuracy: 0.91 - ETA: 2s - loss: 0.2788 - accuracy: 0.91 - ETA: 2s - loss: 0.2788 - accuracy: 0.91 - ETA: 2s - loss: 0.2771 - accuracy: 0.91 - ETA: 2s - loss: 0.2776 - accuracy: 0.91 - ETA: 2s - loss: 0.2781 - accuracy: 0.91 - ETA: 2s - loss: 0.2788 - accuracy: 0.91 - ETA: 2s - loss: 0.2812 - accuracy: 0.91 - ETA: 2s - loss: 0.2804 - accuracy: 0.91 - ETA: 2s - loss: 0.2770 - accuracy: 0.91 - ETA: 2s - loss: 0.2774 - accuracy: 0.91 - ETA: 2s - loss: 0.2767 - accuracy: 0.91 - ETA: 2s - loss: 0.2756 - accuracy: 0.91 - ETA: 2s - loss: 0.2755 - accuracy: 0.91 - ETA: 2s - loss: 0.2792 - accuracy: 0.91 - ETA: 2s - loss: 0.2790 - accuracy: 0.91 - ETA: 2s - loss: 0.2803 - accuracy: 0.91 - ETA: 1s - loss: 0.2833 - accuracy: 0.91 - ETA: 1s - loss: 0.2831 - accuracy: 0.91 - ETA: 1s - loss: 0.2847 - accuracy: 0.91 - ETA: 1s - loss: 0.2860 - accuracy: 0.91 - ETA: 1s - loss: 0.2885 - accuracy: 0.90 - ETA: 1s - loss: 0.2863 - accuracy: 0.91 - ETA: 1s - loss: 0.2866 - accuracy: 0.90 - ETA: 1s - loss: 0.2853 - accuracy: 0.90 - ETA: 1s - loss: 0.2837 - accuracy: 0.91 - ETA: 1s - loss: 0.2821 - accuracy: 0.91 - ETA: 1s - loss: 0.2803 - accuracy: 0.91 - ETA: 1s - loss: 0.2830 - accuracy: 0.91 - ETA: 1s - loss: 0.2870 - accuracy: 0.90 - ETA: 1s - loss: 0.2856 - accuracy: 0.90 - ETA: 1s - loss: 0.2875 - accuracy: 0.90 - ETA: 1s - loss: 0.2862 - accuracy: 0.90 - ETA: 1s - loss: 0.2883 - accuracy: 0.90 - ETA: 0s - loss: 0.2878 - accuracy: 0.90 - ETA: 0s - loss: 0.2884 - accuracy: 0.90 - ETA: 0s - loss: 0.2939 - accuracy: 0.90 - ETA: 0s - loss: 0.2959 - accuracy: 0.90 - ETA: 0s - loss: 0.2973 - accuracy: 0.90 - ETA: 0s - loss: 0.2983 - accuracy: 0.90 - ETA: 0s - loss: 0.2994 - accuracy: 0.90 - ETA: 0s - loss: 0.3001 - accuracy: 0.90 - ETA: 0s - loss: 0.3003 - accuracy: 0.90 - ETA: 0s - loss: 0.2990 - accuracy: 0.90 - ETA: 0s - loss: 0.2975 - accuracy: 0.90 - ETA: 0s - loss: 0.2989 - accuracy: 0.90 - ETA: 0s - loss: 0.2997 - accuracy: 0.90 - ETA: 0s - loss: 0.2999 - accuracy: 0.90 - ETA: 0s - loss: 0.3000 - accuracy: 0.90 - ETA: 0s - loss: 0.2988 - accuracy: 0.90 - ETA: 0s - loss: 0.2989 - accuracy: 0.90 - ETA: 0s - loss: 0.2994 - accuracy: 0.90 - 5s 740us/step - loss: 0.2993 - accuracy: 0.9070 - val_loss: 0.7162 - val_accuracy: 0.8180
#
# Epoch 00018: val_loss did not improve from 0.54728
# Epoch 19/20
# 6680/6680 [==============================] - ETA: 4s - loss: 0.2522 - accuracy: 0.90 - ETA: 4s - loss: 0.1905 - accuracy: 0.92 - ETA: 4s - loss: 0.3522 - accuracy: 0.90 - ETA: 4s - loss: 0.3542 - accuracy: 0.90 - ETA: 4s - loss: 0.3220 - accuracy: 0.90 - ETA: 4s - loss: 0.3029 - accuracy: 0.90 - ETA: 4s - loss: 0.3254 - accuracy: 0.90 - ETA: 4s - loss: 0.3109 - accuracy: 0.90 - ETA: 4s - loss: 0.3018 - accuracy: 0.91 - ETA: 4s - loss: 0.3093 - accuracy: 0.90 - ETA: 4s - loss: 0.3022 - accuracy: 0.90 - ETA: 4s - loss: 0.3108 - accuracy: 0.90 - ETA: 4s - loss: 0.3039 - accuracy: 0.91 - ETA: 4s - loss: 0.2930 - accuracy: 0.91 - ETA: 3s - loss: 0.2922 - accuracy: 0.91 - ETA: 3s - loss: 0.2905 - accuracy: 0.91 - ETA: 3s - loss: 0.2834 - accuracy: 0.91 - ETA: 3s - loss: 0.2808 - accuracy: 0.91 - ETA: 3s - loss: 0.2779 - accuracy: 0.91 - ETA: 3s - loss: 0.2730 - accuracy: 0.91 - ETA: 3s - loss: 0.2770 - accuracy: 0.91 - ETA: 3s - loss: 0.2699 - accuracy: 0.92 - ETA: 3s - loss: 0.2695 - accuracy: 0.92 - ETA: 3s - loss: 0.2712 - accuracy: 0.91 - ETA: 3s - loss: 0.2664 - accuracy: 0.92 - ETA: 3s - loss: 0.2727 - accuracy: 0.91 - ETA: 3s - loss: 0.2715 - accuracy: 0.92 - ETA: 3s - loss: 0.2643 - accuracy: 0.92 - ETA: 3s - loss: 0.2653 - accuracy: 0.92 - ETA: 3s - loss: 0.2685 - accuracy: 0.92 - ETA: 3s - loss: 0.2687 - accuracy: 0.91 - ETA: 2s - loss: 0.2707 - accuracy: 0.91 - ETA: 2s - loss: 0.2725 - accuracy: 0.91 - ETA: 2s - loss: 0.2689 - accuracy: 0.91 - ETA: 2s - loss: 0.2690 - accuracy: 0.91 - ETA: 2s - loss: 0.2677 - accuracy: 0.91 - ETA: 2s - loss: 0.2706 - accuracy: 0.91 - ETA: 2s - loss: 0.2804 - accuracy: 0.91 - ETA: 2s - loss: 0.2859 - accuracy: 0.91 - ETA: 2s - loss: 0.2853 - accuracy: 0.91 - ETA: 2s - loss: 0.2809 - accuracy: 0.91 - ETA: 2s - loss: 0.2778 - accuracy: 0.91 - ETA: 2s - loss: 0.2769 - accuracy: 0.91 - ETA: 2s - loss: 0.2747 - accuracy: 0.91 - ETA: 2s - loss: 0.2715 - accuracy: 0.91 - ETA: 2s - loss: 0.2742 - accuracy: 0.91 - ETA: 2s - loss: 0.2727 - accuracy: 0.91 - ETA: 2s - loss: 0.2727 - accuracy: 0.92 - ETA: 2s - loss: 0.2735 - accuracy: 0.91 - ETA: 1s - loss: 0.2707 - accuracy: 0.92 - ETA: 1s - loss: 0.2688 - accuracy: 0.92 - ETA: 1s - loss: 0.2650 - accuracy: 0.92 - ETA: 1s - loss: 0.2641 - accuracy: 0.92 - ETA: 1s - loss: 0.2616 - accuracy: 0.92 - ETA: 1s - loss: 0.2617 - accuracy: 0.92 - ETA: 1s - loss: 0.2617 - accuracy: 0.92 - ETA: 1s - loss: 0.2596 - accuracy: 0.92 - ETA: 1s - loss: 0.2603 - accuracy: 0.92 - ETA: 1s - loss: 0.2603 - accuracy: 0.92 - ETA: 1s - loss: 0.2617 - accuracy: 0.92 - ETA: 1s - loss: 0.2629 - accuracy: 0.92 - ETA: 1s - loss: 0.2641 - accuracy: 0.92 - ETA: 1s - loss: 0.2641 - accuracy: 0.92 - ETA: 1s - loss: 0.2628 - accuracy: 0.92 - ETA: 1s - loss: 0.2613 - accuracy: 0.92 - ETA: 1s - loss: 0.2616 - accuracy: 0.92 - ETA: 0s - loss: 0.2598 - accuracy: 0.92 - ETA: 0s - loss: 0.2624 - accuracy: 0.92 - ETA: 0s - loss: 0.2639 - accuracy: 0.92 - ETA: 0s - loss: 0.2649 - accuracy: 0.92 - ETA: 0s - loss: 0.2655 - accuracy: 0.92 - ETA: 0s - loss: 0.2690 - accuracy: 0.92 - ETA: 0s - loss: 0.2683 - accuracy: 0.92 - ETA: 0s - loss: 0.2671 - accuracy: 0.92 - ETA: 0s - loss: 0.2669 - accuracy: 0.92 - ETA: 0s - loss: 0.2701 - accuracy: 0.91 - ETA: 0s - loss: 0.2699 - accuracy: 0.91 - ETA: 0s - loss: 0.2745 - accuracy: 0.91 - ETA: 0s - loss: 0.2743 - accuracy: 0.91 - ETA: 0s - loss: 0.2746 - accuracy: 0.91 - ETA: 0s - loss: 0.2747 - accuracy: 0.91 - ETA: 0s - loss: 0.2732 - accuracy: 0.91 - ETA: 0s - loss: 0.2746 - accuracy: 0.91 - ETA: 0s - loss: 0.2779 - accuracy: 0.91 - 5s 740us/step - loss: 0.2778 - accuracy: 0.9169 - val_loss: 0.7066 - val_accuracy: 0.8299
#
# Epoch 00019: val_loss did not improve from 0.54728
# Epoch 20/20
# 6680/6680 [==============================] - ETA: 4s - loss: 0.3706 - accuracy: 0.85 - ETA: 4s - loss: 0.2843 - accuracy: 0.87 - ETA: 4s - loss: 0.2612 - accuracy: 0.89 - ETA: 4s - loss: 0.2866 - accuracy: 0.88 - ETA: 4s - loss: 0.2630 - accuracy: 0.89 - ETA: 4s - loss: 0.2996 - accuracy: 0.89 - ETA: 4s - loss: 0.2891 - accuracy: 0.89 - ETA: 4s - loss: 0.2827 - accuracy: 0.90 - ETA: 4s - loss: 0.2730 - accuracy: 0.90 - ETA: 4s - loss: 0.2664 - accuracy: 0.90 - ETA: 4s - loss: 0.2714 - accuracy: 0.90 - ETA: 4s - loss: 0.2794 - accuracy: 0.90 - ETA: 4s - loss: 0.2867 - accuracy: 0.90 - ETA: 3s - loss: 0.2783 - accuracy: 0.91 - ETA: 3s - loss: 0.2636 - accuracy: 0.91 - ETA: 3s - loss: 0.2639 - accuracy: 0.91 - ETA: 3s - loss: 0.2748 - accuracy: 0.91 - ETA: 3s - loss: 0.2723 - accuracy: 0.91 - ETA: 3s - loss: 0.2814 - accuracy: 0.91 - ETA: 3s - loss: 0.2751 - accuracy: 0.91 - ETA: 3s - loss: 0.2752 - accuracy: 0.91 - ETA: 3s - loss: 0.2851 - accuracy: 0.91 - ETA: 3s - loss: 0.2982 - accuracy: 0.91 - ETA: 3s - loss: 0.3057 - accuracy: 0.91 - ETA: 3s - loss: 0.3010 - accuracy: 0.91 - ETA: 3s - loss: 0.2977 - accuracy: 0.91 - ETA: 3s - loss: 0.2916 - accuracy: 0.91 - ETA: 3s - loss: 0.2872 - accuracy: 0.91 - ETA: 3s - loss: 0.2835 - accuracy: 0.91 - ETA: 3s - loss: 0.2901 - accuracy: 0.91 - ETA: 3s - loss: 0.2874 - accuracy: 0.91 - ETA: 2s - loss: 0.2884 - accuracy: 0.91 - ETA: 2s - loss: 0.2828 - accuracy: 0.91 - ETA: 2s - loss: 0.2796 - accuracy: 0.91 - ETA: 2s - loss: 0.2772 - accuracy: 0.91 - ETA: 2s - loss: 0.2782 - accuracy: 0.91 - ETA: 2s - loss: 0.2770 - accuracy: 0.91 - ETA: 2s - loss: 0.2794 - accuracy: 0.91 - ETA: 2s - loss: 0.2736 - accuracy: 0.91 - ETA: 2s - loss: 0.2728 - accuracy: 0.91 - ETA: 2s - loss: 0.2748 - accuracy: 0.91 - ETA: 2s - loss: 0.2718 - accuracy: 0.91 - ETA: 2s - loss: 0.2706 - accuracy: 0.91 - ETA: 2s - loss: 0.2682 - accuracy: 0.91 - ETA: 2s - loss: 0.2675 - accuracy: 0.91 - ETA: 2s - loss: 0.2723 - accuracy: 0.91 - ETA: 2s - loss: 0.2702 - accuracy: 0.91 - ETA: 2s - loss: 0.2680 - accuracy: 0.91 - ETA: 2s - loss: 0.2694 - accuracy: 0.91 - ETA: 1s - loss: 0.2662 - accuracy: 0.91 - ETA: 1s - loss: 0.2626 - accuracy: 0.91 - ETA: 1s - loss: 0.2650 - accuracy: 0.91 - ETA: 1s - loss: 0.2635 - accuracy: 0.91 - ETA: 1s - loss: 0.2619 - accuracy: 0.91 - ETA: 1s - loss: 0.2600 - accuracy: 0.91 - ETA: 1s - loss: 0.2574 - accuracy: 0.91 - ETA: 1s - loss: 0.2593 - accuracy: 0.91 - ETA: 1s - loss: 0.2573 - accuracy: 0.91 - ETA: 1s - loss: 0.2587 - accuracy: 0.91 - ETA: 1s - loss: 0.2593 - accuracy: 0.91 - ETA: 1s - loss: 0.2592 - accuracy: 0.92 - ETA: 1s - loss: 0.2588 - accuracy: 0.92 - ETA: 1s - loss: 0.2610 - accuracy: 0.92 - ETA: 1s - loss: 0.2614 - accuracy: 0.92 - ETA: 1s - loss: 0.2616 - accuracy: 0.92 - ETA: 1s - loss: 0.2673 - accuracy: 0.91 - ETA: 0s - loss: 0.2691 - accuracy: 0.91 - ETA: 0s - loss: 0.2691 - accuracy: 0.91 - ETA: 0s - loss: 0.2690 - accuracy: 0.91 - ETA: 0s - loss: 0.2726 - accuracy: 0.91 - ETA: 0s - loss: 0.2711 - accuracy: 0.91 - ETA: 0s - loss: 0.2686 - accuracy: 0.91 - ETA: 0s - loss: 0.2675 - accuracy: 0.91 - ETA: 0s - loss: 0.2678 - accuracy: 0.91 - ETA: 0s - loss: 0.2675 - accuracy: 0.91 - ETA: 0s - loss: 0.2667 - accuracy: 0.91 - ETA: 0s - loss: 0.2687 - accuracy: 0.91 - ETA: 0s - loss: 0.2689 - accuracy: 0.91 - ETA: 0s - loss: 0.2717 - accuracy: 0.91 - ETA: 0s - loss: 0.2730 - accuracy: 0.91 - ETA: 0s - loss: 0.2723 - accuracy: 0.91 - ETA: 0s - loss: 0.2726 - accuracy: 0.91 - ETA: 0s - loss: 0.2736 - accuracy: 0.91 - ETA: 0s - loss: 0.2724 - accuracy: 0.91 - 5s 739us/step - loss: 0.2722 - accuracy: 0.9186 - val_loss: 0.7042 - val_accuracy: 0.8335
#
# Epoch 00020: val_loss did not improve from 0.54728

# %% [markdown]
# ### (IMPLEMENTATION) Load the Model with the Best Validation Loss

# %%
### TODO: Load the model weights with the best validation loss.
Xception_model.load_weights('saved_models/weights.best.Xception.hdf5')

# %% [markdown]
# ### (IMPLEMENTATION) Test the Model
#
# Try out your model on the test dataset of dog images. Ensure that your test accuracy is greater than 60%.

# %%
### TODO: Calculate classification accuracy on the test dataset.
Xception_predictions = [np.argmax(Xception_model.predict(np.expand_dims(feature, axis=0))) for feature in test_Xception]
test_accuracy = 100*np.sum(np.array(Xception_predictions)==np.argmax(test_targets, axis=1))/len(Xception_predictions)
print('Test accuracy: %.4f%%' % test_accuracy)
# Out:
# Test accuracy: 82.6555%

# %% [markdown]
# ### (IMPLEMENTATION) Predict Dog Breed with the Model
#
# Write a function that takes an image path as input and returns the dog breed (`Affenpinscher`, `Afghan_hound`, etc) that is predicted by your model.
#
# Similar to the analogous function in Step 5, your function should have three steps:
# 1. Extract the bottleneck features corresponding to the chosen CNN model.
# 2. Supply the bottleneck features as input to the model to return the predicted vector.  Note that the argmax of this prediction vector gives the index of the predicted dog breed.
# 3. Use the `dog_names` array defined in Step 0 of this notebook to return the corresponding breed.
#
# The functions to extract the bottleneck features can be found in `extract_bottleneck_features.py`, and they have been imported in an earlier code cell.  To obtain the bottleneck features corresponding to your chosen CNN architecture, you need to use the function
#
#     extract_{network}
#
# where `{network}`, in the above filename, should be one of `VGG19`, `Resnet50`, `InceptionV3`, or `Xception`.

# %%
### TODO: Write a function that takes a path to an image as input
### and returns the dog breed that is predicted by the model.

def Xception_predict_breed(img_path):
    # extract bottleneck features
    bottleneck_feature = extract_Xception(path_to_tensor(img_path))     
    
    # obtain predicted vector
    predicted_vector = Xception_model.predict(bottleneck_feature)       
    name = dog_names[np.argmax(predicted_vector)].split(".")[1]
    
    # return dog breed that is predicted by the model
    return name

# %% [markdown]
# ---
# <a id='step6'></a>
# ## Step 6: Write your Algorithm
#
# Write an algorithm that accepts a file path to an image and first determines whether the image contains a human, dog, or neither.  Then,
# - if a __dog__ is detected in the image, return the predicted breed.
# - if a __human__ is detected in the image, return the resembling dog breed.
# - if __neither__ is detected in the image, provide output that indicates an error.
#
# You are welcome to write your own functions for detecting humans and dogs in images, but feel free to use the `face_detector` and `dog_detector` functions developed above.  You are __required__ to use your CNN from Step 5 to predict dog breed.
#
# Some sample output for our algorithm is provided below, but feel free to design your own user experience!
#
# ![Sample Human Output](images/sample_human_output.png)
#
#
# ### (IMPLEMENTATION) Write your Algorithm

# %%
### TODO: Write your algorithm.
### Feel free to use as many code cells as needed.
import matplotlib.image as mpimg

def predict_breed(img_path):
    _, ax = plt.subplots()
    img = mpimg.imread(img_path)
    _ = ax.imshow(img)
    # Beautify
    ax.tick_params(axis="both", which="both",length=0)
    plt.show()
    if dog_detector(img_path):
        print("Hey, cute dog!")
        return print("I love dogs! Even more because you are a(n) {}".format(Xception_predict_breed(img_path)))     
    if face_detector(img_path):
        print("Hey, human!")
        return print("I love dogs, do you know? I liked you! And if you were a dog, I guess you would be a(n) ... {}!!".format(Xception_predict_breed(img_path)))    
    else:
        return print("Hum... My brain is confused! I don't know what you are...")

# %% [markdown]
# ---
# <a id='step7'></a>
# ## Step 7: Test Your Algorithm
#
# In this section, you will take your new algorithm for a spin!  What kind of dog does the algorithm think that __you__ look like?  If you have a dog, does it predict your dog's breed accurately?  If you have a cat, does it mistakenly think that your cat is a dog?
#
# ### (IMPLEMENTATION) Test Your Algorithm on Sample Images!
#
# Test your algorithm at least six images on your computer.  Feel free to use any images you like.  Use at least two human and two dog images.
#
# __Question 6:__ Is the output better than you expected :) ?  Or worse :( ?  Provide at least three possible points of improvement for your algorithm.
#
# __Answer:__
#
# The output is better than I expected. There is no errors, even the funny images. I'm impressed.
#
# In my opinion the output could be better with:
# - Image Augmentation.
# - Adding more breeds to the dataset
# - Maybe increasing the depth of the neural network.

# %%
## TODO: Execute your algorithm from Step 6 on
## at least 6 images on your computer.
## Feel free to use as many code cells as needed.
import numpy as np
sample_files = np.array(glob("test_images/*"))
for file in sample_files:
    predict_breed(file)
# Out:
# Hey, cute dog!
# I love dogs! Even more because you are a(n) Pharaoh_hound
# Hey, cute dog!
# I love dogs! Even more because you are a(n) Boston_terrier
# Hey, cute dog!
# I love dogs! Even more because you are a(n) Italian_greyhound
# Hey, cute dog!
# I love dogs! Even more because you are a(n) Bichon_frise
# Hey, cute dog!
# I love dogs! Even more because you are a(n) Bull_terrier

# %% [markdown]
# # Please download your notebook to submit
#
# In order to submit, please do the following:
# 1.  Download an HTML version of the notebook to your computer using 'File: Download as...'
# 2.  Click on the orange Jupyter circle on the top left of the workspace.
# 3.  Navigate into the dog-project folder to ensure that you are using the provided dog_images, lfw, and bottleneck_features folders; this means that those folders will *not* appear in the dog-project folder.  If they do appear because you downloaded them, delete them.
# 4.  While in the dog-project folder, upload the HTML version of this notebook you just downloaded.  The upload button is on the top right.
# 5.  Navigate back to the home folder by clicking on the two dots next to the folder icon, and then open up a terminal under the 'new' tab on the top right
# 6.  Zip the dog-project folder with the following command in the terminal:
#  `zip -r dog-project.zip dog-project`
# 7.  Download the zip file by clicking on the square next to it and selecting 'download'.  This will be the zip file you turn in on the next node after this workspace!
